# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import seaborn as sns
from matplotlib import axes
import os 
import pandas as pd
import json

import sys, os
sys.path.append('/cluster/home/kamara/Explain')
from clutils.nbutils import *
from clutils.nbutils.params import get_param_ranges
os.getcwd()
sns.set()

# %% [markdown]
# # Sparsity

# %%
dir = '/cluster/home/kamara/Explain/csv/node_classification'

expe = "sparsity_mask_nc"


jsonpath = f'/cluster/home/kamara/Explain/configs/config_{expe}.json'
ranges = get_param_ranges(jsonpath)

df_sparsity = pd.read_csv(os.path.join(dir, f'{expe}.csv'), index_col = 0)
res = df_sparsity.groupby(by=['dataset', 'sparsity', 'explainer_name', 'hard_mask']).mean()
res = res.reset_index()

# %%
def explainer_type(row):
    if row['explainer_name'] in ['gnnexplainer', 'pgmexplainer', 'occlusion', 'subgraphx'] :
      return('pertubation')
    elif row['explainer_name'] in ['sa', 'ig'] :
      return('gradient')
    return('baseline')



df_sparsity['type'] = df_sparsity.apply(lambda row: explainer_type(row), axis=1)
df_sparsity["1-fidelity_acc-"] = 1- df_sparsity["fidelity_acc-"]
df_sparsity["1-fidelity_prob-"] = 1- df_sparsity["fidelity_prob-"]
df_sparsity['charact'] = 2 * df_sparsity['fidelity_prob+'] * (1-df_sparsity['fidelity_prob-'])/ (df_sparsity['fidelity_prob+']  + 1-df_sparsity['fidelity_prob-'])

# %%
df_sparsity = df_sparsity.reset_index()
df_sparsity
# Out:
#     dataset  sparsity explainer_name  hard_mask  num_test  f1_score    recall  \
# 0      syn1     0.000       distance      False     100.0  0.005823  1.000000
# 1      syn1     0.000       distance       True     100.0  0.005823  1.000000
# 2      syn1     0.000   gnnexplainer      False     100.0  0.444157  1.000000
# 3      syn1     0.000   gnnexplainer       True     100.0  0.444157  1.000000
# 4      syn1     0.000             ig      False     100.0  0.005099  0.873333
# ..      ...       ...            ...        ...       ...       ...       ...
# 355    syn6     0.997         random       True     100.0  0.002500  0.004000
# 356    syn6     0.997             sa      False     100.0  0.000000  0.000000
# 357    syn6     0.997             sa       True     100.0  0.000000  0.000000
# 358    syn6     0.997      subgraphx      False     100.0  0.661056  0.634000
# 359    syn6     0.997      subgraphx       True     100.0  0.661056  0.634000
#
#      precision  fidelity_acc+  fidelity_acc-  ...  mask_sparsity  expl_edges  \
# 0     0.002920           0.28           0.64  ...       0.010139     4068.33
# 1     0.002920           0.76           0.00  ...       0.010139     4068.33
# 2     0.328940           0.56           0.56  ...       0.953431      191.40
# 3     0.328940           0.76           0.00  ...       0.953431      191.40
# 4     0.002557           0.35           0.64  ...       0.002487     4099.78
# ..         ...            ...            ...  ...            ...         ...
# 355   0.001818           0.00           0.64  ...       0.997214       11.00
# 356   0.000000           0.00           0.64  ...       0.997214       11.00
# 357   0.000000           0.00           0.64  ...       0.997214       11.00
# 358   0.700500           0.54           0.20  ...       0.997829        8.57
# 359   0.700500           0.54           0.20  ...       0.997829        8.57
#
#        time  number_of_edges  mask_sparsity_init  non_zero_values_init  \
# 0    0.0127           4110.0            0.010139               4068.33
# 1    0.0135           4110.0            0.010139               4068.33
# 2    2.6306           4110.0            0.953431                191.40
# 3    2.7273           4110.0            0.953431                191.40
# 4    0.1824           4110.0            0.002487               4099.78
# ..      ...              ...                 ...                   ...
# 355  0.0000           3948.0            0.000253               3947.00
# 356  0.0031           3948.0            0.000750               3945.04
# 357  0.0032           3948.0            0.000750               3945.04
# 358  0.8231           3948.0            0.997822                  8.60
# 359  0.9027           3948.0            0.997822                  8.60
#
#             type  1-fidelity_acc- 1-fidelity_prob-   charact
# 0       baseline             0.36         0.641922  0.177405
# 1       baseline             1.00         1.000000  0.677024
# 2    pertubation             0.44         0.651122  0.407165
# 3    pertubation             1.00         1.000000  0.677024
# 4       gradient             0.36         0.587258  0.079796
# ..           ...              ...              ...       ...
# 355     baseline             0.36         0.400972 -0.000221
# 356     gradient             0.36         0.400972  0.002583
# 357     gradient             0.36         0.400972  0.002584
# 358  pertubation             0.80         0.816930  0.615281
# 359  pertubation             0.80         0.816930  0.615281
#
# [360 rows x 22 columns]

# %% [markdown]
# ## Initial analysis: initial sparsity, time, characterisation

# %%
df_init_spars = df_sparsity.groupby(by=['dataset', 'explainer_name', 'sparsity', "hard_mask"]).mean()
df_init_spars = df_init_spars.reset_index()
dfs = df_init_spars[df_init_spars.sparsity==0.7]
res_init = dfs[['dataset', 'explainer_name', 'hard_mask', 'mask_sparsity_init', 'non_zero_values_init', 'number_of_edges', 'time', 'fidelity_prob+', 'fidelity_prob-', 'charact']]

res_init.groupby(by=['dataset', 'explainer_name', 'hard_mask']).mean()
# Out:
#                                   mask_sparsity_init  non_zero_values_init  \
# dataset explainer_name hard_mask
# syn1    distance       False                0.010139               4068.33
#                        True                 0.010139               4068.33
#         gnnexplainer   False                0.953431                191.40
#                        True                 0.953431                191.40
#         ig             False                0.002487               4099.78
# ...                                              ...                   ...
# syn6    random         True                 0.000253               3947.00
#         sa             False                0.000750               3945.04
#                        True                 0.000750               3945.04
#         subgraphx      False                0.997822                  8.60
#                        True                 0.997822                  8.60
#
#                                   number_of_edges    time  fidelity_prob+  \
# dataset explainer_name hard_mask
# syn1    distance       False               4110.0  0.0126        0.103253
#                        True                4110.0  0.0133        0.511743
#         gnnexplainer   False               4110.0  5.4951        0.285161
#                        True                4110.0  5.4003        0.511743
#         ig             False               4110.0  0.2795       -0.052695
# ...                                           ...     ...             ...
# syn6    random         True                3948.0  0.0000        0.277472
#         sa             False               3948.0  0.0036        0.008694
#                        True                3948.0  0.0032        0.008697
#         subgraphx      False               3948.0  1.0733        0.493473
#                        True                3948.0  0.8213        0.493473
#
#                                   fidelity_prob-   charact
# dataset explainer_name hard_mask
# syn1    distance       False            0.352198  0.178116
#                        True            -0.001285  0.677318
#         gnnexplainer   False            0.344436  0.397441
#                        True            -0.000399  0.677115
#         ig             False            0.681581 -0.126291
# ...                                          ...       ...
# syn6    random         True             0.431006  0.373033
#         sa             False            0.599028  0.017018
#                        True             0.599028  0.017024
#         subgraphx      False            0.183529  0.615151
#                        True             0.183529  0.615151
#
# [90 rows x 7 columns]

# %% [markdown]
# ### Hard mask

# %%
res_init_hard = res_init[res_init.hard_mask==True]

# %%
mask_spars_init = pd.pivot_table(res_init_hard, values='mask_sparsity_init', index=['explainer_name'], columns='dataset')
mask_spars_init['mean_sparsity'] = mask_spars_init.mean(axis=1)
mask_spars_init.sort_values(by=['mean_sparsity'])
# Out:
# dataset             syn1      syn3      syn4      syn5      syn6  \
# explainer_name
# random          0.000243  0.000197  0.000517  0.000293  0.000253
# pagerank        0.000487  0.000606  0.001250  0.001021  0.000507
# distance        0.010139  0.006459  0.004721  0.001232  0.031619
# sa              0.214808  0.000531  0.001395  0.010587  0.000750
# occlusion       0.000243  0.000537  0.001121  0.988639  0.000415
# ig              0.002487  0.000496  0.985579  0.631607  0.004792
# pgmexplainer    0.851698  0.925886  0.985579  0.980587  0.796601
# gnnexplainer    0.953431  0.967177  0.990083  0.988639  0.937042
# subgraphx       0.997397  0.996941  0.995610  0.995601  0.997822
#
# dataset         mean_sparsity
# explainer_name
# random               0.000301
# pagerank             0.000774
# distance             0.010834
# sa                   0.045614
# occlusion            0.198191
# ig                   0.324992
# pgmexplainer         0.908070
# gnnexplainer         0.967274
# subgraphx            0.996674

# %%
df_time = pd.pivot_table(res_init_hard, values='time', index=['explainer_name'], columns='dataset')
df_time['mean_time'] = df_time.mean(axis=1)
df_time.sort_values(by=['mean_time'])
# Out:
# dataset           syn1    syn3    syn4    syn5    syn6  mean_time
# explainer_name
# random          0.0000  0.0001  0.0000  0.0000  0.0000    0.00002
# sa              0.0028  0.0041  0.0036  0.0047  0.0032    0.00368
# distance        0.0133  0.0183  0.0088  0.0154  0.0230    0.01576
# pagerank        0.0198  0.0279  0.0138  0.0191  0.0219    0.02050
# ig              0.2730  0.3017  0.1676  0.2191  0.1433    0.22094
# occlusion       0.4183  0.5057  0.0558  0.1276  0.7387    0.36922
# subgraphx       0.6486  1.5981  0.2591  4.7213  0.8213    1.60968
# gnnexplainer    5.4003  2.7137  2.5718  2.6233  2.6679    3.19540
# pgmexplainer    3.2176  6.5210  4.1914  5.6468  5.2533    4.96602

# %%
df_char = pd.pivot_table(res_init_hard, values='charact', index=['explainer_name'], columns='dataset')
df_char['mean_charact'] = df_char.mean(axis=1)
df_char.sort_values(by=['mean_charact'])
# Out:
# dataset             syn1      syn3      syn4      syn5      syn6  mean_charact
# explainer_name
# sa             -0.238635 -0.000106  0.457419  0.223290  0.017024      0.091798
# random          0.272575 -0.003151  0.071025  0.239814  0.373033      0.190659
# ig             -0.206185 -0.000628  0.981177  0.920105  0.003549      0.339604
# subgraphx       0.587492  0.018127  0.076577  0.524509  0.615151      0.364371
# occlusion       0.647175  0.000000  0.335005  0.926875  0.104610      0.402733
# gnnexplainer    0.677115  0.019988  0.981177  0.926875  0.729945      0.667020
# distance        0.677318  0.020226  0.981177  0.926875  0.748355      0.670790
# pagerank        0.677050  0.020226  0.981177  0.926875  0.749240      0.670914
# pgmexplainer    0.677998  0.020226  0.981177  0.926875  0.749021      0.671059

# %% [markdown]
# ### Soft mask

# %%
res_init_soft = res_init[res_init.hard_mask==False]

# %%
mask_spars_init = pd.pivot_table(res_init_soft, values='mask_sparsity_init', index=['explainer_name'], columns='dataset')
mask_spars_init['mean_sparsity'] = mask_spars_init.mean(axis=1)
mask_spars_init.sort_values(by=['mean_sparsity'])
# Out:
# dataset             syn1      syn3      syn4      syn5      syn6  \
# explainer_name
# random          0.000243  0.000197  0.000517  0.000293  0.000253
# pagerank        0.000487  0.000606  0.001250  0.001021  0.000507
# distance        0.010139  0.006459  0.004721  0.001232  0.031619
# sa              0.214808  0.000531  0.001395  0.010587  0.000750
# occlusion       0.000243  0.000537  0.001121  0.988639  0.000415
# ig              0.002487  0.000496  0.985579  0.631607  0.004792
# pgmexplainer    0.851698  0.925886  0.985579  0.980587  0.796601
# gnnexplainer    0.953431  0.967177  0.990083  0.988639  0.937042
# subgraphx       0.997397  0.996941  0.995610  0.995601  0.997822
#
# dataset         mean_sparsity
# explainer_name
# random               0.000301
# pagerank             0.000774
# distance             0.010834
# sa                   0.045614
# occlusion            0.198191
# ig                   0.324992
# pgmexplainer         0.908070
# gnnexplainer         0.967274
# subgraphx            0.996674

# %%
df_time = pd.pivot_table(res_init_soft, values='time', index=['explainer_name'], columns='dataset')
df_time['mean_time'] = df_time.mean(axis=1)
df_time.sort_values(by=['mean_time'])
# Out:
# dataset           syn1    syn3    syn4    syn5    syn6  mean_time
# explainer_name
# random          0.0001  0.0001  0.0000  0.0000  0.0000    0.00004
# sa              0.0043  0.0036  0.0033  0.0056  0.0036    0.00408
# distance        0.0126  0.0171  0.0078  0.0157  0.0165    0.01394
# pagerank        0.0234  0.0256  0.0140  0.0212  0.0280    0.02244
# ig              0.2795  0.2996  0.1462  0.1778  0.1551    0.21164
# occlusion       0.5741  0.5155  0.0574  0.1653  0.4925    0.36096
# subgraphx       0.4916  1.9075  0.2721  3.7094  1.0733    1.49078
# gnnexplainer    5.4951  2.6142  3.0621  2.6183  5.4585    3.84964
# pgmexplainer    3.7610  4.7005  4.0967  5.6483  3.4760    4.33650

# %%
df_char = pd.pivot_table(res_init_soft, values='charact', index=['explainer_name'], columns='dataset')
df_char['mean_charact'] = df_char.mean(axis=1)
df_char.sort_values(by=['mean_charact'])
# Out:
# dataset             syn1      syn3      syn4      syn5      syn6  mean_charact
# explainer_name
# sa             -0.073754 -0.000106  0.185449  0.197333  0.017018      0.065188
# distance        0.178116 -0.003622  0.071466  0.242291  0.245516      0.146753
# random          0.232497 -0.003556  0.070340  0.228888  0.304561      0.166546
# ig             -0.126291 -0.000627  0.861329  0.341135 -0.050716      0.204966
# occlusion       0.647124  0.000000  0.073514  0.362645  0.104610      0.237579
# gnnexplainer    0.397441 -0.000207  0.109706  0.274780  0.482046      0.252753
# subgraphx       0.587492  0.018127  0.076577  0.524509  0.615151      0.364371
# pagerank        0.637748  0.008173  0.530648  0.243779  0.741528      0.432375
# pgmexplainer    0.712203 -0.002371  0.990290  0.917351  0.727622      0.669019

# %% [markdown]
# ## Plots

# %%
# Create a visualization
type=[True, False]

fig, axs = plt.subplots(2,1,figsize=(15,15))

for i in range(2):
    df_sparsity_h = df_sparsity[df_sparsity.hard_mask==type[i]]
    g0 = sns.lineplot(
        data=df_sparsity_h[df_sparsity_h.dataset=="syn3"],
        x="sparsity", y="precision",
        hue="explainer_name", marker="o", linestyle='--', ax=axs[i], legend=False)
    for line in g0.lines:
        line.set_linestyle("--")

    g1 = sns.lineplot(
        data=df_sparsity_h[df_sparsity_h.dataset=="syn3"],
        x="sparsity", y="recall",
        hue="explainer_name", marker="o", ax=axs[i])


    plt.ylabel('precision / recall')
    axs[i].set_title(f'hard mask is {type[i]}')
plt.show()

# %%
# Create a visualization
type=[True, False]

fig, axs = plt.subplots(2,1,figsize=(15,15))

for i in range(2):
    df_sparsity_h = df_sparsity[df_sparsity.hard_mask==type[i]]
    sns.lineplot(
        data=df_sparsity_h[df_sparsity_h.dataset=="syn3"],
        x="sparsity", y="f1_score",
        hue="explainer_name", marker="o", ax=axs[i])
    plt.ylabel('F1 score')
    axs[i].set_title(f'hard mask is {type[i]}')
plt.show()

# %%
ranges['dataset']
# Out:
# ['syn1', 'syn3', 'syn4', 'syn5', 'syn6']

# %%
sns.set()
fig, axs = plt.subplots(3, 2, figsize=(15,8))
for i in range(5):
    sns.lineplot(
        data=df_sparsity[df_sparsity.dataset==ranges['dataset'][i]],
        x="sparsity", y="auc", 
        hue="explainer_name", marker="o", ax=axs[i//2, i%2])
    if i!=4:
        axs[i//2, i%2].get_legend().remove()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_9229/1228917069.py in <module>
#       2 fig, axs = plt.subplots(3, 2, figsize=(15,8))
#       3 for i in range(5):
# ----> 4     sns.lineplot(
#       5         data=df_sparsity[df_sparsity.dataset==ranges['dataset'][i]],
#       6         x="sparsity", y="auc",
#
# /cluster/apps/nss/gcc-8.2.0/python/3.8.5/x86_64/lib64/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /cluster/apps/nss/gcc-8.2.0/python/3.8.5/x86_64/lib64/python3.8/site-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     690
#     691     variables = _LinePlotter.get_semantics(locals())
# --> 692     p = _LinePlotter(
#     693         data=data, variables=variables,
#     694         estimator=estimator, ci=ci, n_boot=n_boot, seed=seed,
#
# /cluster/apps/nss/gcc-8.2.0/python/3.8.5/x86_64/lib64/python3.8/site-packages/seaborn/relational.py in __init__(self, data, variables, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend)
#     365         )
#     366
# --> 367         super().__init__(data=data, variables=variables)
#     368
#     369         self.estimator = estimator
#
# /cluster/apps/nss/gcc-8.2.0/python/3.8.5/x86_64/lib64/python3.8/site-packages/seaborn/_core.py in __init__(self, data, variables)
#     603     def __init__(self, data=None, variables={}):
#     604
# --> 605         self.assign_variables(data, variables)
#     606
#     607         for var, cls in self._semantic_mappings.items():
#
# /cluster/apps/nss/gcc-8.2.0/python/3.8.5/x86_64/lib64/python3.8/site-packages/seaborn/_core.py in assign_variables(self, data, variables)
#     666         else:
#     667             self.input_format = "long"
# --> 668             plot_data, variables = self._assign_variables_longform(
#     669                 data, **variables,
#     670             )
#
# /cluster/apps/nss/gcc-8.2.0/python/3.8.5/x86_64/lib64/python3.8/site-packages/seaborn/_core.py in _assign_variables_longform(self, data, **kwargs)
#     901
#     902                 err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 903                 raise ValueError(err)
#     904
#     905             else:
#
# ValueError: Could not interpret value `auc` for parameter `y`

# %%
df_sparsity_small = df_sparsity[df_sparsity['dataset'].isin(['syn1', 'syn5'])]
df_sparsity_small
# Out:
#      index dataset  sparsity explainer_name  num_test_nodes  gpu  f1_score  \
# 0        0    syn1     0.000       distance           100.0  1.0  0.005823
# 1        1    syn1     0.000   gnnexplainer           100.0  1.0  0.470810
# 2        2    syn1     0.000        ig_node           100.0  1.0  0.007333
# 3        3    syn1     0.000      occlusion           100.0  1.0  0.005822
# 4        4    syn1     0.000       pagerank           100.0  1.0  0.005825
# ..     ...     ...       ...            ...             ...  ...       ...
# 139    139    syn5     0.997       pagerank           100.0  1.0  0.552941
# 140    140    syn5     0.997   pgmexplainer           100.0  1.0  0.541176
# 141    141    syn5     0.997         random           100.0  1.0  0.005455
# 142    142    syn5     0.997        sa_node           100.0  1.0  0.562549
# 143    143    syn5     0.997      subgraphx           100.0  1.0  0.590981
#
#        recall  precision       auc  ...  fidelity_prob-  mask_sparsity  \
# 0    1.000000   0.002920  0.998450  ...        0.000000       0.009175
# 1    1.000000   0.371259  0.968212  ...        0.000000       0.937606
# 2    0.920000   0.003703  0.519937  ...        0.238978       0.050822
# 3    1.000000   0.002920  0.040737  ...       -0.100171       0.000243
# 4    1.000000   0.002921  0.999891  ...        0.000000       0.000487
# ..        ...        ...       ...  ...             ...            ...
# 139  0.393333   0.932000  0.693659  ...        0.818558       0.997068
# 140  0.383333   0.920000  0.691551  ...        0.753033       0.997068
# 141  0.005000   0.006000  0.499783  ...        0.866700       0.997068
# 142  0.401667   0.941000  0.695966  ...        0.787651       0.997068
# 143  0.444167   0.897286  0.687568  ...        0.791763       0.997079
#
#      expl_edges     time  number_of_edges  mask_sparsity_init  \
# 0       4072.29   0.0159           4110.0            0.009175
# 1        256.44   2.5984           4110.0            0.937606
# 2       3901.12   0.1673           4110.0            0.050822
# 3       4109.00   0.5983           4110.0            0.000243
# 4       4108.00   0.0210           4110.0            0.000487
# ..          ...      ...              ...                 ...
# 139       10.00   0.0201           3410.0            0.000845
# 140       10.00  10.6972           3410.0            0.983378
# 141       10.00   0.0000           3410.0            0.000293
# 142       10.00   0.0039           3410.0            0.983378
# 143        9.96   3.2824           3410.0            0.996106
#
#      non_zero_values_init         type  1-fidelity_acc-  1-fidelity_prob-
# 0                 4072.29     baseline             1.00          1.000000
# 1                  256.44  pertubation             1.00          1.000000
# 2                 3901.12     gradient             0.76          0.761022
# 3                 4109.00  pertubation             1.00          1.100171
# 4                 4108.00     baseline             1.00          1.000000
# ..                    ...          ...              ...               ...
# 139               3407.12     baseline             0.01          0.181442
# 140                 56.68  pertubation             0.06          0.246967
# 141               3409.00     baseline             0.00          0.133300
# 142                 56.68     gradient             0.04          0.212349
# 143                 13.28  pertubation             0.02          0.208237
#
# [72 rows x 23 columns]

# %%
sns.set()

sns.relplot(
        data=df_sparsity,
        x="sparsity", y="charact", col="dataset", row="explainer_name", 
        hue="hard_mask", alpha = .8
    )

# %%
sns.set()

sns.relplot(
        data=df_sparsity,
        x="fidelity_acc+", y="1-fidelity_acc-", col="sparsity", row="dataset", 
        hue="explainer_name", size="time", sizes=(50, 300), style="type", alpha = .8
    )

# %%
sns.relplot(
        data=df_sparsity_small,
        x="fidelity_prob+", y="1-fidelity_prob-", col="sparsity", row="dataset", 
        hue="explainer_name", size="time", sizes=(50, 300), style="type", alpha = .9
    )

# %%
sns.relplot(
        data=df_sparsity_small,
        x="precision", y="recall", col="sparsity", row="dataset", 
        hue="explainer_name", size="time", sizes=(50, 300), style="type"
    )

# %% [markdown]
# # Threshold

# %%
dir = '/cluster/home/kamara/Explain/csv/'

expe = "threshold"


jsonpath = f'/cluster/home/kamara/Explain/config_{expe}.json'
ranges = get_param_ranges(jsonpath)

df = pd.read_csv(os.path.join(dir, f'{expe}.csv'), index_col = 0)
#res = df.groupby(by=['dataset', 'threshold', 'explainer_name']).mean()
#res.reset_index()
#df = df.reset_index()
#df = df[df.dataset=="syn1"]
res = df.groupby(by=['dataset', 'explainer_name', 'threshold']).mean()
res.reset_index()
# Out:
#     dataset explainer_name  threshold  num_test_nodes  gpu  f1_score  \
# 0      syn1       distance        0.5           100.0  1.0  0.563576
# 1      syn1       distance        0.8           100.0  1.0  0.563576
# 2      syn1       distance        0.9           100.0  1.0  0.563576
# 3      syn1   gnnexplainer        0.5           100.0  1.0  0.365325
# 4      syn1   gnnexplainer        0.8           100.0  1.0  0.396900
# ..      ...            ...        ...             ...  ...       ...
# 130    syn6        sa_node        0.8           100.0  1.0  0.114324
# 131    syn6        sa_node        0.9           100.0  1.0  0.180224
# 132    syn6      subgraphx        0.5           100.0  1.0  0.770111
# 133    syn6      subgraphx        0.8           100.0  1.0  0.782778
# 134    syn6      subgraphx        0.9           100.0  1.0  0.773444
#
#        recall  precision       auc  fidelity_acc+  fidelity_acc-  \
# 0    0.413333   0.939500  0.603303           0.05           0.53
# 1    0.413333   0.939500  0.603303           0.05           0.53
# 2    0.413333   0.939500  0.603303           0.05           0.53
# 3    0.650000   0.355707  0.720080           0.44           0.29
# 4    0.683333   0.392814  0.727922           0.44           0.31
# ..        ...        ...       ...            ...            ...
# 130  0.112000   0.246149  0.331125           0.01           0.64
# 131  0.112000   0.532635  0.336103           0.01           0.64
# 132  0.740000   0.814000  0.869815           0.62           0.04
# 133  0.752000   0.827500  0.875820           0.63           0.03
# 134  0.744000   0.811500  0.871812           0.62           0.05
#
#      fidelity_prob+  fidelity_prob-  mask_sparsity  expl_edges    time  \
# 0         -0.123116        0.487905       0.999336        2.73  0.0162
# 1         -0.123116        0.487905       0.999336        2.73  0.0139
# 2         -0.123116        0.487905       0.999336        2.73  0.0163
# 3          0.285291        0.151176       0.941944      238.61  2.6174
# 4          0.300469        0.173215       0.942144      237.79  4.7447
# ..              ...             ...            ...         ...     ...
# 130       -0.010230        0.589573       0.548607     1782.10  0.0029
# 131       -0.014498        0.589573       0.560998     1733.18  0.0027
# 132        0.570269        0.045479       0.997756        8.86  3.0914
# 133        0.580068        0.035429       0.997735        8.94  3.3878
# 134        0.567656        0.052988       0.997741        8.92  3.1119
#
#      number_of_edges  mask_sparsity_init  non_zero_values_init
# 0             4110.0            0.009175               4072.29
# 1             4110.0            0.009175               4072.29
# 2             4110.0            0.009175               4072.29
# 3             4110.0            0.937606                256.44
# 4             4110.0            0.937606                256.44
# ..               ...                 ...                   ...
# 130           3948.0            0.000750               3945.04
# 131           3948.0            0.000750               3945.04
# 132           3948.0            0.977756                  8.86
# 133           3948.0            0.987736                  8.94
# 134           3948.0            0.977741                  8.92
#
# [135 rows x 19 columns]

# %%
def explainer_type(row):
    if row['explainer_name'] in ['gnnexplainer', 'pgmexplainer', 'occlusion', 'subgraphx'] :
      return('pertubation')
    elif row['explainer_name'] in ['sa_node', 'ig_node'] :
      return('gradient')
    return('baseline')



df['type'] = df.apply(lambda row: explainer_type(row), axis=1)
df["1-fidelity_acc-"] = 1- df["fidelity_acc-"]
df["1-fidelity_prob-"] = 1- df["fidelity_prob-"]

# %%
df = df.reset_index()
df
# Out:
#     dataset  threshold explainer_name  num_test_nodes  gpu  f1_score  \
# 0      syn1        0.5       distance           100.0  1.0  0.563576
# 1      syn1        0.5   gnnexplainer           100.0  1.0  0.365325
# 2      syn1        0.5        ig_node           100.0  1.0  0.446275
# 3      syn1        0.5      occlusion           100.0  1.0  0.001630
# 4      syn1        0.5       pagerank           100.0  1.0  0.880128
# ..      ...        ...            ...             ...  ...       ...
# 130    syn6        0.9       pagerank           100.0  1.0  0.423048
# 131    syn6        0.9   pgmexplainer           100.0  1.0  0.380048
# 132    syn6        0.9         random           100.0  1.0  0.005078
# 133    syn6        0.9        sa_node           100.0  1.0  0.180224
# 134    syn6        0.9      subgraphx           100.0  1.0  0.773444
#
#        recall  precision       auc  fidelity_acc+  ...  fidelity_prob-  \
# 0    0.413333   0.939500  0.603303           0.05  ...        0.487905
# 1    0.650000   0.355707  0.720080           0.44  ...        0.151176
# 2    0.436667   0.459524  0.478424           0.05  ...        0.445705
# 3    0.240000   0.000818  0.062967           0.48  ...        0.009594
# 4    0.861667   0.903381  0.930774           0.53  ...       -0.018173
# ..        ...        ...       ...            ...  ...             ...
# 130  0.314000   0.957333  0.656954           0.63  ...        0.326768
# 131  0.376000   0.560708  0.687330           0.57  ...        0.253975
# 132  0.194000   0.002573  0.500879           0.07  ...        0.577516
# 133  0.112000   0.532635  0.336103           0.01  ...        0.589573
# 134  0.744000   0.811500  0.871812           0.62  ...        0.052988
#
#      mask_sparsity  expl_edges    time  number_of_edges  mask_sparsity_init  \
# 0         0.999336        2.73  0.0162           4110.0            0.009175
# 1         0.941944      238.61  2.6174           4110.0            0.937606
# 2         0.520219     1971.90  0.1674           4110.0            0.050822
# 3         0.062044     3855.00  0.7179           4110.0            0.000243
# 4         0.997202       11.50  0.0198           4110.0            0.000487
# ..             ...         ...     ...              ...                 ...
# 130       0.999103        3.54  0.0209           3948.0            0.000507
# 131       0.997219       10.98  3.8762           3948.0            0.780314
# 132       0.899491      396.81  0.0000           3948.0            0.000253
# 133       0.560998     1733.18  0.0027           3948.0            0.000750
# 134       0.997741        8.92  3.1119           3948.0            0.977741
#
#      non_zero_values_init         type  1-fidelity_acc- 1-fidelity_prob-
# 0                 4072.29     baseline             0.47         0.512095
# 1                  256.44  pertubation             0.71         0.848824
# 2                 3901.12     gradient             0.47         0.554295
# 3                 4109.00  pertubation             0.95         0.990406
# 4                 4108.00     baseline             0.95         1.018173
# ..                    ...          ...              ...              ...
# 130               3946.00     baseline             0.64         0.673232
# 131                867.32  pertubation             0.77         0.746025
# 132               3947.00     baseline             0.37         0.422484
# 133               3945.04     gradient             0.36         0.410427
# 134                  8.92  pertubation             0.95         0.947012
#
# [135 rows x 22 columns]

# %%
# Create a visualization


fig, ax = plt.subplots(figsize=(15,8))
g0 = sns.lineplot(
    data=df[df.dataset=="syn3"],
    x="threshold", y="precision",
    hue="explainer_name", marker="o", linestyle='--', ax=ax, legend=False)
for line in g0.lines:
    line.set_linestyle("--")

g1 = sns.lineplot(
    data=df[df.dataset=="syn3"],
    x="threshold", y="recall",
    hue="explainer_name", marker="o", ax=ax)


plt.ylabel('precision / recall')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,8))
sns.lineplot(
    data=df[df.dataset=="syn3"],
    x="threshold", y="f1_score", 
    hue="explainer_name", marker="o", ax=ax)

# %%
df_small = df[df['dataset'].isin(['syn1', 'syn5'])]
df_small
# Out:
#     dataset  threshold explainer_name  num_test_nodes  gpu  f1_score  \
# 0      syn1        0.5       distance           100.0  1.0  0.563576
# 1      syn1        0.5   gnnexplainer           100.0  1.0  0.365325
# 2      syn1        0.5        ig_node           100.0  1.0  0.446275
# 3      syn1        0.5      occlusion           100.0  1.0  0.001630
# 4      syn1        0.5       pagerank           100.0  1.0  0.880128
# 5      syn1        0.5   pgmexplainer           100.0  1.0  0.501004
# 6      syn1        0.5         random           100.0  1.0  0.005979
# 7      syn1        0.5        sa_node           100.0  1.0  0.028457
# 8      syn1        0.5      subgraphx           100.0  1.0  0.807160
# 9      syn1        0.8       distance           100.0  1.0  0.563576
# 10     syn1        0.8   gnnexplainer           100.0  1.0  0.396900
# 11     syn1        0.8        ig_node           100.0  1.0  0.339048
# 12     syn1        0.8      occlusion           100.0  1.0  0.007459
# 13     syn1        0.8       pagerank           100.0  1.0  0.571909
# 14     syn1        0.8   pgmexplainer           100.0  1.0  0.522865
# 15     syn1        0.8         random           100.0  1.0  0.006058
# 16     syn1        0.8        sa_node           100.0  1.0  0.014393
# 17     syn1        0.8      subgraphx           100.0  1.0  0.788960
# 18     syn1        0.9       distance           100.0  1.0  0.563576
# 19     syn1        0.9   gnnexplainer           100.0  1.0  0.358370
# 20     syn1        0.9        ig_node           100.0  1.0  0.157143
# 21     syn1        0.9      occlusion           100.0  1.0  0.013983
# 22     syn1        0.9       pagerank           100.0  1.0  0.491190
# 23     syn1        0.9   pgmexplainer           100.0  1.0  0.471866
# 24     syn1        0.9         random           100.0  1.0  0.005707
# 25     syn1        0.9        sa_node           100.0  1.0  0.014286
# 26     syn1        0.9      subgraphx           100.0  1.0  0.798312
# 81     syn5        0.5       distance           100.0  1.0  0.358749
# 82     syn5        0.5   gnnexplainer           100.0  1.0  0.558295
# 83     syn5        0.5        ig_node           100.0  1.0  0.781497
# 84     syn5        0.5      occlusion           100.0  1.0  0.317872
# 85     syn5        0.5       pagerank           100.0  1.0  0.538479
# 86     syn5        0.5   pgmexplainer           100.0  1.0  0.792880
# 87     syn5        0.5         random           100.0  1.0  0.013988
# 88     syn5        0.5        sa_node           100.0  1.0  0.738765
# 89     syn5        0.5      subgraphx           100.0  1.0  0.624797
# 90     syn5        0.8       distance           100.0  1.0  0.358749
# 91     syn5        0.8   gnnexplainer           100.0  1.0  0.560953
# 92     syn5        0.8        ig_node           100.0  1.0  0.443217
# 93     syn5        0.8      occlusion           100.0  1.0  0.328294
# 94     syn5        0.8       pagerank           100.0  1.0  0.358749
# 95     syn5        0.8   pgmexplainer           100.0  1.0  0.830996
# 96     syn5        0.8         random           100.0  1.0  0.014498
# 97     syn5        0.8        sa_node           100.0  1.0  0.507126
# 98     syn5        0.8      subgraphx           100.0  1.0  0.622009
# 99     syn5        0.9       distance           100.0  1.0  0.358749
# 100    syn5        0.9   gnnexplainer           100.0  1.0  0.574700
# 101    syn5        0.9        ig_node           100.0  1.0  0.273165
# 102    syn5        0.9      occlusion           100.0  1.0  0.300097
# 103    syn5        0.9       pagerank           100.0  1.0  0.338442
# 104    syn5        0.9   pgmexplainer           100.0  1.0  0.851155
# 105    syn5        0.9         random           100.0  1.0  0.012194
# 106    syn5        0.9        sa_node           100.0  1.0  0.374597
# 107    syn5        0.9      subgraphx           100.0  1.0  0.629564
#
#        recall  precision       auc  fidelity_acc+  ...  fidelity_prob-  \
# 0    0.413333   0.939500  0.603303           0.05  ...        0.487905
# 1    0.650000   0.355707  0.720080           0.44  ...        0.151176
# 2    0.436667   0.459524  0.478424           0.05  ...        0.445705
# 3    0.240000   0.000818  0.062967           0.48  ...        0.009594
# 4    0.861667   0.903381  0.930774           0.53  ...       -0.018173
# 5    0.855000   0.433912  0.916793           0.53  ...       -0.023408
# 6    0.770000   0.003001  0.500446           0.48  ...        0.237188
# 7    0.111667   0.028801  0.041801           0.05  ...        0.509471
# 8    0.808333   0.823357  0.903998           0.45  ...        0.083544
# 9    0.413333   0.939500  0.603303           0.05  ...        0.487905
# 10   0.683333   0.392814  0.727922           0.44  ...        0.173215
# 11   0.253333   0.520000  0.387418           0.07  ...        0.482980
# 12   0.123333   0.010398  0.062181           0.28  ...        0.279828
# 13   0.421667   0.939500  0.710803           0.53  ...        0.013379
# 14   0.530000   0.631063  0.763202           0.41  ...        0.311931
# 15   0.376667   0.003054  0.505341           0.21  ...        0.407586
# 16   0.026667   0.050054  0.029584           0.00  ...        0.487905
# 17   0.786667   0.808452  0.893145           0.45  ...        0.090550
# 18   0.413333   0.939500  0.603303           0.05  ...        0.487905
# 19   0.598333   0.368546  0.678427           0.32  ...        0.287634
# 20   0.093333   0.520000  0.308265           0.12  ...        0.305373
# 21   0.078333   0.040206  0.068522           0.25  ...        0.338137
# 22   0.335000   1.000000  0.667500           0.53  ...        0.254542
# 23   0.393333   0.703296  0.696138           0.33  ...        0.390160
# 24   0.188333   0.002898  0.499716           0.11  ...        0.443439
# 25   0.008333   0.050000  0.031121           0.00  ...        0.487905
# 26   0.795000   0.823357  0.897334           0.45  ...        0.077922
# 81   0.226667   0.914333  0.556616           0.45  ...        0.866700
# 82   0.474167   0.714326  0.642085           0.85  ...        0.863046
# 83   0.733333   0.850781  0.866189           1.00  ...        0.584709
# 84   0.233333   0.786846  0.503521           0.75  ...        0.867967
# 85   0.384167   0.920905  0.691994           1.00  ...        0.849978
# 86   0.929167   0.718911  0.964074           1.00  ...        0.012246
# 87   0.750833   0.007060  0.498173           0.96  ...        0.838597
# 88   0.643333   0.898417  0.821477           0.99  ...        0.763766
# 89   0.491667   0.903142  0.745650           1.00  ...        0.564677
# 90   0.226667   0.914333  0.556616           0.45  ...        0.866700
# 91   0.480833   0.699222  0.644578           0.84  ...        0.865169
# 92   0.302500   0.889845  0.651096           0.49  ...        0.796815
# 93   0.213333   0.868345  0.533869           0.74  ...        0.867848
# 94   0.226667   0.914333  0.613252           1.00  ...        0.869240
# 95   0.915833   0.779160  0.957408           1.00  ...        0.137648
# 96   0.377500   0.007391  0.503718           0.74  ...        0.867799
# 97   0.357500   0.977048  0.678726           0.83  ...        0.824847
# 98   0.488333   0.894924  0.743969           1.00  ...        0.567772
# 99   0.226667   0.914333  0.556616           0.45  ...        0.866700
# 100  0.495000   0.723105  0.648559           0.84  ...        0.859929
# 101  0.171667   0.902405  0.585754           0.17  ...        0.807763
# 102  0.189167   0.870012  0.527847           0.72  ...        0.867848
# 103  0.212500   0.914333  0.606168           0.95  ...        0.869237
# 104  0.905833   0.817405  0.952461           1.00  ...        0.191085
# 105  0.170833   0.006323  0.495063           0.50  ...        0.867890
# 106  0.246667   0.995000  0.623327           0.58  ...        0.831408
# 107  0.494167   0.909309  0.746903           1.00  ...        0.568202
#
#      mask_sparsity  expl_edges     time  number_of_edges  mask_sparsity_init  \
# 0         0.999336        2.73   0.0162           4110.0            0.009175
# 1         0.941944      238.61   2.6174           4110.0            0.937606
# 2         0.520219     1971.90   0.1674           4110.0            0.050822
# 3         0.062044     3855.00   0.7179           4110.0            0.000243
# 4         0.997202       11.50   0.0198           4110.0            0.000487
# 5         0.968681      128.72   3.6772           4110.0            0.819397
# 6         0.501431     2049.12   0.0001           4110.0            0.000243
# 7         0.052672     3893.52   0.0027           4110.0            0.000487
# 8         0.997304       11.08   0.8782           4110.0            0.947304
# 9         0.999336        2.73   0.0139           4110.0            0.009175
# 10        0.942144      237.79   4.7447           4110.0            0.937606
# 11        0.522161     1963.92   0.1609           4110.0            0.050822
# 12        0.070818     3818.94   0.5102           4110.0            0.000243
# 13        0.998647        5.56   0.0227           4110.0            0.000487
# 14        0.994297       23.44   3.9813           4110.0            0.820701
# 15        0.800216      821.11   0.0001           4110.0            0.000243
# 16        0.053528     3890.00   0.0048           4110.0            0.000487
# 17        0.997328       10.98   0.9468           4110.0            0.947328
# 18        0.999336        2.73   0.0163           4110.0            0.009175
# 19        0.969039      127.25   2.6277           4110.0            0.937606
# 20        0.524316     1955.06   0.1487           4110.0            0.050822
# 21        0.100397     3697.37   0.5205           4110.0            0.000243
# 22        0.999022        4.02   0.0226           4110.0            0.000487
# 23        0.997732        9.32   5.4703           4110.0            0.821333
# 24        0.899976      411.10   0.0000           4110.0            0.000243
# 25        0.056647     3877.18   0.0033           4110.0            0.000487
# 26        0.997348       10.90   0.9897           4110.0            0.947348
# 81        0.999103        3.06   0.0124           3410.0            0.001220
# 82        0.997164        9.67   2.5275           3410.0            0.989724
# 83        0.993759       21.28   0.2249           3410.0            0.778094
# 84        0.881296      404.78   0.1295           3410.0            0.002346
# 85        0.997085        9.94   0.0184           3410.0            0.000845
# 86        0.990047       33.94   5.9245           3410.0            0.983378
# 87        0.500370     1703.74   0.0000           3410.0            0.000293
# 88        0.994921       17.32   0.0040           3410.0            0.983378
# 89        0.996176       13.04   3.1927           3410.0            0.996176
# 90        0.999103        3.06   0.0155           3410.0            0.001220
# 91        0.997114        9.84   3.8330           3410.0            0.989724
# 92        0.997566        8.30   0.1908           3410.0            0.778094
# 93        0.959783      137.14   0.1517           3410.0            0.002346
# 94        0.998205        6.12   0.0220           3410.0            0.000845
# 95        0.991320       29.60   6.5631           3410.0            0.983378
# 96        0.800173      681.41   0.0000           3410.0            0.000293
# 97        0.997419        8.80   0.0044           3410.0            0.983378
# 98        0.996170       13.06   3.4908           3410.0            0.996170
# 99        0.999103        3.06   0.0152           3410.0            0.001220
# 100       0.997114        9.84   2.6087           3410.0            0.989724
# 101       0.998628        4.68   0.2175           3410.0            0.778094
# 102       0.959903      136.73   0.1450           3410.0            0.002346
# 103       0.998305        5.78   0.0185           3410.0            0.000845
# 104       0.991941       27.48  11.3458           3410.0            0.983378
# 105       0.899891      341.37   0.0001           3410.0            0.000293
# 106       0.998246        5.98   0.0038           3410.0            0.983378
# 107       0.996164       13.08   5.0218           3410.0            0.996164
#
#      non_zero_values_init         type  1-fidelity_acc- 1-fidelity_prob-
# 0                 4072.29     baseline             0.47         0.512095
# 1                  256.44  pertubation             0.71         0.848824
# 2                 3901.12     gradient             0.47         0.554295
# 3                 4109.00  pertubation             0.95         0.990406
# 4                 4108.00     baseline             0.95         1.018173
# 5                  742.28  pertubation             0.99         1.023408
# 6                 4109.00     baseline             0.58         0.762812
# 7                 4108.00     gradient             0.47         0.490529
# 8                   11.08  pertubation             0.81         0.916456
# 9                 4072.29     baseline             0.47         0.512095
# 10                 256.44  pertubation             0.69         0.826785
# 11                3901.12     gradient             0.47         0.517020
# 12                4109.00  pertubation             0.75         0.720172
# 13                4108.00     baseline             0.95         0.986621
# 14                 736.92  pertubation             0.54         0.688069
# 15                4109.00     baseline             0.51         0.592414
# 16                4108.00     gradient             0.47         0.512095
# 17                  10.98  pertubation             0.82         0.909450
# 18                4072.29     baseline             0.47         0.512095
# 19                 256.44  pertubation             0.59         0.712366
# 20                3901.12     gradient             0.47         0.694627
# 21                4109.00  pertubation             0.69         0.661863
# 22                4108.00     baseline             0.70         0.745458
# 23                 734.32  pertubation             0.48         0.609840
# 24                4109.00     baseline             0.47         0.556561
# 25                4108.00     gradient             0.47         0.512095
# 26                  10.90  pertubation             0.82         0.922078
# 81                3405.84     baseline             0.00         0.133300
# 82                  35.04  pertubation             0.01         0.136954
# 83                 756.70     gradient             0.28         0.415291
# 84                3402.00  pertubation             0.00         0.132033
# 85                3407.12     baseline             0.01         0.150022
# 86                  56.68  pertubation             0.98         0.987754
# 87                3409.00     baseline             0.03         0.161403
# 88                  56.68     gradient             0.05         0.236234
# 89                  13.04  pertubation             0.27         0.435323
# 90                3405.84     baseline             0.00         0.133300
# 91                  35.04  pertubation             0.00         0.134831
# 92                 756.70     gradient             0.09         0.203185
# 93                3402.00  pertubation             0.00         0.132152
# 94                3407.12     baseline             0.00         0.130760
# 95                  56.68  pertubation             0.82         0.862352
# 96                3409.00     baseline             0.00         0.132201
# 97                  56.68     gradient             0.02         0.175153
# 98                  13.06  pertubation             0.26         0.432228
# 99                3405.84     baseline             0.00         0.133300
# 100                 35.04  pertubation             0.01         0.140071
# 101                756.70     gradient             0.08         0.192237
# 102               3402.00  pertubation             0.00         0.132152
# 103               3407.12     baseline             0.00         0.130763
# 104                 56.68  pertubation             0.74         0.808915
# 105               3409.00     baseline             0.00         0.132110
# 106                 56.68     gradient             0.04         0.168592
# 107                 13.08  pertubation             0.27         0.431798
#
# [54 rows x 22 columns]

# %%
sns.set()

sns.relplot(
        data=df_small,
        x="fidelity_acc+", y="1-fidelity_acc-", col="threshold", row="dataset", 
        hue="explainer_name", size="time", sizes=(50, 300), style="type"
    )

# %%
sns.relplot(
        data=df_small,
        x="fidelity_prob+", y="1-fidelity_prob-", col="threshold", row="dataset", 
        hue="explainer_name", size="time", sizes=(50, 300), style="type", alpha = .9
    )

# %%
sns.relplot(
        data=df_small,
        x="precision", y="recall", col="threshold", row="dataset", 
        hue="explainer_name", size="time", sizes=(50, 300), style="type"
    )

# %% [markdown]
# # Topk

# %%
dir = '/cluster/home/kamara/Explain/csv/'

expe = "topk"


jsonpath = f'/cluster/home/kamara/Explain/config_{expe}.json'
ranges = get_param_ranges(jsonpath)

df = pd.read_csv(os.path.join(dir, f'{expe}.csv'), index_col = 0)
#res = df.groupby(by=['dataset', 'threshold', 'explainer_name']).mean()
#res.reset_index()
#df = df.reset_index()
#df = df[df.dataset=="syn1"]
res = df.groupby(by=['dataset', 'explainer_name', 'topk']).mean()
res.reset_index()
# Out:
#     dataset explainer_name  topk  num_test_nodes  gpu  f1_score    recall  \
# 0      syn1       distance    10           100.0  1.0  0.827099  0.895000
# 1      syn1       distance    20           100.0  1.0  0.598033  0.988333
# 2      syn1       distance    40           100.0  1.0  0.308923  1.000000
# 3      syn1       distance   100           100.0  1.0  0.127024  1.000000
# 4      syn1       distance   500           100.0  1.0  0.026476  1.000000
# ..      ...            ...   ...             ...  ...       ...       ...
# 220    syn6      subgraphx    10           100.0  1.0  0.773000  0.744000
# 221    syn6      subgraphx    20           100.0  1.0  0.764556  0.734000
# 222    syn6      subgraphx    40           100.0  1.0  0.768111  0.738000
# 223    syn6      subgraphx   100           100.0  1.0  0.784778  0.754000
# 224    syn6      subgraphx   500           100.0  1.0  0.765222  0.732000
#
#      precision       auc  fidelity_acc+  fidelity_acc-  fidelity_prob+  \
# 0     0.777849  0.838573           0.38           0.33        0.327711
# 1     0.429664  0.961615           0.51           0.07        0.471140
# 2     0.182739  0.980144           0.53           0.05        0.487905
# 3     0.067827  0.990226           0.53           0.01        0.487905
# 4     0.013416  0.998450           0.53           0.00        0.487905
# ..         ...       ...            ...            ...             ...
# 220   0.810500 -1.000000           0.63           0.02        0.580567
# 221   0.809000 -1.000000           0.63           0.03        0.580177
# 222   0.807000 -1.000000           0.63           0.04        0.577465
# 223   0.824500 -1.000000           0.63           0.03        0.579735
# 224   0.813000 -1.000000           0.63           0.04        0.573782
#
#      fidelity_prob-  mask_sparsity  expl_edges    time  number_of_edges  \
# 0          0.226022       0.997567       10.00  0.0162           4110.0
# 1         -0.002833       0.995134       20.00  0.0163           4110.0
# 2         -0.020141       0.990268       40.00  0.0136           4110.0
# 3         -0.015155       0.975669      100.00  0.0140           4110.0
# 4         -0.006607       0.878345      500.00  0.0186           4110.0
# ..              ...            ...         ...     ...              ...
# 220        0.025418       0.997685        9.14  3.2561           3948.0
# 221        0.034979       0.997685        9.14  3.3019           3948.0
# 222        0.043080       0.997619        9.40  4.2650           3948.0
# 223        0.033479       0.997467       10.00  4.1106           3948.0
# 224        0.044031       0.996484       13.88  3.9086           3948.0
#
#      mask_sparsity_init  non_zero_values_init
# 0              0.009175               4072.29
# 1              0.009175               4072.29
# 2              0.009175               4072.29
# 3              0.009175               4072.29
# 4              0.009175               4072.29
# ..                  ...                   ...
# 220            0.987710                  9.04
# 221            0.987736                  8.94
# 222            0.987720                  9.00
# 223            0.987720                  9.00
# 224            0.987751                  8.88
#
# [225 rows x 19 columns]

# %%
def explainer_type(row):
    if row['explainer_name'] in ['gnnexplainer', 'pgmexplainer', 'occlusion', 'subgraphx'] :
      return('pertubation')
    elif row['explainer_name'] in ['sa_node', 'ig_node'] :
      return('gradient')
    return('baseline')



df['type'] = df.apply(lambda row: explainer_type(row), axis=1)
df["1-fidelity_acc-"] = 1- df["fidelity_acc-"]
df["1-fidelity_prob-"] = 1- df["fidelity_prob-"]

# %%
df = df.reset_index()
df
# Out:
#     dataset  topk explainer_name  num_test_nodes  gpu  f1_score    recall  \
# 0      syn1    10       distance           100.0  1.0  0.827099  0.895000
# 1      syn1    10   gnnexplainer           100.0  1.0  0.393343  0.440000
# 2      syn1    10        ig_node           100.0  1.0  0.415758  0.381667
# 3      syn1    10      occlusion           100.0  1.0  0.040000  0.053333
# 4      syn1    10       pagerank           100.0  1.0  0.863636  0.791667
# ..      ...   ...            ...             ...  ...       ...       ...
# 220    syn6   500       pagerank           100.0  1.0  0.039216  1.000000
# 221    syn6   500   pgmexplainer           100.0  1.0  0.056839  0.978000
# 222    syn6   500         random           100.0  1.0  0.005317  0.252000
# 223    syn6   500        sa_node           100.0  1.0  0.003187  0.112000
# 224    syn6   500      subgraphx           100.0  1.0  0.765222  0.732000
#
#      precision       auc  fidelity_acc+  ...  fidelity_prob-  mask_sparsity  \
# 0     0.777849  0.838573           0.38  ...        0.226022       0.997567
# 1     0.360433  0.650486           0.21  ...        0.415991       0.997567
# 2     0.456667  0.690219           0.05  ...        0.435937       0.997567
# 3     0.032000  0.512180           0.25  ...        0.447654       0.997567
# 4     0.950000  0.895794           0.53  ...       -0.005111       0.997567
# ..         ...       ...            ...  ...             ...            ...
# 220   0.020000  0.999761           0.64  ...        0.002842       0.873354
# 221   0.029418  0.976755           0.64  ...        0.008439       0.903652
# 222   0.002687  0.505638           0.06  ...        0.568873       0.873354
# 223   0.001619  0.499740           0.01  ...        0.589573       0.873354
# 224   0.813000 -1.000000           0.63  ...        0.044031       0.996484
#
#      expl_edges    time  number_of_edges  mask_sparsity_init  \
# 0         10.00  0.0162           4110.0            0.009175
# 1         10.00  5.4596           4110.0            0.937606
# 2         10.00  0.1592           4110.0            0.050822
# 3         10.00  0.5690           4110.0            0.000243
# 4         10.00  0.0200           4110.0            0.000487
# ..          ...     ...              ...                 ...
# 220      500.00  0.0275           3948.0            0.000507
# 221      380.38  5.5268           3948.0            0.780294
# 222      500.00  0.0000           3948.0            0.000253
# 223      500.00  0.0034           3948.0            0.000750
# 224       13.88  3.9086           3948.0            0.987751
#
#      non_zero_values_init         type  1-fidelity_acc- 1-fidelity_prob-
# 0                 4072.29     baseline             0.67         0.773978
# 1                  256.44  pertubation             0.48         0.584009
# 2                 3901.12     gradient             0.47         0.564063
# 3                 4109.00  pertubation             0.51         0.552346
# 4                 4108.00     baseline             0.95         1.005111
# ..                    ...          ...              ...              ...
# 220               3946.00     baseline             0.99         0.997158
# 221                867.40  pertubation             0.98         0.991561
# 222               3947.00     baseline             0.40         0.431127
# 223               3945.04     gradient             0.36         0.410427
# 224                  8.88  pertubation             0.96         0.955969
#
# [225 rows x 22 columns]

# %%
# Create a visualization


fig, ax = plt.subplots(figsize=(15,8))
g0 = sns.lineplot(
    data=df[df.dataset=="syn3"],
    x="topk", y="precision",
    hue="explainer_name", marker="o", linestyle='--', ax=ax, legend=False)
for line in g0.lines:
    line.set_linestyle("--")

g1 = sns.lineplot(
    data=df[df.dataset=="syn3"],
    x="topk", y="recall",
    hue="explainer_name", marker="o", ax=ax)


plt.ylabel('precision / recall')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,8))
sns.lineplot(
    data=df[df.dataset=="syn3"],
    x="topk", y="f1_score", 
    hue="explainer_name", marker="o", ax=ax)

# %%
df_small = df[df['dataset'].isin(['syn1', 'syn5'])]
df_small
# Out:
#     dataset  topk explainer_name  num_test_nodes  gpu  f1_score    recall  \
# 0      syn1    10       distance           100.0  1.0  0.827099  0.895000
# 1      syn1    10   gnnexplainer           100.0  1.0  0.393343  0.440000
# 2      syn1    10        ig_node           100.0  1.0  0.415758  0.381667
# 3      syn1    10      occlusion           100.0  1.0  0.040000  0.053333
# 4      syn1    10       pagerank           100.0  1.0  0.863636  0.791667
# ..      ...   ...            ...             ...  ...       ...       ...
# 175    syn5   500       pagerank           100.0  1.0  0.091600  1.000000
# 176    syn5   500   pgmexplainer           100.0  1.0  0.658149  1.000000
# 177    syn5   500         random           100.0  1.0  0.014618  0.290000
# 178    syn5   500        sa_node           100.0  1.0  0.658149  1.000000
# 179    syn5   500      subgraphx           100.0  1.0  0.618212  0.484167
#
#      precision       auc  fidelity_acc+  ...  fidelity_prob-  mask_sparsity  \
# 0     0.777849  0.838573           0.38  ...        0.226022       0.997567
# 1     0.360433  0.650486           0.21  ...        0.415991       0.997567
# 2     0.456667  0.690219           0.05  ...        0.435937       0.997567
# 3     0.032000  0.512180           0.25  ...        0.447654       0.997567
# 4     0.950000  0.895794           0.53  ...       -0.005111       0.997567
# ..         ...       ...            ...  ...             ...            ...
# 175   0.047998  0.999499           1.00  ...        0.000000       0.853372
# 176   0.522223  0.999228           1.00  ...        0.000000       0.983378
# 177   0.007498  0.504424           0.45  ...        0.868089       0.853372
# 178   0.522223  0.999415           1.00  ...        0.000000       0.983378
# 179   0.896031 -1.000000           1.00  ...        0.580751       0.996199
#
#      expl_edges    time  number_of_edges  mask_sparsity_init  \
# 0         10.00  0.0162           4110.0            0.009175
# 1         10.00  5.4596           4110.0            0.937606
# 2         10.00  0.1592           4110.0            0.050822
# 3         10.00  0.5690           4110.0            0.000243
# 4         10.00  0.0200           4110.0            0.000487
# ..          ...     ...              ...                 ...
# 175      500.00  0.0202           3410.0            0.000845
# 176       56.68  6.4482           3410.0            0.983378
# 177      500.00  0.0001           3410.0            0.000293
# 178       56.68  0.0047           3410.0            0.983378
# 179       12.96  4.0484           3410.0            0.996199
#
#      non_zero_values_init         type  1-fidelity_acc- 1-fidelity_prob-
# 0                 4072.29     baseline             0.67         0.773978
# 1                  256.44  pertubation             0.48         0.584009
# 2                 3901.12     gradient             0.47         0.564063
# 3                 4109.00  pertubation             0.51         0.552346
# 4                 4108.00     baseline             0.95         1.005111
# ..                    ...          ...              ...              ...
# 175               3407.12     baseline             1.00         1.000000
# 176                 56.68  pertubation             1.00         1.000000
# 177               3409.00     baseline             0.00         0.131911
# 178                 56.68     gradient             1.00         1.000000
# 179                 12.96  pertubation             0.25         0.419249
#
# [90 rows x 22 columns]

# %%
sns.set()

sns.relplot(
        data=df_small,
        x="fidelity_acc+", y="1-fidelity_acc-", col="topk", row="dataset", 
        hue="explainer_name", size="time", sizes=(50, 300), style="type"
    )

# %%
sns.relplot(
        data=df_small,
        x="fidelity_prob+", y="1-fidelity_prob-", col="topk", row="dataset", 
        hue="explainer_name", size="time", sizes=(50, 300), style="type", alpha = .9
    )

# %%
sns.relplot(
        data=df_small,
        x="precision", y="recall", col="topk", row="dataset", 
        hue="explainer_name", size="time", sizes=(50, 300), style="type"
    )

# %% [markdown]
# # Accuracy Top

# %%
dir = '/cluster/home/kamara/Explain/csv/'

expe = "top_edges"


jsonpath = f'/cluster/home/kamara/Explain/config_{expe}.json'
ranges = get_param_ranges(jsonpath)

df = pd.read_csv(os.path.join(dir, f'{expe}.csv'), index_col = 0)
#res = df.groupby(by=['dataset', 'threshold', 'explainer_name']).mean()
#res.reset_index()
#df = df.reset_index()
#df = df[df.dataset=="syn1"]
res = df.groupby(by=['dataset', 'explainer_name']).mean()

# %%
def explainer_type(row):
    if row['explainer_name'] in ['gnnexplainer', 'pgmexplainer', 'occlusion', 'subgraphx'] :
      return('pertubation')
    elif row['explainer_name'] in ['sa_node', 'ig_node'] :
      return('gradient')
    return('baseline')



df['type'] = df.apply(lambda row: explainer_type(row), axis=1)
df["1-fidelity_acc-"] = 1- df["fidelity_acc-"]
df["1-fidelity_prob-"] = 1- df["fidelity_prob-"]

# %%
df = df.reset_index()
df
# Out:
#    dataset explainer_name  num_test_nodes  gpu  f1_score_top  recall_top  \
# 0     syn1       distance           200.0  1.0      0.698606    0.686667
# 1     syn1   gnnexplainer           200.0  1.0      0.328182    0.320000
# 2     syn1        ig_node           200.0  1.0      0.438333    0.438333
# 3     syn1      occlusion           200.0  1.0      0.054167    0.054167
# 4     syn1       pagerank           200.0  1.0      0.868333    0.868333
# 5     syn1   pgmexplainer           200.0  1.0      0.568561    0.568333
# 6     syn1         random           200.0  1.0      0.002500    0.002500
# 7     syn1        sa_node           200.0  1.0      0.018788    0.018333
# 8     syn1      subgraphx           200.0  1.0      0.680818    0.642500
# 9     syn3       distance           200.0  1.0      0.722813    0.711250
# 10    syn3   gnnexplainer           200.0  1.0      0.610890    0.582083
# 11    syn3        ig_node           200.0  1.0      0.000000    0.000000
# 12    syn3      occlusion           200.0  1.0      0.332303    0.320833
# 13    syn3       pagerank           200.0  1.0      0.935674    0.933750
# 14    syn3   pgmexplainer           200.0  1.0      0.644131    0.642917
# 15    syn3         random           200.0  1.0      0.004583    0.004583
# 16    syn3        sa_node           200.0  1.0      0.000000    0.000000
# 17    syn3      subgraphx           200.0  1.0      0.568586    0.551667
# 18    syn4       distance           200.0  1.0      0.626712    0.615000
# 19    syn4   gnnexplainer           200.0  1.0      0.603697    0.588333
# 20    syn4        ig_node           200.0  1.0      0.858530    0.855000
# 21    syn4      occlusion           200.0  1.0      0.607121    0.605000
# 22    syn4       pagerank           200.0  1.0      0.839167    0.839167
# 23    syn4   pgmexplainer           200.0  1.0      0.934667    0.913333
# 24    syn4         random           200.0  1.0      0.006667    0.006667
# 25    syn4        sa_node           200.0  1.0      0.142727    0.140833
# 26    syn4      subgraphx           200.0  1.0      0.570909    0.549167
# 27    syn5       distance           200.0  1.0      0.674812    0.658333
# 28    syn5   gnnexplainer           200.0  1.0      0.621695    0.595417
# 29    syn5        ig_node           200.0  1.0      0.806736    0.797917
# 30    syn5      occlusion           200.0  1.0      0.277803    0.276667
# 31    syn5       pagerank           200.0  1.0      0.853287    0.851667
# 32    syn5   pgmexplainer           200.0  1.0      0.831922    0.822500
# 33    syn5         random           200.0  1.0      0.009583    0.009583
# 34    syn5        sa_node           200.0  1.0      0.835983    0.832083
# 35    syn5      subgraphx           200.0  1.0      0.486891    0.472917
# 36    syn6       distance           200.0  1.0      0.724667    0.724000
# 37    syn6   gnnexplainer           200.0  1.0      0.204222    0.204000
# 38    syn6        ig_node           200.0  1.0      0.199222    0.198000
# 39    syn6      occlusion           200.0  1.0      0.023000    0.023000
# 40    syn6       pagerank           200.0  1.0      0.663556    0.599000
# 41    syn6   pgmexplainer           200.0  1.0      0.381333    0.363000
# 42    syn6         random           200.0  1.0      0.006000    0.006000
# 43    syn6        sa_node           200.0  1.0      0.113222    0.109000
# 44    syn6      subgraphx           200.0  1.0      0.679333    0.655000
#
#     precision_top  ged  auc_top  f1_score  ...  fidelity_prob-  mask_sparsity  \
# 0        0.713333 -1.0     -1.0  0.005823  ...        0.000000       0.010618
# 1        0.338000 -1.0     -1.0  0.447901  ...        0.000000       0.926178
# 2        0.438333 -1.0     -1.0  0.007163  ...        0.252697       0.040309
# 3        0.054167 -1.0     -1.0  0.005822  ...       -0.096364       0.000243
# 4        0.868333 -1.0     -1.0  0.005825  ...        0.000000       0.000487
# 5        0.568833 -1.0     -1.0  0.164252  ...       -0.000051       0.802185
# 6        0.002500 -1.0     -1.0  0.005822  ...       -0.000157       0.000243
# 7        0.019333 -1.0     -1.0  0.004854  ...        0.276523       0.000487
# 8        0.727750 -1.0     -1.0  0.774763  ...        0.123255       0.927438
# 9        0.736154 -1.0     -1.0  0.009405  ...        0.000000       0.008171
# 10       0.645116 -1.0     -1.0  0.751120  ...        0.000000       0.974732
# 11       0.000000 -1.0     -1.0  0.008523  ...       -0.000543       0.000459
# 12       0.345841 -1.0     -1.0  0.064492  ...       -0.000653       0.069017
# 13       0.937962 -1.0     -1.0  0.009410  ...        0.000000       0.000604
# 14       0.645667 -1.0     -1.0  0.536775  ...       -0.000014       0.932626
# 15       0.004583 -1.0     -1.0  0.009404  ...       -0.000003       0.000197
# 16       0.000000 -1.0     -1.0  0.008136  ...       -0.000251       0.000640
# 17       0.590130 -1.0     -1.0  0.713287  ...       -0.003268       0.976892
# 18       0.640917 -1.0     -1.0  0.012320  ...        0.000000       0.004938
# 19       0.622333 -1.0     -1.0  0.791955  ...        0.000000       0.990108
# 20       0.863167 -1.0     -1.0  0.245143  ...        0.000000       0.342707
# 21       0.609667 -1.0     -1.0  0.012320  ...        0.235554       0.001082
# 22       0.839167 -1.0     -1.0  0.012335  ...        0.000000       0.001235
# 23       0.963417 -1.0     -1.0  0.644665  ...        0.000000       0.985651
# 24       0.006667 -1.0     -1.0  0.012320  ...        0.000645       0.000517
# 25       0.145000 -1.0     -1.0  0.009900  ...        0.335663       0.001405
# 26       0.600250 -1.0     -1.0  0.711818  ...        0.947216       0.995651
# 27       0.693455 -1.0     -1.0  0.013978  ...        0.000000       0.001151
# 28       0.652467 -1.0     -1.0  0.778759  ...        0.000000       0.989689
# 29       0.817220 -1.0     -1.0  0.518986  ...        0.017587       0.748589
# 30       0.279076 -1.0     -1.0  0.013978  ...        0.000000       0.002387
# 31       0.855212 -1.0     -1.0  0.013991  ...        0.000000       0.000912
# 32       0.842795 -1.0     -1.0  0.651047  ...        0.000000       0.983340
# 33       0.009583 -1.0     -1.0  0.013978  ...        0.004491       0.000293
# 34       0.840523 -1.0     -1.0  0.651047  ...        0.000000       0.983340
# 35       0.503835 -1.0     -1.0  0.622345  ...        0.594995       0.996176
# 36       0.725500 -1.0     -1.0  0.005111  ...        0.000000       0.034868
# 37       0.204500 -1.0     -1.0  0.348225  ...        0.000000       0.943673
# 38       0.200750 -1.0     -1.0  0.004309  ...        0.386550       0.002768
# 39       0.023000 -1.0     -1.0  0.005053  ...       -0.036690       0.000280
# 40       0.744250 -1.0     -1.0  0.005056  ...        0.000000       0.000507
# 41       0.404250 -1.0     -1.0  0.053734  ...       -0.000646       0.808333
# 42       0.006000 -1.0     -1.0  0.005053  ...       -0.000354       0.000253
# 43       0.118500 -1.0     -1.0  0.003570  ...        0.047458       0.000747
# 44       0.709750 -1.0     -1.0  0.760278  ...        0.026920       0.992718
#
#     expl_edges    time  number_of_edges  mask_sparsity_init  \
# 0     4066.360  0.0171           4110.0            0.010618
# 1      303.410  5.5336           4110.0            0.926178
# 2     3944.330  0.2779           4110.0            0.040309
# 3     4109.000  0.9668           4110.0            0.000243
# 4     4108.000  0.0252           4110.0            0.000487
# 5      813.020  5.5697           4110.0            0.802185
# 6     4109.000  0.0001           4110.0            0.000243
# 7     4108.000  0.0040           4110.0            0.000487
# 8      298.230  2.2555           4110.0            0.927438
# 9     5038.490  0.0225           5080.0            0.008171
# 10     128.360  5.4594           5080.0            0.974732
# 11    5077.670  0.3112           5080.0            0.000459
# 12    4729.395  0.4339           5080.0            0.069017
# 13    5076.930  0.0308           5080.0            0.000604
# 14     342.260  8.7511           5080.0            0.932626
# 15    5079.000  0.0001           5080.0            0.000197
# 16    5076.750  0.0046           5080.0            0.000640
# 17     117.390  1.9539           5080.0            0.976892
# 18    1926.440  0.0093           1936.0            0.004938
# 19      19.150  5.5851           1936.0            0.990108
# 20    1272.520  0.2950           1936.0            0.342707
# 21    1933.905  0.0784           1936.0            0.001082
# 22    1933.610  0.0152           1936.0            0.001235
# 23      27.780  6.8016           1936.0            0.985651
# 24    1935.000  0.0000           1936.0            0.000517
# 25    1933.280  0.0057           1936.0            0.001405
# 26       8.420  0.3401           1936.0            0.995651
# 27    3406.075  0.0162           3410.0            0.001151
# 28      35.160  5.2330           3410.0            0.989689
# 29     857.310  0.3296           3410.0            0.748589
# 30    3401.860  0.1609           3410.0            0.002387
# 31    3406.890  0.0219           3410.0            0.000912
# 32      56.810  9.6800           3410.0            0.983340
# 33    3409.000  0.0001           3410.0            0.000293
# 34      56.810  0.0062           3410.0            0.983340
# 35      13.040  3.6071           3410.0            0.996176
# 36    3810.340  0.0176           3948.0            0.034868
# 37     222.380  5.4235           3948.0            0.943673
# 38    3937.070  0.2812           3948.0            0.002768
# 39    3946.895  0.6272           3948.0            0.000280
# 40    3946.000  0.0234           3948.0            0.000507
# 41     756.700  5.2963           3948.0            0.808333
# 42    3947.000  0.0001           3948.0            0.000253
# 43    3945.050  0.0055           3948.0            0.000747
# 44      28.750  3.8347           3948.0            0.992718
#
#     non_zero_values_init         type  1-fidelity_acc-  1-fidelity_prob-
# 0               4066.360     baseline            1.000          1.000000
# 1                303.410  pertubation            1.000          1.000000
# 2               3944.330     gradient            0.760          0.747303
# 3               4109.000  pertubation            1.000          1.096364
# 4               4108.000     baseline            1.000          1.000000
# 5                813.020  pertubation            1.000          1.000051
# 6               4109.000     baseline            1.000          1.000157
# 7               4108.000     gradient            0.705          0.723477
# 8                 10.530  pertubation            0.770          0.876745
# 9               5038.490     baseline            1.000          1.000000
# 10               128.360  pertubation            1.000          1.000000
# 11              5077.670     gradient            1.000          1.000543
# 12              4729.395  pertubation            1.000          1.000653
# 13              5076.930     baseline            1.000          1.000000
# 14               342.260  pertubation            1.000          1.000014
# 15              5079.000     baseline            1.000          1.000003
# 16              5076.750     gradient            1.000          1.000251
# 17                15.790  pertubation            1.000          1.003268
# 18              1926.440     baseline            1.000          1.000000
# 19                19.150  pertubation            1.000          1.000000
# 20              1272.520     gradient            1.000          1.000000
# 21              1933.905  pertubation            0.760          0.764446
# 22              1933.610     baseline            1.000          1.000000
# 23                27.780  pertubation            1.000          1.000000
# 24              1935.000     baseline            1.000          0.999355
# 25              1933.280     gradient            0.655          0.664337
# 26                 8.420  pertubation            0.000          0.052784
# 27              3406.075     baseline            1.000          1.000000
# 28                35.160  pertubation            1.000          1.000000
# 29               857.310     gradient            0.970          0.982413
# 30              3401.860  pertubation            1.000          1.000000
# 31              3406.890     baseline            1.000          1.000000
# 32                56.810  pertubation            1.000          1.000000
# 33              3409.000     baseline            0.995          0.995509
# 34                56.810     gradient            1.000          1.000000
# 35                13.040  pertubation            0.225          0.405005
# 36              3810.340     baseline            1.000          1.000000
# 37               222.380  pertubation            1.000          1.000000
# 38              3937.070     gradient            0.545          0.613450
# 39              3946.895  pertubation            0.995          1.036690
# 40              3946.000     baseline            1.000          1.000000
# 41               756.700  pertubation            1.000          1.000646
# 42              3947.000     baseline            1.000          1.000354
# 43              3945.050     gradient            0.970          0.952542
# 44                 9.010  pertubation            0.980          0.973080
#
# [45 rows x 26 columns]

# %%
sns.relplot(
    data=df[df.dataset.isin(["syn1", "syn3", "syn4"])],
    x="precision_top", y="recall_top", col = 'dataset',
    hue="explainer_name", size="time", sizes=(50, 300), style="type"
)

# %%
sns.relplot(
    data=df[df.dataset.isin(["syn5", "syn6"])],
    x="precision_top", y="recall_top", col = 'dataset',
    hue="explainer_name", size="time", sizes=(50, 300), style="type"
)

# %%
df_top = pd.pivot_table(df, values='f1_score_top', index=['explainer_name'], columns='dataset')
df_top['mean_acc_top'] = df_top.mean(axis=1)
df_top.sort_values(by=['mean_acc_top'])
# Out:
# dataset             syn1      syn3      syn4      syn5      syn6  mean_acc_top
# explainer_name
# random          0.002500  0.004583  0.006667  0.009583  0.006000      0.005867
# sa_node         0.018788  0.000000  0.142727  0.835983  0.113222      0.222144
# occlusion       0.054167  0.332303  0.607121  0.277803  0.023000      0.258879
# ig_node         0.438333  0.000000  0.858530  0.806736  0.199222      0.460564
# gnnexplainer    0.328182  0.610890  0.603697  0.621695  0.204222      0.473737
# subgraphx       0.680818  0.568586  0.570909  0.486891  0.679333      0.597308
# pgmexplainer    0.568561  0.644131  0.934667  0.831922  0.381333      0.672123
# distance        0.698606  0.722813  0.626712  0.674812  0.724667      0.689522
# pagerank        0.868333  0.935674  0.839167  0.853287  0.663556      0.832003
