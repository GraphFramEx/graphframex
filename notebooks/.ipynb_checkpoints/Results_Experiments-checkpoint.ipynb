# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import seaborn as sns
from matplotlib import axes
import pandas as pd
import os
from os.path import join
import json

# %%
import sys, os
sys.path.append('/cluster/home/kamara/Explain')
from clutils.nbutils import *
os.getcwd()
# Out:
# '/cluster/home/kamara/Explain/notebooks'

# %%
def parseLogs(logfile, kw="rawlogs:", **kwargs):
    logs = {}
    dicts = []
    with open(logfile) as f:
        for i_line, line in enumerate(f):
            pos = line.find(kw)
            if pos >= 0:
                pos += len(kw)
                pos_tensor = line.find("tensor(")
                while pos_tensor >= 0:
                    comma_end = line.find(",", pos_tensor)
                    tensor_end = line.find(")", pos_tensor)
                    line_new = line[:pos_tensor] + line[pos_tensor + len("tensor("):comma_end] + line[tensor_end+1:]
                    print("LINE", line)
                    print("NEW", line_new)
                    if len(line_new) >= len(line):
                        print("No line reduction")
                        break
                    line = line_new
                    pos_tensor = line.find("tensor(")
                    
                #print(ast.literal_eval(line[pos:]))
                #line[pos:] = line[pos:].replace("'", "")
                kline = line[pos:]
                kline = kline.replace("true", "True")
                try:
                    dic = ast.literal_eval(kline)
                except:
                    # print("Encountering weird patterns in logs")
                    # print("Line number %d" % i_line)
                    # print(line)
                    line = line.replace("nan,", "-1e8,")
                    line = line.replace("NaN", "-1e8")
                    try:
                        dic = ast.literal_eval(line[pos:])
                    except:
                        print("Unable to replace NaNs")
                        print(line)
                        continue
                for k in dic.keys():
                    if k not in logs:
                        logs[k] = []
                    logs[k].append(dic[k])
                dicts.append(dic)

    df = pd.DataFrame(dicts)

    return logs, df

# %%
def get_info(logdir):
    infos, fidelity, initial_mask_infos, transformed_mask_infos = {}, {}, {}, {}
    for filename in os.listdir(logdir):
        if filename.endswith(".stdout") and filename.startswith("_"):
            _, infos[filename.replace(".stdout", "")] = parseLogs(join(logdir, filename), kw='__infos:')
            _, initial_mask_infos[filename.replace(".stdout", "")] = parseLogs(join(logdir, filename), kw='__initial_edge_mask_infos:')
            _, transformed_mask_infos[filename.replace(".stdout", "")] = parseLogs(join(logdir, filename), kw='__transformed_mask_infos:')
            _, fidelity[filename.replace(".stdout", "")] = parseLogs(join(logdir, filename), kw='__fidelity:')             
    return(infos, initial_mask_infos, transformed_mask_infos, fidelity)


def get_gnn_info(logdir):
    gnn_train, gnn_test = {}, {}
    for filename in os.listdir(logdir):
        if filename.endswith(".stdout") and filename.startswith("_"):
            _, gnn_train[filename.replace(".stdout", "")] = parseLogs(join(logdir, filename), kw='__gnn_train_scores: ')
            _, gnn_test[filename.replace(".stdout", "")] = parseLogs(join(logdir, filename), kw='__gnn_test_scores: ')
    return(gnn_train, gnn_test)


def get_param_ranges(jsonpath, dataset = ""):
    f = open(jsonpath,)
    data = json.load(f)
    ranges = data['params']
    ranges['none'] = ''
    return(ranges)

# %%
def get_df_results(logs, ranges, name, metrics, selection = 'last'):
    dicts = []
    for params_set in enumerateParams(ranges):
        key = name.format(**params_set)
        # if key in logs and len(logs[key]) >= 1 and metric in logs[key]:
        any_metric = (key in logs) and (len(logs[key]) >= 1) and any([metric in logs[key] for metric in metrics])
        if any_metric:
            if selection == 'all':
                for index, row in logs[key].iterrows():
                    metrics_dict = {
                        metric: select_value(row.to_frame().T, metric, 'last') if key in logs and len(logs[key]) >= 1 and metric in logs[key] else -1
                        for metric in metrics
                    }
                    dicts.append(dictmerge(params_set, metrics_dict))
                    
            else:
                metrics_dict = {
                    metric: select_value(logs[key], metric, selection) if key in logs and len(logs[key]) >= 1 and metric in logs[key] else -1
                    for metric in metrics
                }
                dicts.append(dictmerge(params_set, metrics_dict))

    df = pd.DataFrame(dicts)
    #df = df.drop(columns=['none'])
    return df

# %% [markdown]
# ## Node Classification - Real world

# %% [markdown]
# ### Sparsity

# %%
logdir = f'/cluster/scratch/kamara/checkpoints/node_classification/real/sparsity_real_avg10expe/logs'
jsonpath = f'/cluster/home/kamara/Explain/configs/config_real_sparsity_avg10expe.json'
infos, initial_mask_infos, transformed_mask_infos, fidelity = get_info(logdir)
gnn_train, gnn_test = get_gnn_info(logdir)

print(list(fidelity.keys())[1])
ranges = get_param_ranges(jsonpath)
# Out:
# _explainer_name=random_sparsity=0_dataset=pubmed_true_label_as_target=True_hard_mask=True_seed=7

# %%
#name = '{none}_explainer_name={explainer_name}_sparsity={sparsity}_dataset={dataset}_true_label_as_target={true_label_as_target}_hard_mask={hard_mask}'
name = '{none}_explainer_name={explainer_name}_sparsity={sparsity}_dataset={dataset}_true_label_as_target={true_label_as_target}_hard_mask={hard_mask}_seed={seed}'
#name = '{none}_explainer_name={explainer_name}_sparsity={sparsity}'

# %% [markdown]
# ### GNN scores

# %%
df_gnn_train = get_df_results(gnn_train, ranges, name, metrics = ["prec", "recall", "f1_score", "acc"])
df_gnn_test = get_df_results(gnn_test, ranges, name, metrics = ["prec", "recall", "f1_score", "acc"])

df_gnn_train = df_gnn_train.groupby(by=['dataset']).mean().reset_index()
df_gnn_test = df_gnn_test.groupby(by=['dataset']).mean().reset_index()

gnn_scores = pd.merge(df_gnn_train, df_gnn_test, on=['dataset', 'sparsity', 'num_test'], suffixes=['_train', '_test'])
gnn_scores = gnn_scores.drop(columns=["sparsity", "num_test", "seed_train", "seed_test"])
gnn_scores
# Out:
#      dataset  prec_train  recall_train  acc_train  prec_test  recall_test  \
# 0      actor    0.594775      0.480935   0.538197   0.260749     0.249035
# 1  chameleon    0.817928      0.806324   0.806410   0.646635     0.634489
# 2   citeseer    1.000000      1.000000   1.000000   0.651307     0.652012
# 3       cora    1.000000      1.000000   1.000000   0.781336     0.817381
# 4    cornell    0.927170      0.908066   0.974694   0.354803     0.338859
# 5   facebook    0.931203      0.926196   0.933334   0.923301     0.917619
# 6     pubmed    1.000000      1.000000   1.000000   0.771646     0.781766
# 7      texas    0.972625      0.966848   0.991954   0.296897     0.277057
# 8  wisconsin    0.980174      0.955045   0.975833   0.397882     0.406152
#
#    acc_test
# 0  0.285942
# 1  0.632237
# 2  0.676400
# 3  0.803496
# 4  0.532487
# 5  0.926356
# 6  0.778500
# 7  0.510811
# 8  0.535294

# %%
#gnn_scores.to_csv('/cluster/home/kamara/Explain/csv/node_classification/real/nc_real_gnn_scores.csv', index=False)

# %% [markdown]
# ### Explainability methods scores

# %%
df_infos = get_df_results(infos, ranges, name, metrics = ['time', "number_of_edges", "mask_sparsity_init", "non_zero_values_init"])
df_initial_mask_infos = get_df_results(initial_mask_infos, ranges, name, metrics = ['mask_size', "mask_entropy", "max_avg"])
df_tranformed_mask_infos = get_df_results(transformed_mask_infos, ranges, name, metrics = ['mask_size', "mask_entropy", "max_avg"])
df_fid = get_df_results(fidelity, ranges, name, metrics = ['fidelity_acc+', 'fidelity_acc-', 'fidelity_prob+', 'fidelity_prob-', 
                                                           'fidelity_gnn_acc+', 'fidelity_gnn_acc-', 'fidelity_gnn_prob+', 'fidelity_gnn_prob-'])

# %%
df_mask_infos = pd.merge(df_initial_mask_infos, df_tranformed_mask_infos, suffixes=['_init', '_transf'], on=["dataset", "explainer_name", "num_test", "data_save_dir", "seed", "sparsity", "true_label_as_target", "hard_mask"])
scores = df_fid
scores = pd.merge(scores, df_mask_infos, on=["dataset", "explainer_name", "num_test", "data_save_dir", "seed", "sparsity", "true_label_as_target", "hard_mask"])
scores = pd.merge(scores, df_infos, on=["dataset", "explainer_name", "num_test", "data_save_dir", "seed", "sparsity", "true_label_as_target", "hard_mask"])
scores
#scores.to_csv('/cluster/home/kamara/Explain/csv/node_classification/real/nc_real_sparsity_all.csv', index=False)
# Out:
#       none_x explainer_name  sparsity   dataset true_label_as_target  \
# 0                    random      0.00      cora                 True
# 1                    random      0.00      cora                 True
# 2                    random      0.00      cora                 True
# 3                    random      0.00      cora                 True
# 4                    random      0.00      cora                 True
# ...      ...            ...       ...       ...                  ...
# 12327          pgmexplainer      0.99  facebook                False
# 12328          pgmexplainer      0.99  facebook                False
# 12329          pgmexplainer      0.99  facebook                False
# 12330          pgmexplainer      0.99  facebook                False
# 12331          pgmexplainer      0.99  facebook                False
#
#       hard_mask explain_graph_x  num_test  seed data_save_dir  ...  \
# 0          True           False       100     0          data  ...
# 1          True           False       100     1          data  ...
# 2          True           False       100     2          data  ...
# 3          True           False       100     3          data  ...
# 4          True           False       100     4          data  ...
# ...         ...             ...       ...   ...           ...  ...
# 12327      True           False       100     1          data  ...
# 12328      True           False       100     2          data  ...
# 12329      True           False       100     3          data  ...
# 12330      True           False       100     4          data  ...
# 12331      True           False       100     5          data  ...
#
#        explain_graph_transf  mask_size_transf  mask_entropy_transf  \
# 0                     False          13249.92             9.299591
# 1                     False          13250.48             9.299754
# 2                     False          13250.34             9.299545
# 3                     False          13249.36             9.299762
# 4                     False          13249.54             9.299681
# ...                     ...               ...                  ...
# 12327                 False           2768.48             7.475550
# 12328                 False           2392.10             7.094828
# 12329                 False           2672.38             7.429812
# 12330                 False           2674.88             7.356349
# 12331                 False           2576.30             7.368583
#
#        max_avg_transf  none_y  explain_graph_y     time  number_of_edges  \
# 0            0.428312                    False   0.0002            13264
# 1            0.490545                    False   0.0002            13264
# 2            0.498040                    False   0.0002            13264
# 3            0.489739                    False   0.0002            13264
# 4            0.470068                    False   0.0002            13264
# ...               ...     ...              ...      ...              ...
# 12327        0.516261                    False  89.3687           364116
# 12328        0.522513                    False  87.7417           364116
# 12329        0.492495                    False  91.9752           364116
# 12330        0.536693                    False  87.2857           364116
# 12331        0.537466                    False  87.4044           364116
#
#        mask_sparsity_init  non_zero_values_init
# 0                0.001062              13249.92
# 1                0.001019              13250.48
# 2                0.001030              13250.34
# 3                0.001104              13249.36
# 4                0.001090              13249.54
# ...                   ...                   ...
# 12327            0.944714              20130.39
# 12328            0.948680              18686.40
# 12329            0.957629              15427.86
# 12330            0.951040              17826.97
# 12331            0.935533              23473.47
#
# [12332 rows x 36 columns]

# %%
res = scores.groupby(by=['dataset', "true_label_as_target", "hard_mask", 'sparsity', 'explainer_name']).mean()
res = res.drop(columns=['seed'])
#res[['mask_size', "mask_entropy", "max_avg"]]
res
# Out:
#                                                                       num_test  \
# dataset   true_label_as_target hard_mask sparsity explainer_name
# actor     False                False     0.000    basic_gnnexplainer     100.0
#                                                   distance               100.0
#                                                   gnnexplainer           100.0
#                                                   gradcam                100.0
#                                                   ig                     100.0
# ...                                                                        ...
# wisconsin True                 True      0.997    gnnexplainer           100.0
#                                                   ig                     100.0
#                                                   occlusion              100.0
#                                                   pagerank               100.0
#                                                   random                 100.0
#
#                                                                       fidelity_acc+  \
# dataset   true_label_as_target hard_mask sparsity explainer_name
# actor     False                False     0.000    basic_gnnexplainer         -1.000
#                                                   distance                   -1.000
#                                                   gnnexplainer               -1.000
#                                                   gradcam                    -1.000
#                                                   ig                         -1.000
# ...                                                                             ...
# wisconsin True                 True      0.997    gnnexplainer                0.666
#                                                   ig                          0.366
#                                                   occlusion                   0.667
#                                                   pagerank                    0.290
#                                                   random                      0.228
#
#                                                                       fidelity_acc-  \
# dataset   true_label_as_target hard_mask sparsity explainer_name
# actor     False                False     0.000    basic_gnnexplainer         -1.000
#                                                   distance                   -1.000
#                                                   gnnexplainer               -1.000
#                                                   gradcam                    -1.000
#                                                   ig                         -1.000
# ...                                                                             ...
# wisconsin True                 True      0.997    gnnexplainer                0.458
#                                                   ig                          0.063
#                                                   occlusion                   0.205
#                                                   pagerank                    0.077
#                                                   random                      0.804
#
#                                                                       fidelity_prob+  \
# dataset   true_label_as_target hard_mask sparsity explainer_name
# actor     False                False     0.000    basic_gnnexplainer       -1.000000
#                                                   distance                 -1.000000
#                                                   gnnexplainer             -1.000000
#                                                   gradcam                  -1.000000
#                                                   ig                       -1.000000
# ...                                                                              ...
# wisconsin True                 True      0.997    gnnexplainer              0.545173
#                                                   ig                        0.246022
#                                                   occlusion                 0.545069
#                                                   pagerank                  0.171710
#                                                   random                    0.096575
#
#                                                                       fidelity_prob-  \
# dataset   true_label_as_target hard_mask sparsity explainer_name
# actor     False                False     0.000    basic_gnnexplainer       -1.000000
#                                                   distance                 -1.000000
#                                                   gnnexplainer             -1.000000
#                                                   gradcam                  -1.000000
#                                                   ig                       -1.000000
# ...                                                                              ...
# wisconsin True                 True      0.997    gnnexplainer              0.308689
#                                                   ig                       -0.068371
#                                                   occlusion                 0.080260
#                                                   pagerank                 -0.056536
#                                                   random                    0.666690
#
#                                                                       fidelity_gnn_acc+  \
# dataset   true_label_as_target hard_mask sparsity explainer_name
# actor     False                False     0.000    basic_gnnexplainer              0.722
#                                                   distance                        0.820
#                                                   gnnexplainer                    0.836
#                                                   gradcam                         0.770
#                                                   ig                              0.828
# ...                                                                                 ...
# wisconsin True                 True      0.997    gnnexplainer                   -1.000
#                                                   ig                             -1.000
#                                                   occlusion                      -1.000
#                                                   pagerank                       -1.000
#                                                   random                         -1.000
#
#                                                                       fidelity_gnn_acc-  \
# dataset   true_label_as_target hard_mask sparsity explainer_name
# actor     False                False     0.000    basic_gnnexplainer              0.312
#                                                   distance                        0.687
#                                                   gnnexplainer                    0.753
#                                                   gradcam                         0.693
#                                                   ig                              0.640
# ...                                                                                 ...
# wisconsin True                 True      0.997    gnnexplainer                   -1.000
#                                                   ig                             -1.000
#                                                   occlusion                      -1.000
#                                                   pagerank                       -1.000
#                                                   random                         -1.000
#
#                                                                       fidelity_gnn_prob+  \
# dataset   true_label_as_target hard_mask sparsity explainer_name
# actor     False                False     0.000    basic_gnnexplainer            0.150069
#                                                   distance                      0.182060
#                                                   gnnexplainer                  0.178340
#                                                   gradcam                       0.174446
#                                                   ig                            0.180331
# ...                                                                                  ...
# wisconsin True                 True      0.997    gnnexplainer                 -1.000000
#                                                   ig                           -1.000000
#                                                   occlusion                    -1.000000
#                                                   pagerank                     -1.000000
#                                                   random                       -1.000000
#
#                                                                       fidelity_gnn_prob-  \
# dataset   true_label_as_target hard_mask sparsity explainer_name
# actor     False                False     0.000    basic_gnnexplainer            0.088249
#                                                   distance                      0.151183
#                                                   gnnexplainer                  0.175748
#                                                   gradcam                       0.152992
#                                                   ig                            0.140814
# ...                                                                                  ...
# wisconsin True                 True      0.997    gnnexplainer                 -1.000000
#                                                   ig                           -1.000000
#                                                   occlusion                    -1.000000
#                                                   pagerank                     -1.000000
#                                                   random                       -1.000000
#
#                                                                       mask_sparsity  \
# dataset   true_label_as_target hard_mask sparsity explainer_name
# actor     False                False     0.000    basic_gnnexplainer       0.970945
#                                                   distance                 0.000080
#                                                   gnnexplainer             0.970945
#                                                   gradcam                  0.419769
#                                                   ig                       0.030613
# ...                                                                             ...
# wisconsin True                 True      0.997    gnnexplainer             0.997393
#                                                   ig                       0.997393
#                                                   occlusion                0.997393
#                                                   pagerank                 0.997393
#                                                   random                   0.997393
#
#                                                                       ...  \
# dataset   true_label_as_target hard_mask sparsity explainer_name      ...
# actor     False                False     0.000    basic_gnnexplainer  ...
#                                                   distance            ...
#                                                   gnnexplainer        ...
#                                                   gradcam             ...
#                                                   ig                  ...
# ...                                                                   ...
# wisconsin True                 True      0.997    gnnexplainer        ...
#                                                   ig                  ...
#                                                   occlusion           ...
#                                                   pagerank            ...
#                                                   random              ...
#
#                                                                       mask_size_init  \
# dataset   true_label_as_target hard_mask sparsity explainer_name
# actor     False                False     0.000    basic_gnnexplainer        1769.996
#                                                   distance                 60913.117
#                                                   gnnexplainer              1769.996
#                                                   gradcam                  35346.504
#                                                   ig                       59053.126
# ...                                                                              ...
# wisconsin True                 True      0.997    gnnexplainer               287.783
#                                                   ig                        1120.830
#                                                   occlusion                  287.783
#                                                   pagerank                  1087.551
#                                                   random                    1148.872
#
#                                                                       mask_entropy_init  \
# dataset   true_label_as_target hard_mask sparsity explainer_name
# actor     False                False     0.000    basic_gnnexplainer           5.684779
#                                                   distance                    10.958437
#                                                   gnnexplainer                 5.007442
#                                                   gradcam                      8.168174
#                                                   ig                          10.742004
# ...                                                                                 ...
# wisconsin True                 True      0.997    gnnexplainer                 3.921350
#                                                   ig                           6.850792
#                                                   occlusion                    5.029174
#                                                   pagerank                     5.931450
#                                                   random                       6.854129
#
#                                                                       max_avg_init  \
# dataset   true_label_as_target hard_mask sparsity explainer_name
# actor     False                False     0.000    basic_gnnexplainer      0.713987
#                                                   distance                0.117579
#                                                   gnnexplainer            0.062815
#                                                   gradcam                 0.116363
#                                                   ig                      0.185476
# ...                                                                            ...
# wisconsin True                 True      0.997    gnnexplainer            0.066819
#                                                   ig                      0.210837
#                                                   occlusion               0.727468
#                                                   pagerank                0.001056
#                                                   random                  0.446496
#
#                                                                       mask_size_transf  \
# dataset   true_label_as_target hard_mask sparsity explainer_name
# actor     False                False     0.000    basic_gnnexplainer          1769.996
#                                                   distance                   60913.117
#                                                   gnnexplainer                1769.996
#                                                   gradcam                    35346.504
#                                                   ig                         59053.126
# ...                                                                                ...
# wisconsin True                 True      0.997    gnnexplainer                   3.000
#                                                   ig                             3.000
#                                                   occlusion                      3.000
#                                                   pagerank                       3.000
#                                                   random                         3.000
#
#                                                                       mask_entropy_transf  \
# dataset   true_label_as_target hard_mask sparsity explainer_name
# actor     False                False     0.000    basic_gnnexplainer             5.684779
#                                                   distance                      10.958437
#                                                   gnnexplainer                   5.007442
#                                                   gradcam                        8.168174
#                                                   ig                            10.742004
# ...                                                                                   ...
# wisconsin True                 True      0.997    gnnexplainer                   0.774409
#                                                   ig                             1.079416
#                                                   occlusion                      1.086211
#                                                   pagerank                       1.088098
#                                                   random                         1.098612
#
#                                                                       max_avg_transf  \
# dataset   true_label_as_target hard_mask sparsity explainer_name
# actor     False                False     0.000    basic_gnnexplainer        0.713987
#                                                   distance                  0.117579
#                                                   gnnexplainer              0.062815
#                                                   gradcam                   0.116363
#                                                   ig                        0.185476
# ...                                                                              ...
# wisconsin True                 True      0.997    gnnexplainer              0.659021
#                                                   ig                        0.719721
#                                                   occlusion                 0.795199
#                                                   pagerank                  0.758350
#                                                   random                    0.998312
#
#                                                                          time  \
# dataset   true_label_as_target hard_mask sparsity explainer_name
# actor     False                False     0.000    basic_gnnexplainer  3.79272
#                                                   distance            0.74688
#                                                   gnnexplainer        3.76496
#                                                   gradcam             0.00529
#                                                   ig                  0.25437
# ...                                                                       ...
# wisconsin True                 True      0.997    gnnexplainer        3.83499
#                                                   ig                  0.13043
#                                                   occlusion           0.35526
#                                                   pagerank            0.02136
#                                                   random              0.00010
#
#                                                                       number_of_edges  \
# dataset   true_label_as_target hard_mask sparsity explainer_name
# actor     False                False     0.000    basic_gnnexplainer          60918.0
#                                                   distance                    60918.0
#                                                   gnnexplainer                60918.0
#                                                   gradcam                     60918.0
#                                                   ig                          60918.0
# ...                                                                               ...
# wisconsin True                 True      0.997    gnnexplainer                 1151.0
#                                                   ig                           1151.0
#                                                   occlusion                    1151.0
#                                                   pagerank                     1151.0
#                                                   random                       1151.0
#
#                                                                       mask_sparsity_init  \
# dataset   true_label_as_target hard_mask sparsity explainer_name
# actor     False                False     0.000    basic_gnnexplainer            0.970945
#                                                   distance                      0.000080
#                                                   gnnexplainer                  0.970945
#                                                   gradcam                       0.419769
#                                                   ig                            0.030613
# ...                                                                                  ...
# wisconsin True                 True      0.997    gnnexplainer                  0.749971
#                                                   ig                            0.026212
#                                                   occlusion                     0.749971
#                                                   pagerank                      0.055125
#                                                   random                        0.001849
#
#                                                                       non_zero_values_init
# dataset   true_label_as_target hard_mask sparsity explainer_name
# actor     False                False     0.000    basic_gnnexplainer              1769.996
#                                                   distance                       60913.117
#                                                   gnnexplainer                    1769.996
#                                                   gradcam                        35346.504
#                                                   ig                             59053.126
# ...                                                                                    ...
# wisconsin True                 True      0.997    gnnexplainer                     287.783
#                                                   ig                              1120.830
#                                                   occlusion                        287.783
#                                                   pagerank                        1087.551
#                                                   random                          1148.872
#
# [1235 rows x 21 columns]

# %%
res = res.reset_index()
res.to_csv('/cluster/home/kamara/Explain/csv/node_classification/real/nc_real_sparsity_avg10expe.csv', index=False)

# %% [markdown]
# ## Topk

# %%
logdir = f'/cluster/scratch/kamara/checkpoints/node_classification/real/topk/topk_real_1/logs'
jsonpath = f'/cluster/home/kamara/Explain/configs/real/topk/config_real_topk_1expe.json'
infos, initial_mask_infos, transformed_mask_infos, fidelity = get_info(logdir)
gnn_train, gnn_test = get_gnn_info(logdir)

print(list(fidelity.keys())[1])
ranges = get_param_ranges(jsonpath)
# Out:
# _explainer_name=pagerank_dataset=wisconsin_true_label_as_target=False_hard_mask=True

# %%
#name = '{none}_explainer_name={explainer_name}_sparsity={sparsity}_dataset={dataset}_true_label_as_target={true_label_as_target}_hard_mask={hard_mask}'
name = '{none}_explainer_name={explainer_name}_dataset={dataset}_true_label_as_target={true_label_as_target}_hard_mask={hard_mask}'

# %%
df_infos = get_df_results(infos, ranges, name, metrics = ['time', "number_of_edges"])
df_initial_mask_infos = get_df_results(initial_mask_infos, ranges, name, metrics = ['mask_size', "mask_entropy", "max_avg"])
df_tranformed_mask_infos = get_df_results(transformed_mask_infos, ranges, name, metrics = ['mask_size', "mask_entropy", "max_avg", "topk"], selection="all")
df_fid = get_df_results(fidelity, ranges, name, metrics = ['fidelity_acc+', 'fidelity_acc-', 'fidelity_prob+', 'fidelity_prob-', 
                                                           'fidelity_gnn_acc+', 'fidelity_gnn_acc-', 'fidelity_gnn_prob+', 'fidelity_gnn_prob-', 'topk'], selection="all")

# %%
df_mask_infos = pd.merge(df_initial_mask_infos, df_tranformed_mask_infos, suffixes=['_init', '_transf'], on=["dataset", "explainer_name", "num_test", "data_save_dir", "seed", "true_label_as_target", "hard_mask"])
scores = df_fid
scores = pd.merge(scores, df_mask_infos, on=["dataset", "explainer_name", "num_test", "data_save_dir", "seed", "true_label_as_target", "hard_mask", "topk"])
scores = pd.merge(scores, df_infos, on=["dataset", "explainer_name", "num_test", "data_save_dir", "seed", "true_label_as_target", "hard_mask"])
scores
#scores.to_csv('/cluster/home/kamara/Explain/csv/node_classification/real/nc_real_sparsity_all.csv', index=False)
# Out:
#      none_x explainer_name    dataset             topk_list_x  \
# 0                   random       cora  1,5,10,15,20,25,50,100
# 1                   random       cora  1,5,10,15,20,25,50,100
# 2                   random       cora  1,5,10,15,20,25,50,100
# 3                   random       cora  1,5,10,15,20,25,50,100
# 4                   random       cora  1,5,10,15,20,25,50,100
# ...     ...            ...        ...                     ...
# 2464          pgmexplainer  wisconsin  1,5,10,15,20,25,50,100
# 2465          pgmexplainer  wisconsin  1,5,10,15,20,25,50,100
# 2466          pgmexplainer  wisconsin  1,5,10,15,20,25,50,100
# 2467          pgmexplainer  wisconsin  1,5,10,15,20,25,50,100
# 2468          pgmexplainer  wisconsin  1,5,10,15,20,25,50,100
#
#      true_label_as_target hard_mask explain_graph_x  num_test  seed  \
# 0                    True      True           False       100     0
# 1                    True      True           False       100     0
# 2                    True      True           False       100     0
# 3                    True      True           False       100     0
# 4                    True      True           False       100     0
# ...                   ...       ...             ...       ...   ...
# 2464                False     False           False       100     0
# 2465                False     False           False       100     0
# 2466                False     False           False       100     0
# 2467                False     False           False       100     0
# 2468                False     False           False       100     0
#
#      data_save_dir  ...        topk_list_transf  explain_graph_transf  \
# 0             data  ...  1,5,10,15,20,25,50,100                 False
# 1             data  ...  1,5,10,15,20,25,50,100                 False
# 2             data  ...  1,5,10,15,20,25,50,100                 False
# 3             data  ...  1,5,10,15,20,25,50,100                 False
# 4             data  ...  1,5,10,15,20,25,50,100                 False
# ...            ...  ...                     ...                   ...
# 2464          data  ...  1,5,10,15,20,25,50,100                 False
# 2465          data  ...  1,5,10,15,20,25,50,100                 False
# 2466          data  ...  1,5,10,15,20,25,50,100                 False
# 2467          data  ...  1,5,10,15,20,25,50,100                 False
# 2468          data  ...  1,5,10,15,20,25,50,100                 False
#
#       mask_size_transf  mask_entropy_transf  max_avg_transf  none_y  \
# 0                 1.00             0.000000        1.000000
# 1                 5.00             1.609438        0.999720
# 2                10.00             2.302585        0.999468
# 3                15.00             2.708050        0.999279
# 4                20.00             2.995732        0.999034
# ...                ...                  ...             ...     ...
# 2464             15.00             2.694923        0.836447
# 2465             19.98             2.979302        0.810814
# 2466             24.82             3.193790        0.798190
# 2467             48.76             3.847085        0.689827
# 2468             95.11             4.465277        0.574972
#
#                  topk_list_y  explain_graph_y    time number_of_edges
# 0     1,5,10,15,20,25,50,100            False  0.0002           13264
# 1     1,5,10,15,20,25,50,100            False  0.0002           13264
# 2     1,5,10,15,20,25,50,100            False  0.0002           13264
# 3     1,5,10,15,20,25,50,100            False  0.0002           13264
# 4     1,5,10,15,20,25,50,100            False  0.0002           13264
# ...                      ...              ...     ...             ...
# 2464  1,5,10,15,20,25,50,100            False  2.4069            1151
# 2465  1,5,10,15,20,25,50,100            False  2.4069            1151
# 2466  1,5,10,15,20,25,50,100            False  2.4069            1151
# 2467  1,5,10,15,20,25,50,100            False  2.4069            1151
# 2468  1,5,10,15,20,25,50,100            False  2.4069            1151
#
# [2469 rows x 36 columns]

# %%
res = scores.groupby(by=['dataset', "true_label_as_target", "hard_mask", 'topk', 'explainer_name']).mean()
res = res.drop(columns=['seed'])
#res[['mask_size', "mask_entropy", "max_avg"]]
res
# Out:
#                                                                    num_test  \
# dataset   true_label_as_target hard_mask topk  explainer_name
# actor     False                False     1.0   basic_gnnexplainer     100.0
#                                                distance               100.0
#                                                gnnexplainer           100.0
#                                                gradcam                100.0
#                                                occlusion              100.0
# ...                                                                     ...
# wisconsin True                 True      100.0 occlusion              100.0
#                                                pagerank               100.0
#                                                pgmexplainer           100.0
#                                                random                 100.0
#                                                sa                     100.0
#
#                                                                    fidelity_acc+  \
# dataset   true_label_as_target hard_mask topk  explainer_name
# actor     False                False     1.0   basic_gnnexplainer          -1.00
#                                                distance                    -1.00
#                                                gnnexplainer                -1.00
#                                                gradcam                     -1.00
#                                                occlusion                   -1.00
# ...                                                                          ...
# wisconsin True                 True      100.0 occlusion                    0.67
#                                                pagerank                     0.70
#                                                pgmexplainer                 0.63
#                                                random                       0.20
#                                                sa                           0.70
#
#                                                                    fidelity_acc-  \
# dataset   true_label_as_target hard_mask topk  explainer_name
# actor     False                False     1.0   basic_gnnexplainer          -1.00
#                                                distance                    -1.00
#                                                gnnexplainer                -1.00
#                                                gradcam                     -1.00
#                                                occlusion                   -1.00
# ...                                                                          ...
# wisconsin True                 True      100.0 occlusion                    0.13
#                                                pagerank                     0.09
#                                                pgmexplainer                 0.13
#                                                random                       0.55
#                                                sa                           0.45
#
#                                                                    fidelity_prob+  \
# dataset   true_label_as_target hard_mask topk  explainer_name
# actor     False                False     1.0   basic_gnnexplainer       -1.000000
#                                                distance                 -1.000000
#                                                gnnexplainer             -1.000000
#                                                gradcam                  -1.000000
#                                                occlusion                -1.000000
# ...                                                                           ...
# wisconsin True                 True      100.0 occlusion                 0.133390
#                                                pagerank                  0.117450
#                                                pgmexplainer              0.108370
#                                                random                   -0.008910
#                                                sa                        0.140986
#
#                                                                    fidelity_prob-  \
# dataset   true_label_as_target hard_mask topk  explainer_name
# actor     False                False     1.0   basic_gnnexplainer       -1.000000
#                                                distance                 -1.000000
#                                                gnnexplainer             -1.000000
#                                                gradcam                  -1.000000
#                                                occlusion                -1.000000
# ...                                                                           ...
# wisconsin True                 True      100.0 occlusion                -0.034419
#                                                pagerank                 -0.001679
#                                                pgmexplainer             -0.005719
#                                                random                    0.088731
#                                                sa                        0.066443
#
#                                                                    fidelity_gnn_acc+  \
# dataset   true_label_as_target hard_mask topk  explainer_name
# actor     False                False     1.0   basic_gnnexplainer               0.00
#                                                distance                         0.07
#                                                gnnexplainer                     0.43
#                                                gradcam                          0.16
#                                                occlusion                        0.38
# ...                                                                              ...
# wisconsin True                 True      100.0 occlusion                       -1.00
#                                                pagerank                        -1.00
#                                                pgmexplainer                    -1.00
#                                                random                          -1.00
#                                                sa                              -1.00
#
#                                                                    fidelity_gnn_acc-  \
# dataset   true_label_as_target hard_mask topk  explainer_name
# actor     False                False     1.0   basic_gnnexplainer               0.42
#                                                distance                         0.39
#                                                gnnexplainer                     0.41
#                                                gradcam                          0.38
#                                                occlusion                        0.39
# ...                                                                              ...
# wisconsin True                 True      100.0 occlusion                       -1.00
#                                                pagerank                        -1.00
#                                                pgmexplainer                    -1.00
#                                                random                          -1.00
#                                                sa                              -1.00
#
#                                                                    fidelity_gnn_prob+  \
# dataset   true_label_as_target hard_mask topk  explainer_name
# actor     False                False     1.0   basic_gnnexplainer            0.002503
#                                                distance                      0.016935
#                                                gnnexplainer                  0.074586
#                                                gradcam                       0.037296
#                                                occlusion                     0.062185
# ...                                                                               ...
# wisconsin True                 True      100.0 occlusion                    -1.000000
#                                                pagerank                     -1.000000
#                                                pgmexplainer                 -1.000000
#                                                random                       -1.000000
#                                                sa                           -1.000000
#
#                                                                    fidelity_gnn_prob-  \
# dataset   true_label_as_target hard_mask topk  explainer_name
# actor     False                False     1.0   basic_gnnexplainer            0.113221
#                                                distance                      0.106466
#                                                gnnexplainer                  0.098053
#                                                gradcam                       0.082071
#                                                occlusion                     0.083376
# ...                                                                               ...
# wisconsin True                 True      100.0 occlusion                    -1.000000
#                                                pagerank                     -1.000000
#                                                pgmexplainer                 -1.000000
#                                                random                       -1.000000
#                                                sa                           -1.000000
#
#                                                                    mask_size_init  \
# dataset   true_label_as_target hard_mask topk  explainer_name
# actor     False                False     1.0   basic_gnnexplainer         1208.43
#                                                distance                  60913.74
#                                                gnnexplainer               1208.43
#                                                gradcam                   39772.57
#                                                occlusion                  1208.25
# ...                                                                           ...
# wisconsin True                 True      100.0 occlusion                   290.10
#                                                pagerank                   1082.04
#                                                pgmexplainer                517.66
#                                                random                     1148.96
#                                                sa                          829.70
#
#                                                                    mask_entropy_init  \
# dataset   true_label_as_target hard_mask topk  explainer_name
# actor     False                False     1.0   basic_gnnexplainer           5.300966
#                                                distance                    10.960461
#                                                gnnexplainer                 4.690754
#                                                gradcam                      8.478164
#                                                occlusion                    5.610678
# ...                                                                              ...
# wisconsin True                 True      100.0 occlusion                    4.690044
#                                                pagerank                     5.922828
#                                                pgmexplainer                 5.756787
#                                                random                       6.853682
#                                                sa                           6.272720
#
#                                                                    max_avg_init  \
# dataset   true_label_as_target hard_mask topk  explainer_name
# actor     False                False     1.0   basic_gnnexplainer      0.696889
#                                                distance                0.110511
#                                                gnnexplainer            0.051125
#                                                gradcam                 0.149737
#                                                occlusion               0.479297
# ...                                                                         ...
# wisconsin True                 True      100.0 occlusion               0.418526
#                                                pagerank                0.001028
#                                                pgmexplainer            0.298066
#                                                random                  0.490891
#                                                sa                      0.566140
#
#                                                                    mask_size_transf  \
# dataset   true_label_as_target hard_mask topk  explainer_name
# actor     False                False     1.0   basic_gnnexplainer              1.00
#                                                distance                        1.00
#                                                gnnexplainer                    1.00
#                                                gradcam                         1.00
#                                                occlusion                       1.00
# ...                                                                             ...
# wisconsin True                 True      100.0 occlusion                      78.65
#                                                pagerank                      100.00
#                                                pgmexplainer                   95.11
#                                                random                        100.00
#                                                sa                             99.23
#
#                                                                    mask_entropy_transf  \
# dataset   true_label_as_target hard_mask topk  explainer_name
# actor     False                False     1.0   basic_gnnexplainer             0.000000
#                                                distance                       0.000000
#                                                gnnexplainer                   0.000000
#                                                gradcam                        0.000000
#                                                occlusion                      0.000000
# ...                                                                                ...
# wisconsin True                 True      100.0 occlusion                      3.744467
#                                                pagerank                       4.446748
#                                                pgmexplainer                   4.465948
#                                                random                         4.604816
#                                                sa                             4.504462
#
#                                                                    max_avg_transf  \
# dataset   true_label_as_target hard_mask topk  explainer_name
# actor     False                False     1.0   basic_gnnexplainer        1.000000
#                                                distance                  1.000000
#                                                gnnexplainer              1.000000
#                                                gradcam                   1.000000
#                                                occlusion                 1.000000
# ...                                                                           ...
# wisconsin True                 True      100.0 occlusion                 0.420155
#                                                pagerank                  0.206235
#                                                pgmexplainer              0.550145
#                                                random                    0.943692
#                                                sa                        0.643644
#
#                                                                      time  \
# dataset   true_label_as_target hard_mask topk  explainer_name
# actor     False                False     1.0   basic_gnnexplainer  3.8270
#                                                distance            0.8971
#                                                gnnexplainer        7.4523
#                                                gradcam             0.0079
#                                                occlusion           3.3738
# ...                                                                   ...
# wisconsin True                 True      100.0 occlusion           0.6651
#                                                pagerank            0.0262
#                                                pgmexplainer        2.5542
#                                                random              0.0001
#                                                sa                  0.0048
#
#                                                                    number_of_edges
# dataset   true_label_as_target hard_mask topk  explainer_name
# actor     False                False     1.0   basic_gnnexplainer          60918.0
#                                                distance                    60918.0
#                                                gnnexplainer                60918.0
#                                                gradcam                     60918.0
#                                                occlusion                   60918.0
# ...                                                                            ...
# wisconsin True                 True      100.0 occlusion                    1151.0
#                                                pagerank                     1151.0
#                                                pgmexplainer                 1151.0
#                                                random                       1151.0
#                                                sa                           1151.0
#
# [2469 rows x 17 columns]

# %%
res = res.reset_index()
res.to_csv('/cluster/home/kamara/Explain/csv/node_classification/real/topk/nc_real_topk_1expe.csv', index=False)

# %% [markdown]
# ## Node Classification - Real world - 10 seeds

# %%
datasets = [
      "cora",
      "pubmed",
      "citeseer",
      "cornell",
      "texas",
      "wisconsin",
      "actor",
      "chameleon",
    "squirrel",
    "facebook"
    ]

# %% [markdown]
# ### Sparsity

# %%
#name = '{none}_explainer_name={explainer_name}_sparsity={sparsity}_dataset={dataset}_true_label_as_target={true_label_as_target}_hard_mask={hard_mask}'
#name = '{none}_explainer_name={explainer_name}_sparsity={sparsity}_dataset={dataset}_true_label_as_target={true_label_as_target}_hard_mask={hard_mask}_seed={seed}'
name = '{none}_explainer_name={explainer_name}_sparsity={sparsity}_true_label_as_target={true_label_as_target}_hard_mask={hard_mask}_seed={seed}'
#name = '{none}_explainer_name={explainer_name}_sparsity={sparsity}'

# %%
SCORES = []
for data in datasets:

    logdir = f'/cluster/home/kamara/checkpoints/node_classification/real/sparsity_real_avg10expe_{data}/logs'
    jsonpath = f'/cluster/home/kamara/Explain/configs/config_real_sparsity_avg10expe_{data}.json'
    ranges = get_param_ranges(jsonpath)
    infos, initial_mask_infos, transformed_mask_infos, fidelity = get_info(logdir)
    
    df_infos = get_df_results(infos, ranges, name, metrics = ['dataset', 'time', "number_of_edges", "mask_sparsity_init", "non_zero_values_init"])
    print(df_infos)
    df_initial_mask_infos = get_df_results(initial_mask_infos, ranges, name, metrics = ['mask_size', "mask_entropy", "max_avg"])
    df_tranformed_mask_infos = get_df_results(transformed_mask_infos, ranges, name, metrics = ['mask_size', "mask_entropy", "max_avg"])
    df_fid = get_df_results(fidelity, ranges, name, metrics = ['fidelity_acc+', 'fidelity_acc-', 'fidelity_prob+', 'fidelity_prob-', 
                                                           'fidelity_gnn_acc+', 'fidelity_gnn_acc-', 'fidelity_gnn_prob+', 'fidelity_gnn_prob-',
                                                           'mask_sparsity', 'expl_edges'])
    
    df_mask_infos = pd.merge(df_initial_mask_infos, df_tranformed_mask_infos, suffixes=['_init', '_transf'], on=["dataset", "explainer_name", "num_test", "data_save_dir", "seed", "sparsity", "true_label_as_target", "hard_mask"])
    scores = df_fid
    scores = pd.merge(scores, df_mask_infos, on=["explainer_name", "num_test", "data_save_dir", "seed", "sparsity", "true_label_as_target", "hard_mask"])
    scores = pd.merge(scores, df_infos, on=["explainer_name", "num_test", "data_save_dir", "seed", "sparsity", "true_label_as_target", "hard_mask"])
    res = scores.groupby(by=['dataset', "true_label_as_target", "hard_mask", 'sparsity', 'explainer_name']).mean()
    res = res.drop(columns=['seed'])
    print('res', res)

    SCORES.append(res)
    print(SCORES)
# Out:
#      none explainer_name  sparsity dataset true_label_as_target hard_mask  \
# 0                 random     0.000    cora                 True      True
# 1                 random     0.000    cora                 True      True
# 2                 random     0.000    cora                 True      True
# 3                 random     0.000    cora                 True      True
# 4                 random     0.000    cora                 True      True
# ...   ...            ...       ...     ...                  ...       ...
# 1595        pgmexplainer     0.997    cora                False     False
# 1596        pgmexplainer     0.997    cora                False     False
# 1597        pgmexplainer     0.997    cora                False     False
# 1598        pgmexplainer     0.997    cora                False     False
# 1599        pgmexplainer     0.997    cora                False     False
#
#      explain_graph  num_test  seed data_save_dir     time  number_of_edges  \
# 0            False       100     0          data   0.0002            13264
# 1            False       100     1          data   0.0002            13264
# 2            False       100     2          data   0.0002            13264
# 3            False       100     3          data   0.0002            13264
# 4            False       100     4          data   0.0002            13264
# ...            ...       ...   ...           ...      ...              ...
# 1595         False       100     5          data  11.8607            13264
# 1596         False       100     6          data  11.6665            13264
# 1597         False       100     7          data  11.6375            13264
# 1598         False       100     8          data  11.6613            13264
# 1599         False       100     9          data  11.3518            13264
#
#       mask_sparsity_init  non_zero_values_init
# 0               0.001062              13249.92
# 1               0.001019              13250.48
# 2               0.001030              13250.34
# 3               0.001104              13249.36
# 4               0.001090              13249.54
# ...                  ...                   ...
# 1595            0.972170                369.14
# 1596            0.970847                386.68
# 1597            0.972916                359.24
# 1598            0.971211                381.86
# 1599            0.964439                471.68
#
# [1600 rows x 14 columns]
# res                                                                     num_test  \
# dataset true_label_as_target hard_mask sparsity explainer_name
# cora    False                False     0.000    basic_gnnexplainer     100.0
#                                                 distance               100.0
#                                                 gnnexplainer           100.0
#                                                 gradcam                100.0
#                                                 ig                     100.0
# ...                                                                      ...
#         True                 True      0.997    occlusion              100.0
#                                                 pagerank               100.0
#                                                 pgmexplainer           100.0
#                                                 random                 100.0
#                                                 sa                     100.0
#
#                                                                     fidelity_acc+  \
# dataset true_label_as_target hard_mask sparsity explainer_name
# cora    False                False     0.000    basic_gnnexplainer         -1.000
#                                                 distance                   -1.000
#                                                 gnnexplainer               -1.000
#                                                 gradcam                    -1.000
#                                                 ig                         -1.000
# ...                                                                           ...
#         True                 True      0.997    occlusion                   0.897
#                                                 pagerank                    0.879
#                                                 pgmexplainer                0.625
#                                                 random                      0.073
#                                                 sa                          0.745
#
#                                                                     fidelity_acc-  \
# dataset true_label_as_target hard_mask sparsity explainer_name
# cora    False                False     0.000    basic_gnnexplainer         -1.000
#                                                 distance                   -1.000
#                                                 gnnexplainer               -1.000
#                                                 gradcam                    -1.000
#                                                 ig                         -1.000
# ...                                                                           ...
#         True                 True      0.997    occlusion                   0.011
#                                                 pagerank                    0.035
#                                                 pgmexplainer                0.052
#                                                 random                      0.884
#                                                 sa                          0.148
#
#                                                                     fidelity_prob+  \
# dataset true_label_as_target hard_mask sparsity explainer_name
# cora    False                False     0.000    basic_gnnexplainer       -1.000000
#                                                 distance                 -1.000000
#                                                 gnnexplainer             -1.000000
#                                                 gradcam                  -1.000000
#                                                 ig                       -1.000000
# ...                                                                            ...
#         True                 True      0.997    occlusion                 0.791508
#                                                 pagerank                  0.766729
#                                                 pgmexplainer              0.521140
#                                                 random                   -0.009590
#                                                 sa                        0.634229
#
#                                                                     fidelity_prob-  \
# dataset true_label_as_target hard_mask sparsity explainer_name
# cora    False                False     0.000    basic_gnnexplainer       -1.000000
#                                                 distance                 -1.000000
#                                                 gnnexplainer             -1.000000
#                                                 gradcam                  -1.000000
#                                                 ig                       -1.000000
# ...                                                                            ...
#         True                 True      0.997    occlusion                -0.072082
#                                                 pagerank                 -0.047175
#                                                 pgmexplainer             -0.031500
#                                                 random                    0.771632
#                                                 sa                        0.062011
#
#                                                                     fidelity_gnn_acc+  \
# dataset true_label_as_target hard_mask sparsity explainer_name
# cora    False                False     0.000    basic_gnnexplainer              0.376
#                                                 distance                        0.162
#                                                 gnnexplainer                    0.493
#                                                 gradcam                         0.215
#                                                 ig                              0.337
# ...                                                                               ...
#         True                 True      0.997    occlusion                      -1.000
#                                                 pagerank                       -1.000
#                                                 pgmexplainer                   -1.000
#                                                 random                         -1.000
#                                                 sa                             -1.000
#
#                                                                     fidelity_gnn_acc-  \
# dataset true_label_as_target hard_mask sparsity explainer_name
# cora    False                False     0.000    basic_gnnexplainer              0.379
#                                                 distance                        0.068
#                                                 gnnexplainer                    0.373
#                                                 gradcam                         0.036
#                                                 ig                              0.031
# ...                                                                               ...
#         True                 True      0.997    occlusion                      -1.000
#                                                 pagerank                       -1.000
#                                                 pgmexplainer                   -1.000
#                                                 random                         -1.000
#                                                 sa                             -1.000
#
#                                                                     fidelity_gnn_prob+  \
# dataset true_label_as_target hard_mask sparsity explainer_name
# cora    False                False     0.000    basic_gnnexplainer            0.384231
#                                                 distance                      0.539109
#                                                 gnnexplainer                  0.541627
#                                                 gradcam                       0.498248
#                                                 ig                            0.556903
# ...                                                                                ...
#         True                 True      0.997    occlusion                    -1.000000
#                                                 pagerank                     -1.000000
#                                                 pgmexplainer                 -1.000000
#                                                 random                       -1.000000
#                                                 sa                           -1.000000
#
#                                                                     fidelity_gnn_prob-  \
# dataset true_label_as_target hard_mask sparsity explainer_name
# cora    False                False     0.000    basic_gnnexplainer            0.413214
#                                                 distance                      0.311883
#                                                 gnnexplainer                  0.601882
#                                                 gradcam                       0.365465
#                                                 ig                            0.264937
# ...                                                                                ...
#         True                 True      0.997    occlusion                    -1.000000
#                                                 pagerank                     -1.000000
#                                                 pgmexplainer                 -1.000000
#                                                 random                       -1.000000
#                                                 sa                           -1.000000
#
#                                                                     mask_sparsity  \
# dataset true_label_as_target hard_mask sparsity explainer_name
# cora    False                False     0.000    basic_gnnexplainer       0.987620
#                                                 distance                 0.122430
#                                                 gnnexplainer             0.987620
#                                                 gradcam                  0.761656
#                                                 ig                       0.251848
# ...                                                                           ...
#         True                 True      0.997    occlusion                0.997526
#                                                 pagerank                 0.997213
#                                                 pgmexplainer             0.997308
#                                                 random                   0.997060
#                                                 sa                       0.997272
#
#                                                                     ...  \
# dataset true_label_as_target hard_mask sparsity explainer_name      ...
# cora    False                False     0.000    basic_gnnexplainer  ...
#                                                 distance            ...
#                                                 gnnexplainer        ...
#                                                 gradcam             ...
#                                                 ig                  ...
# ...                                                                 ...
#         True                 True      0.997    occlusion           ...
#                                                 pagerank            ...
#                                                 pgmexplainer        ...
#                                                 random              ...
#                                                 sa                  ...
#
#                                                                     mask_size_init  \
# dataset true_label_as_target hard_mask sparsity explainer_name
# cora    False                False     0.000    basic_gnnexplainer         164.210
#                                                 distance                 11640.092
#                                                 gnnexplainer               164.208
#                                                 gradcam                   3161.393
#                                                 ig                        9923.491
# ...                                                                            ...
#         True                 True      0.997    occlusion                  176.661
#                                                 pagerank                  2097.576
#                                                 pgmexplainer               402.402
#                                                 random                   13249.918
#                                                 sa                        4184.238
#
#                                                                     mask_entropy_init  \
# dataset true_label_as_target hard_mask sparsity explainer_name
# cora    False                False     0.000    basic_gnnexplainer           3.292074
#                                                 distance                     8.849912
#                                                 gnnexplainer                 2.920812
#                                                 gradcam                      4.747347
#                                                 ig                           7.807732
# ...                                                                               ...
#         True                 True      0.997    occlusion                    4.315175
#                                                 pagerank                     5.678179
#                                                 pgmexplainer                 5.050473
#                                                 random                       9.299681
#                                                 sa                           5.970723
#
#                                                                     max_avg_init  \
# dataset true_label_as_target hard_mask sparsity explainer_name
# cora    False                False     0.000    basic_gnnexplainer      0.368996
#                                                 distance                0.169638
#                                                 gnnexplainer            0.141127
#                                                 gradcam                 0.135885
#                                                 ig                      0.146000
# ...                                                                          ...
#         True                 True      0.997    occlusion               0.817187
#                                                 pagerank                0.048300
#                                                 pgmexplainer            0.453154
#                                                 random                  0.476803
#                                                 sa                      0.280061
#
#                                                                     mask_size_transf  \
# dataset true_label_as_target hard_mask sparsity explainer_name
# cora    False                False     0.000    basic_gnnexplainer           164.210
#                                                 distance                   11640.092
#                                                 gnnexplainer                 164.208
#                                                 gradcam                     3161.393
#                                                 ig                          9923.491
# ...                                                                              ...
#         True                 True      0.997    occlusion                     32.823
#                                                 pagerank                      36.974
#                                                 pgmexplainer                  35.713
#                                                 random                        39.000
#                                                 sa                            36.191
#
#                                                                     mask_entropy_transf  \
# dataset true_label_as_target hard_mask sparsity explainer_name
# cora    False                False     0.000    basic_gnnexplainer             3.292074
#                                                 distance                       8.849912
#                                                 gnnexplainer                   2.920812
#                                                 gradcam                        4.747347
#                                                 ig                             7.807732
# ...                                                                                 ...
#         True                 True      0.997    occlusion                      3.374415
#                                                 pagerank                       3.342843
#                                                 pgmexplainer                   3.475922
#                                                 random                         3.663561
#                                                 sa                             3.434591
#
#                                                                     max_avg_transf  \
# dataset true_label_as_target hard_mask sparsity explainer_name
# cora    False                False     0.000    basic_gnnexplainer        0.368996
#                                                 distance                  0.169638
#                                                 gnnexplainer              0.141127
#                                                 gradcam                   0.135885
#                                                 ig                        0.146000
# ...                                                                            ...
#         True                 True      0.997    occlusion                 0.818041
#                                                 pagerank                  0.232930
#                                                 pgmexplainer              0.817691
#                                                 random                    0.998005
#                                                 sa                        0.539364
#
#                                                                         time  \
# dataset true_label_as_target hard_mask sparsity explainer_name
# cora    False                False     0.000    basic_gnnexplainer   3.63883
#                                                 distance             0.28118
#                                                 gnnexplainer         3.62851
#                                                 gradcam              0.00431
#                                                 ig                   0.15615
# ...                                                                      ...
#         True                 True      0.997    occlusion            0.56956
#                                                 pagerank             0.30943
#                                                 pgmexplainer        11.72742
#                                                 random               0.00020
#                                                 sa                   0.00703
#
#                                                                     number_of_edges  \
# dataset true_label_as_target hard_mask sparsity explainer_name
# cora    False                False     0.000    basic_gnnexplainer          13264.0
#                                                 distance                    13264.0
#                                                 gnnexplainer                13264.0
#                                                 gradcam                     13264.0
#                                                 ig                          13264.0
# ...                                                                             ...
#         True                 True      0.997    occlusion                   13264.0
#                                                 pagerank                    13264.0
#                                                 pgmexplainer                13264.0
#                                                 random                      13264.0
#                                                 sa                          13264.0
#
#                                                                     mask_sparsity_init  \
# dataset true_label_as_target hard_mask sparsity explainer_name
# cora    False                False     0.000    basic_gnnexplainer            0.987620
#                                                 distance                      0.122430
#                                                 gnnexplainer                  0.987620
#                                                 gradcam                       0.761656
#                                                 ig                            0.251848
# ...                                                                                ...
#         True                 True      0.997    occlusion                     0.986681
#                                                 pagerank                      0.841859
#                                                 pgmexplainer                  0.969662
#                                                 random                        0.001062
#                                                 sa                            0.684542
#
#                                                                     non_zero_values_init
# dataset true_label_as_target hard_mask sparsity explainer_name
# cora    False                False     0.000    basic_gnnexplainer               164.210
#                                                 distance                       11640.092
#                                                 gnnexplainer                     164.208
#                                                 gradcam                         3161.393
#                                                 ig                              9923.491
# ...                                                                                  ...
#         True                 True      0.997    occlusion                        176.661
#                                                 pagerank                        2097.576
#                                                 pgmexplainer                     402.402
#                                                 random                         13249.918
#                                                 sa                              4184.238
#
# [160 rows x 21 columns]
# [                                                                    num_test  \
# dataset true_label_as_target hard_mask sparsity explainer_name
# cora    False                False     0.000    basic_gnnexplainer     100.0
#                                                 distance               100.0
#                                                 gnnexplainer           100.0
#                                                 gradcam                100.0
#                                                 ig                     100.0
# ...                                                                      ...
#         True                 True      0.997    occlusion              100.0
#                                                 pagerank               100.0
#                                                 pgmexplainer           100.0
#                                                 random                 100.0
#                                                 sa                     100.0
#
#                                                                     fidelity_acc+  \
# dataset true_label_as_target hard_mask sparsity explainer_name
# cora    False                False     0.000    basic_gnnexplainer         -1.000
#                                                 distance                   -1.000
#                                                 gnnexplainer               -1.000
#                                                 gradcam                    -1.000
#                                                 ig                         -1.000
# ...                                                                           ...
#         True                 True      0.997    occlusion                   0.897
#                                                 pagerank                    0.879
#                                                 pgmexplainer                0.625
#                                                 random                      0.073
#                                                 sa                          0.745
#
#                                                                     fidelity_acc-  \
# dataset true_label_as_target hard_mask sparsity explainer_name
# cora    False                False     0.000    basic_gnnexplainer         -1.000
#                                                 distance                   -1.000
#                                                 gnnexplainer               -1.000
#                                                 gradcam                    -1.000
#                                                 ig                         -1.000
# ...                                                                           ...
#         True                 True      0.997    occlusion                   0.011
#                                                 pagerank                    0.035
#                                                 pgmexplainer                0.052
#                                                 random                      0.884
#                                                 sa                          0.148
#
#                                                                     fidelity_prob+  \
# dataset true_label_as_target hard_mask sparsity explainer_name
# cora    False                False     0.000    basic_gnnexplainer       -1.000000
#                                                 distance                 -1.000000
#                                                 gnnexplainer             -1.000000
#                                                 gradcam                  -1.000000
#                                                 ig                       -1.000000
# ...                                                                            ...
#         True                 True      0.997    occlusion                 0.791508
#                                                 pagerank                  0.766729
#                                                 pgmexplainer              0.521140
#                                                 random                   -0.009590
#                                                 sa                        0.634229
#
#                                                                     fidelity_prob-  \
# dataset true_label_as_target hard_mask sparsity explainer_name
# cora    False                False     0.000    basic_gnnexplainer       -1.000000
#                                                 distance                 -1.000000
#                                                 gnnexplainer             -1.000000
#                                                 gradcam                  -1.000000
#                                                 ig                       -1.000000
# ...                                                                            ...
#         True                 True      0.997    occlusion                -0.072082
#                                                 pagerank                 -0.047175
#                                                 pgmexplainer             -0.031500
#                                                 random                    0.771632
#                                                 sa                        0.062011
#
#                                                                     fidelity_gnn_acc+  \
# dataset true_label_as_target hard_mask sparsity explainer_name
# cora    False                False     0.000    basic_gnnexplainer              0.376
#                                                 distance                        0.162
#                                                 gnnexplainer                    0.493
#                                                 gradcam                         0.215
#                                                 ig                              0.337
# ...                                                                               ...
#         True                 True      0.997    occlusion                      -1.000
#                                                 pagerank                       -1.000
#                                                 pgmexplainer                   -1.000
#                                                 random                         -1.000
#                                                 sa                             -1.000
#
#                                                                     fidelity_gnn_acc-  \
# dataset true_label_as_target hard_mask sparsity explainer_name
# cora    False                False     0.000    basic_gnnexplainer              0.379
#                                                 distance                        0.068
#                                                 gnnexplainer                    0.373
#                                                 gradcam                         0.036
#                                                 ig                              0.031
# ...                                                                               ...
#         True                 True      0.997    occlusion                      -1.000
#                                                 pagerank                       -1.000
#                                                 pgmexplainer                   -1.000
#                                                 random                         -1.000
#                                                 sa                             -1.000
#
#                                                                     fidelity_gnn_prob+  \
# dataset true_label_as_target hard_mask sparsity explainer_name
# cora    False                False     0.000    basic_gnnexplainer            0.384231
#                                                 distance                      0.539109
#                                                 gnnexplainer                  0.541627
#                                                 gradcam                       0.498248
#                                                 ig                            0.556903
# ...                                                                                ...
#         True                 True      0.997    occlusion                    -1.000000
#                                                 pagerank                     -1.000000
#                                                 pgmexplainer                 -1.000000
#                                                 random                       -1.000000
#                                                 sa                           -1.000000
#
#                                                                     fidelity_gnn_prob-  \
# dataset true_label_as_target hard_mask sparsity explainer_name
# cora    False                False     0.000    basic_gnnexplainer            0.413214
#                                                 distance                      0.311883
#                                                 gnnexplainer                  0.601882
#                                                 gradcam                       0.365465
#                                                 ig                            0.264937
# ...                                                                                ...
#         True                 True      0.997    occlusion                    -1.000000
#                                                 pagerank                     -1.000000
#                                                 pgmexplainer                 -1.000000
#                                                 random                       -1.000000
#                                                 sa                           -1.000000
#
#                                                                     mask_sparsity  \
# dataset true_label_as_target hard_mask sparsity explainer_name
# cora    False                False     0.000    basic_gnnexplainer       0.987620
#                                                 distance                 0.122430
#                                                 gnnexplainer             0.987620
#                                                 gradcam                  0.761656
#                                                 ig                       0.251848
# ...                                                                           ...
#         True                 True      0.997    occlusion                0.997526
#                                                 pagerank                 0.997213
#                                                 pgmexplainer             0.997308
#                                                 random                   0.997060
#                                                 sa                       0.997272
#
#                                                                     ...  \
# dataset true_label_as_target hard_mask sparsity explainer_name      ...
# cora    False                False     0.000    basic_gnnexplainer  ...
#                                                 distance            ...
#                                                 gnnexplainer        ...
#                                                 gradcam             ...
#                                                 ig                  ...
# ...                                                                 ...
#         True                 True      0.997    occlusion           ...
#                                                 pagerank            ...
#                                                 pgmexplainer        ...
#                                                 random              ...
#                                                 sa                  ...
#
#                                                                     mask_size_init  \
# dataset true_label_as_target hard_mask sparsity explainer_name
# cora    False                False     0.000    basic_gnnexplainer         164.210
#                                                 distance                 11640.092
#                                                 gnnexplainer               164.208
#                                                 gradcam                   3161.393
#                                                 ig                        9923.491
# ...                                                                            ...
#         True                 True      0.997    occlusion                  176.661
#                                                 pagerank                  2097.576
#                                                 pgmexplainer               402.402
#                                                 random                   13249.918
#                                                 sa                        4184.238
#
#                                                                     mask_entropy_init  \
# dataset true_label_as_target hard_mask sparsity explainer_name
# cora    False                False     0.000    basic_gnnexplainer           3.292074
#                                                 distance                     8.849912
#                                                 gnnexplainer                 2.920812
#                                                 gradcam                      4.747347
#                                                 ig                           7.807732
# ...                                                                               ...
#         True                 True      0.997    occlusion                    4.315175
#                                                 pagerank                     5.678179
#                                                 pgmexplainer                 5.050473
#                                                 random                       9.299681
#                                                 sa                           5.970723
#
#                                                                     max_avg_init  \
# dataset true_label_as_target hard_mask sparsity explainer_name
# cora    False                False     0.000    basic_gnnexplainer      0.368996
#                                                 distance                0.169638
#                                                 gnnexplainer            0.141127
#                                                 gradcam                 0.135885
#                                                 ig                      0.146000
# ...                                                                          ...
#         True                 True      0.997    occlusion               0.817187
#                                                 pagerank                0.048300
#                                                 pgmexplainer            0.453154
#                                                 random                  0.476803
#                                                 sa                      0.280061
#
#                                                                     mask_size_transf  \
# dataset true_label_as_target hard_mask sparsity explainer_name
# cora    False                False     0.000    basic_gnnexplainer           164.210
#                                                 distance                   11640.092
#                                                 gnnexplainer                 164.208
#                                                 gradcam                     3161.393
#                                                 ig                          9923.491
# ...                                                                              ...
#         True                 True      0.997    occlusion                     32.823
#                                                 pagerank                      36.974
#                                                 pgmexplainer                  35.713
#                                                 random                        39.000
#                                                 sa                            36.191
#
#                                                                     mask_entropy_transf  \
# dataset true_label_as_target hard_mask sparsity explainer_name
# cora    False                False     0.000    basic_gnnexplainer             3.292074
#                                                 distance                       8.849912
#                                                 gnnexplainer                   2.920812
#                                                 gradcam                        4.747347
#                                                 ig                             7.807732
# ...                                                                                 ...
#         True                 True      0.997    occlusion                      3.374415
#                                                 pagerank                       3.342843
#                                                 pgmexplainer                   3.475922
#                                                 random                         3.663561
#                                                 sa                             3.434591
#
#                                                                     max_avg_transf  \
# dataset true_label_as_target hard_mask sparsity explainer_name
# cora    False                False     0.000    basic_gnnexplainer        0.368996
#                                                 distance                  0.169638
#                                                 gnnexplainer              0.141127
#                                                 gradcam                   0.135885
#                                                 ig                        0.146000
# ...                                                                            ...
#         True                 True      0.997    occlusion                 0.818041
#                                                 pagerank                  0.232930
#                                                 pgmexplainer              0.817691
#                                                 random                    0.998005
#                                                 sa                        0.539364
#
#                                                                         time  \
# dataset true_label_as_target hard_mask sparsity explainer_name
# cora    False                False     0.000    basic_gnnexplainer   3.63883
#                                                 distance             0.28118
#                                                 gnnexplainer         3.62851
#                                                 gradcam              0.00431
#                                                 ig                   0.15615
# ...                                                                      ...
#         True                 True      0.997    occlusion            0.56956
#                                                 pagerank             0.30943
#                                                 pgmexplainer        11.72742
#                                                 random               0.00020
#                                                 sa                   0.00703
#
#                                                                     number_of_edges  \
# dataset true_label_as_target hard_mask sparsity explainer_name
# cora    False                False     0.000    basic_gnnexplainer          13264.0
#                                                 distance                    13264.0
#                                                 gnnexplainer                13264.0
#                                                 gradcam                     13264.0
#                                                 ig                          13264.0
# ...                                                                             ...
#         True                 True      0.997    occlusion                   13264.0
#                                                 pagerank                    13264.0
#                                                 pgmexplainer                13264.0
#                                                 random                      13264.0
#                                                 sa                          13264.0
#
#                                                                     mask_sparsity_init  \
# dataset true_label_as_target hard_mask sparsity explainer_name
# cora    False                False     0.000    basic_gnnexplainer            0.987620
#                                                 distance                      0.122430
#                                                 gnnexplainer                  0.987620
#                                                 gradcam                       0.761656
#                                                 ig                            0.251848
# ...
#
#                                                                      fidelity_gnn_prob+  \
# dataset  true_label_as_target hard_mask sparsity explainer_name
# facebook False                False     0.000    basic_gnnexplainer            0.572414
#                                                  distance                      0.309697
#                                                  gnnexplainer                  0.257359
#                                                  gradcam                       0.308520
#                                                  ig                            0.360399
# ...                                                                                 ...
#          True                 True      0.997    occlusion                    -1.000000
#                                                  pagerank                     -1.000000
#                                                  pgmexplainer                 -1.000000
#                                                  random                       -1.000000
#                                                  sa                           -1.000000
#
#                                                                      fidelity_gnn_prob-  \
# dataset  true_label_as_target hard_mask sparsity explainer_name
# facebook False                False     0.000    basic_gnnexplainer            0.120615
#                                                  distance                      0.369471
#                                                  gnnexplainer                  0.605383
#                                                  gradcam                       0.423542
#                                                  ig                            0.324589
# ...                                                                                 ...
#          True                 True      0.997    occlusion                    -1.000000
#                                                  pagerank                     -1.000000
#                                                  pgmexplainer                 -1.000000
#                                                  random                       -1.000000
#                                                  sa                           -1.000000
#
#                                                                      mask_sparsity  \
# dataset  true_label_as_target hard_mask sparsity explainer_name
# facebook False                False     0.000    basic_gnnexplainer       0.979087
#                                                  distance                 0.000029
#                                                  gnnexplainer             0.979087
#                                                  gradcam                  0.628983
#                                                  ig                       0.060936
# ...                                                                            ...
#          True                 True      0.997    occlusion                0.998051
#                                                  pagerank                 0.997045
#                                                  pgmexplainer             0.997471
#                                                  random                   0.997001
#                                                  sa                       0.997059
#
#                                                                      ...  \
# dataset  true_label_as_target hard_mask sparsity explainer_name      ...
# facebook False                False     0.000    basic_gnnexplainer  ...
#                                                  distance            ...
#                                                  gnnexplainer        ...
#                                                  gradcam             ...
#                                                  ig                  ...
# ...                                                                  ...
#          True                 True      0.997    occlusion           ...
#                                                  pagerank            ...
#                                                  pgmexplainer        ...
#                                                  random              ...
#                                                  sa                  ...
#
#                                                                      mask_size_init  \
# dataset  true_label_as_target hard_mask sparsity explainer_name
# facebook False                False     0.000    basic_gnnexplainer        7614.638
#                                                  distance                364105.539
#                                                  gnnexplainer              7614.639
#                                                  gradcam                 135093.267
#                                                  ig                      341928.275
# ...                                                                             ...
#          True                 True      0.997    occlusion                 7832.505
#                                                  pagerank                 23741.544
#                                                  pgmexplainer             18670.273
#                                                  random                  363750.047
#                                                  sa                      303056.977
#
#                                                                      mask_entropy_init  \
# dataset  true_label_as_target hard_mask sparsity explainer_name
# facebook False                False     0.000    basic_gnnexplainer           6.747496
#                                                  distance                    12.757013
#                                                  gnnexplainer                 6.202966
#                                                  gradcam                      7.912284
#                                                  ig                          12.269136
# ...                                                                                ...
#          True                 True      0.997    occlusion                    7.007714
#                                                  pagerank                     8.251815
#                                                  pgmexplainer                 8.227726
#                                                  random                      12.612083
#                                                  sa                          11.879324
#
#                                                                      max_avg_init  \
# dataset  true_label_as_target hard_mask sparsity explainer_name
# facebook False                False     0.000    basic_gnnexplainer      0.761433
#                                                  distance                0.112228
#                                                  gnnexplainer            0.043189
#                                                  gradcam                 0.099737
#                                                  ig                      0.166454
# ...                                                                           ...
#          True                 True      0.997    occlusion               0.889634
#                                                  pagerank                0.001836
#                                                  pgmexplainer            0.371260
#                                                  random                  0.503269
#                                                  sa                      0.645168
#
#                                                                      mask_size_transf  \
# dataset  true_label_as_target hard_mask sparsity explainer_name
# facebook False                False     0.000    basic_gnnexplainer          7614.638
#                                                  distance                  364105.539
#                                                  gnnexplainer                7614.639
#                                                  gradcam                   135093.267
#                                                  ig                        341928.275
# ...                                                                               ...
#          True                 True      0.997    occlusion                    709.722
#                                                  pagerank                    1076.078
#                                                  pgmexplainer                 920.693
#                                                  random                      1092.000
#                                                  sa                          1070.690
#
#                                                                      mask_entropy_transf  \
# dataset  true_label_as_target hard_mask sparsity explainer_name
# facebook False                False     0.000    basic_gnnexplainer             6.747496
#                                                  distance                      12.757013
#                                                  gnnexplainer                   6.202966
#                                                  gradcam                        7.912284
#                                                  ig                            12.269136
# ...                                                                                  ...
#          True                 True      0.997    occlusion                      6.057597
#                                                  pagerank                       6.233838
#                                                  pgmexplainer                   6.582991
#                                                  random                         6.995766
#                                                  sa                             6.865591
#
#                                                                      max_avg_transf  \
# dataset  true_label_as_target hard_mask sparsity explainer_name
# facebook False                False     0.000    basic_gnnexplainer        0.761433
#                                                  distance                  0.112228
#                                                  gnnexplainer              0.043189
#                                                  gradcam                   0.099737
#                                                  ig                        0.166454
# ...                                                                             ...
#          True                 True      0.997    occlusion                 0.889796
#                                                  pagerank                  0.027866
#                                                  pgmexplainer              0.643379
#                                                  random                    0.998317
#                                                  sa                        0.714942
#
#                                                                          time  \
# dataset  true_label_as_target hard_mask sparsity explainer_name
# facebook False                False     0.000    basic_gnnexplainer   4.62639
#                                                  distance             1.69635
#                                                  gnnexplainer         3.74675
#                                                  gradcam              0.01044
#                                                  ig                   0.24743
# ...                                                                       ...
#          True                 True      0.997    occlusion           21.22537
#                                                  pagerank             2.46246
#                                                  pgmexplainer        88.90563
#                                                  random               0.00279
#                                                  sa                   0.01203
#
#                                                                      number_of_edges  \
# dataset  true_label_as_target hard_mask sparsity explainer_name
# facebook False                False     0.000    basic_gnnexplainer         364116.0
#                                                  distance                   364116.0
#                                                  gnnexplainer               364116.0
#                                                  gradcam                    364116.0
#                                                  ig                         364116.0
# ...                                                                              ...
#          True                 True      0.997    occlusion                  364116.0
#                                                  pagerank                   364116.0
#                                                  pgmexplainer               364116.0
#                                                  random                     364116.0
#                                                  sa                         364116.0
#
#                                                                      mask_sparsity_init  \
# dataset  true_label_as_target hard_mask sparsity explainer_name
# facebook False                False     0.000    basic_gnnexplainer            0.979087
#                                                  distance                      0.000029
#                                                  gnnexplainer                  0.979087
#                                                  gradcam                       0.628983
#                                                  ig                            0.060936
# ...                                                                                 ...
#          True                 True      0.997    occlusion                     0.978489
#                                                  pagerank                      0.934797
#                                                  pgmexplainer                  0.948724
#                                                  random                        0.001005
#                                                  sa                            0.167691
#
#                                                                      non_zero_values_init
# dataset  true_label_as_target hard_mask sparsity explainer_name
# facebook False                False     0.000    basic_gnnexplainer              7614.638
#                                                  distance                      364105.539
#                                                  gnnexplainer                    7614.639
#                                                  gradcam                       135093.267
#                                                  ig                            341928.275
# ...                                                                                   ...
#          True                 True      0.997    occlusion                       7832.505
#                                                  pagerank                       23741.544
#                                                  pgmexplainer                   18670.273
#                                                  random                        363750.047
#                                                  sa                            303056.977
#
# [160 rows x 21 columns]]

# %%
avg_scores = pd.concat(SCORES)
avg_scores
# Out:
#                                                                      num_test  \
# dataset  true_label_as_target hard_mask sparsity explainer_name
# cora     False                False     0.000    basic_gnnexplainer     100.0
#                                                  distance               100.0
#                                                  gnnexplainer           100.0
#                                                  gradcam                100.0
#                                                  ig                     100.0
# ...                                                                       ...
# facebook True                 True      0.997    occlusion              100.0
#                                                  pagerank               100.0
#                                                  pgmexplainer           100.0
#                                                  random                 100.0
#                                                  sa                     100.0
#
#                                                                      fidelity_acc+  \
# dataset  true_label_as_target hard_mask sparsity explainer_name
# cora     False                False     0.000    basic_gnnexplainer         -1.000
#                                                  distance                   -1.000
#                                                  gnnexplainer               -1.000
#                                                  gradcam                    -1.000
#                                                  ig                         -1.000
# ...                                                                            ...
# facebook True                 True      0.997    occlusion                   0.862
#                                                  pagerank                    0.786
#                                                  pgmexplainer                0.550
#                                                  random                      0.072
#                                                  sa                          0.265
#
#                                                                      fidelity_acc-  \
# dataset  true_label_as_target hard_mask sparsity explainer_name
# cora     False                False     0.000    basic_gnnexplainer         -1.000
#                                                  distance                   -1.000
#                                                  gnnexplainer               -1.000
#                                                  gradcam                    -1.000
#                                                  ig                         -1.000
# ...                                                                            ...
# facebook True                 True      0.997    occlusion                   0.012
#                                                  pagerank                    0.044
#                                                  pgmexplainer                0.040
#                                                  random                      0.785
#                                                  sa                          0.550
#
#                                                                      fidelity_prob+  \
# dataset  true_label_as_target hard_mask sparsity explainer_name
# cora     False                False     0.000    basic_gnnexplainer       -1.000000
#                                                  distance                 -1.000000
#                                                  gnnexplainer             -1.000000
#                                                  gradcam                  -1.000000
#                                                  ig                       -1.000000
# ...                                                                             ...
# facebook True                 True      0.997    occlusion                 0.751350
#                                                  pagerank                  0.685483
#                                                  pgmexplainer              0.454271
#                                                  random                    0.002038
#                                                  sa                        0.194527
#
#                                                                      fidelity_prob-  \
# dataset  true_label_as_target hard_mask sparsity explainer_name
# cora     False                False     0.000    basic_gnnexplainer       -1.000000
#                                                  distance                 -1.000000
#                                                  gnnexplainer             -1.000000
#                                                  gradcam                  -1.000000
#                                                  ig                       -1.000000
# ...                                                                             ...
# facebook True                 True      0.997    occlusion                -0.059571
#                                                  pagerank                 -0.027353
#                                                  pgmexplainer             -0.032108
#                                                  random                    0.683861
#                                                  sa                        0.453309
#
#                                                                      fidelity_gnn_acc+  \
# dataset  true_label_as_target hard_mask sparsity explainer_name
# cora     False                False     0.000    basic_gnnexplainer              0.376
#                                                  distance                        0.162
#                                                  gnnexplainer                    0.493
#                                                  gradcam                         0.215
#                                                  ig                              0.337
# ...                                                                                ...
# facebook True                 True      0.997    occlusion                      -1.000
#                                                  pagerank                       -1.000
#                                                  pgmexplainer                   -1.000
#                                                  random                         -1.000
#                                                  sa                             -1.000
#
#                                                                      fidelity_gnn_acc-  \
# dataset  true_label_as_target hard_mask sparsity explainer_name
# cora     False                False     0.000    basic_gnnexplainer              0.379
#                                                  distance                        0.068
#                                                  gnnexplainer                    0.373
#                                                  gradcam                         0.036
#                                                  ig                              0.031
# ...                                                                                ...
# facebook True                 True      0.997    occlusion                      -1.000
#                                                  pagerank                       -1.000
#                                                  pgmexplainer                   -1.000
#                                                  random                         -1.000
#                                                  sa                             -1.000
#
#                                                                      fidelity_gnn_prob+  \
# dataset  true_label_as_target hard_mask sparsity explainer_name
# cora     False                False     0.000    basic_gnnexplainer            0.384231
#                                                  distance                      0.539109
#                                                  gnnexplainer                  0.541627
#                                                  gradcam                       0.498248
#                                                  ig                            0.556903
# ...                                                                                 ...
# facebook True                 True      0.997    occlusion                    -1.000000
#                                                  pagerank                     -1.000000
#                                                  pgmexplainer                 -1.000000
#                                                  random                       -1.000000
#                                                  sa                           -1.000000
#
#                                                                      fidelity_gnn_prob-  \
# dataset  true_label_as_target hard_mask sparsity explainer_name
# cora     False                False     0.000    basic_gnnexplainer            0.413214
#                                                  distance                      0.311883
#                                                  gnnexplainer                  0.601882
#                                                  gradcam                       0.365465
#                                                  ig                            0.264937
# ...                                                                                 ...
# facebook True                 True      0.997    occlusion                    -1.000000
#                                                  pagerank                     -1.000000
#                                                  pgmexplainer                 -1.000000
#                                                  random                       -1.000000
#                                                  sa                           -1.000000
#
#                                                                      mask_sparsity  \
# dataset  true_label_as_target hard_mask sparsity explainer_name
# cora     False                False     0.000    basic_gnnexplainer       0.987620
#                                                  distance                 0.122430
#                                                  gnnexplainer             0.987620
#                                                  gradcam                  0.761656
#                                                  ig                       0.251848
# ...                                                                            ...
# facebook True                 True      0.997    occlusion                0.998051
#                                                  pagerank                 0.997045
#                                                  pgmexplainer             0.997471
#                                                  random                   0.997001
#                                                  sa                       0.997059
#
#                                                                      ...  \
# dataset  true_label_as_target hard_mask sparsity explainer_name      ...
# cora     False                False     0.000    basic_gnnexplainer  ...
#                                                  distance            ...
#                                                  gnnexplainer        ...
#                                                  gradcam             ...
#                                                  ig                  ...
# ...                                                                  ...
# facebook True                 True      0.997    occlusion           ...
#                                                  pagerank            ...
#                                                  pgmexplainer        ...
#                                                  random              ...
#                                                  sa                  ...
#
#                                                                      mask_size_init  \
# dataset  true_label_as_target hard_mask sparsity explainer_name
# cora     False                False     0.000    basic_gnnexplainer         164.210
#                                                  distance                 11640.092
#                                                  gnnexplainer               164.208
#                                                  gradcam                   3161.393
#                                                  ig                        9923.491
# ...                                                                             ...
# facebook True                 True      0.997    occlusion                 7832.505
#                                                  pagerank                 23741.544
#                                                  pgmexplainer             18670.273
#                                                  random                  363750.047
#                                                  sa                      303056.977
#
#                                                                      mask_entropy_init  \
# dataset  true_label_as_target hard_mask sparsity explainer_name
# cora     False                False     0.000    basic_gnnexplainer           3.292074
#                                                  distance                     8.849912
#                                                  gnnexplainer                 2.920812
#                                                  gradcam                      4.747347
#                                                  ig                           7.807732
# ...                                                                                ...
# facebook True                 True      0.997    occlusion                    7.007714
#                                                  pagerank                     8.251815
#                                                  pgmexplainer                 8.227726
#                                                  random                      12.612083
#                                                  sa                          11.879324
#
#                                                                      max_avg_init  \
# dataset  true_label_as_target hard_mask sparsity explainer_name
# cora     False                False     0.000    basic_gnnexplainer      0.368996
#                                                  distance                0.169638
#                                                  gnnexplainer            0.141127
#                                                  gradcam                 0.135885
#                                                  ig                      0.146000
# ...                                                                           ...
# facebook True                 True      0.997    occlusion               0.889634
#                                                  pagerank                0.001836
#                                                  pgmexplainer            0.371260
#                                                  random                  0.503269
#                                                  sa                      0.645168
#
#                                                                      mask_size_transf  \
# dataset  true_label_as_target hard_mask sparsity explainer_name
# cora     False                False     0.000    basic_gnnexplainer           164.210
#                                                  distance                   11640.092
#                                                  gnnexplainer                 164.208
#                                                  gradcam                     3161.393
#                                                  ig                          9923.491
# ...                                                                               ...
# facebook True                 True      0.997    occlusion                    709.722
#                                                  pagerank                    1076.078
#                                                  pgmexplainer                 920.693
#                                                  random                      1092.000
#                                                  sa                          1070.690
#
#                                                                      mask_entropy_transf  \
# dataset  true_label_as_target hard_mask sparsity explainer_name
# cora     False                False     0.000    basic_gnnexplainer             3.292074
#                                                  distance                       8.849912
#                                                  gnnexplainer                   2.920812
#                                                  gradcam                        4.747347
#                                                  ig                             7.807732
# ...                                                                                  ...
# facebook True                 True      0.997    occlusion                      6.057597
#                                                  pagerank                       6.233838
#                                                  pgmexplainer                   6.582991
#                                                  random                         6.995766
#                                                  sa                             6.865591
#
#                                                                      max_avg_transf  \
# dataset  true_label_as_target hard_mask sparsity explainer_name
# cora     False                False     0.000    basic_gnnexplainer        0.368996
#                                                  distance                  0.169638
#                                                  gnnexplainer              0.141127
#                                                  gradcam                   0.135885
#                                                  ig                        0.146000
# ...                                                                             ...
# facebook True                 True      0.997    occlusion                 0.889796
#                                                  pagerank                  0.027866
#                                                  pgmexplainer              0.643379
#                                                  random                    0.998317
#                                                  sa                        0.714942
#
#                                                                          time  \
# dataset  true_label_as_target hard_mask sparsity explainer_name
# cora     False                False     0.000    basic_gnnexplainer   3.63883
#                                                  distance             0.28118
#                                                  gnnexplainer         3.62851
#                                                  gradcam              0.00431
#                                                  ig                   0.15615
# ...                                                                       ...
# facebook True                 True      0.997    occlusion           21.22537
#                                                  pagerank             2.46246
#                                                  pgmexplainer        88.90563
#                                                  random               0.00279
#                                                  sa                   0.01203
#
#                                                                      number_of_edges  \
# dataset  true_label_as_target hard_mask sparsity explainer_name
# cora     False                False     0.000    basic_gnnexplainer          13264.0
#                                                  distance                    13264.0
#                                                  gnnexplainer                13264.0
#                                                  gradcam                     13264.0
#                                                  ig                          13264.0
# ...                                                                              ...
# facebook True                 True      0.997    occlusion                  364116.0
#                                                  pagerank                   364116.0
#                                                  pgmexplainer               364116.0
#                                                  random                     364116.0
#                                                  sa                         364116.0
#
#                                                                      mask_sparsity_init  \
# dataset  true_label_as_target hard_mask sparsity explainer_name
# cora     False                False     0.000    basic_gnnexplainer            0.987620
#                                                  distance                      0.122430
#                                                  gnnexplainer                  0.987620
#                                                  gradcam                       0.761656
#                                                  ig                            0.251848
# ...                                                                                 ...
# facebook True                 True      0.997    occlusion                     0.978489
#                                                  pagerank                      0.934797
#                                                  pgmexplainer                  0.948724
#                                                  random                        0.001005
#                                                  sa                            0.167691
#
#                                                                      non_zero_values_init
# dataset  true_label_as_target hard_mask sparsity explainer_name
# cora     False                False     0.000    basic_gnnexplainer               164.210
#                                                  distance                       11640.092
#                                                  gnnexplainer                     164.208
#                                                  gradcam                         3161.393
#                                                  ig                              9923.491
# ...                                                                                   ...
# facebook True                 True      0.997    occlusion                       7832.505
#                                                  pagerank                       23741.544
#                                                  pgmexplainer                   18670.273
#                                                  random                        363750.047
#                                                  sa                            303056.977
#
# [1584 rows x 21 columns]

# %%
avg_scores = avg_scores.reset_index()
avg_scores.to_csv('/cluster/home/kamara/Explain/csv/node_classification/real/nc_real_sparsity_avg10expe.csv', index=False)

# %% [markdown]
# ### GNN scores

# %%
GNN_SCORES = []
for data in datasets:

    logdir = f'/cluster/home/kamara/checkpoints/node_classification/real/sparsity_real_avg10expe_{data}/logs'
    jsonpath = f'/cluster/home/kamara/Explain/configs/config_real_sparsity_avg10expe_{data}.json'
    ranges = get_param_ranges(jsonpath)
    gnn_train, gnn_test = get_gnn_info(logdir)
    
    df_gnn_train = get_df_results(gnn_train, ranges, name, metrics = ["prec", "recall", "acc"])
    df_gnn_test = get_df_results(gnn_test, ranges, name, metrics = ["prec", "recall", "acc"])
    df_gnn_train['f1_score'] = 2*df_gnn_train['recall']*df_gnn_train['prec']/(df_gnn_train['recall']+df_gnn_train['prec'])
    df_gnn_test['f1_score'] = 2*df_gnn_test['recall']*df_gnn_test['prec']/(df_gnn_test['recall']+df_gnn_test['prec'])

    df_gnn_train = df_gnn_train.groupby(by=['dataset']).mean().reset_index()
    df_gnn_test = df_gnn_test.groupby(by=['dataset']).mean().reset_index()

    gnn_scores = pd.merge(df_gnn_train, df_gnn_test, on=['dataset', 'sparsity', 'num_test'], suffixes=['_train', '_test'])
    gnn_scores = gnn_scores.drop(columns=["sparsity", "num_test", "seed_train", "seed_test"])
    print('res', gnn_scores)

    GNN_SCORES.append(gnn_scores)
    print(GNN_SCORES)
# Out:
# res   dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0    cora         1.0           1.0        1.0             1.0   0.781341
#
#    recall_test  acc_test  f1_score_test
# 0     0.817384    0.8035       0.798947
# [  dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0    cora         1.0           1.0        1.0             1.0   0.781341
#
#    recall_test  acc_test  f1_score_test
# 0     0.817384    0.8035       0.798947  ]
# res   dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  pubmed         1.0           1.0        1.0             1.0   0.771646
#
#    recall_test  acc_test  f1_score_test
# 0     0.781766    0.7785        0.77667
# [  dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0    cora         1.0           1.0        1.0             1.0   0.781341
#
#    recall_test  acc_test  f1_score_test
# 0     0.817384    0.8035       0.798947  ,   dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  pubmed         1.0           1.0        1.0             1.0   0.771646
#
#    recall_test  acc_test  f1_score_test
# 0     0.781766    0.7785        0.77667  ]
# res     dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  citeseer         1.0           1.0        1.0             1.0   0.651307
#
#    recall_test  acc_test  f1_score_test
# 0     0.652012    0.6764       0.651656
# [  dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0    cora         1.0           1.0        1.0             1.0   0.781341
#
#    recall_test  acc_test  f1_score_test
# 0     0.817384    0.8035       0.798947  ,   dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  pubmed         1.0           1.0        1.0             1.0   0.771646
#
#    recall_test  acc_test  f1_score_test
# 0     0.781766    0.7785        0.77667  ,     dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  citeseer         1.0           1.0        1.0             1.0   0.651307
#
#    recall_test  acc_test  f1_score_test
# 0     0.652012    0.6764       0.651656  ]
# res    dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  cornell    0.927224      0.908135   0.974713        0.917484   0.354914
#
#    recall_test  acc_test  f1_score_test
# 0     0.338861  0.532432       0.344153
# [  dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0    cora         1.0           1.0        1.0             1.0   0.781341
#
#    recall_test  acc_test  f1_score_test
# 0     0.817384    0.8035       0.798947  ,   dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  pubmed         1.0           1.0        1.0             1.0   0.771646
#
#    recall_test  acc_test  f1_score_test
# 0     0.781766    0.7785        0.77667  ,     dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  citeseer         1.0           1.0        1.0             1.0   0.651307
#
#    recall_test  acc_test  f1_score_test
# 0     0.652012    0.6764       0.651656  ,    dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  cornell    0.927224      0.908135   0.974713        0.917484   0.354914
#
#    recall_test  acc_test  f1_score_test
# 0     0.338861  0.532432       0.344153  ]
# res   dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0   texas    0.972625      0.966848   0.991954        0.969666   0.296897
#
#    recall_test  acc_test  f1_score_test
# 0     0.277057  0.510811       0.284965
# [  dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0    cora         1.0           1.0        1.0             1.0   0.781341
#
#    recall_test  acc_test  f1_score_test
# 0     0.817384    0.8035       0.798947  ,   dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  pubmed         1.0           1.0        1.0             1.0   0.771646
#
#    recall_test  acc_test  f1_score_test
# 0     0.781766    0.7785        0.77667  ,     dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  citeseer         1.0           1.0        1.0             1.0   0.651307
#
#    recall_test  acc_test  f1_score_test
# 0     0.652012    0.6764       0.651656  ,    dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  cornell    0.927224      0.908135   0.974713        0.917484   0.354914
#
#    recall_test  acc_test  f1_score_test
# 0     0.338861  0.532432       0.344153  ,   dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0   texas    0.972625      0.966848   0.991954        0.969666   0.296897
#
#    recall_test  acc_test  f1_score_test
# 0     0.277057  0.510811       0.284965  ]
# res      dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  wisconsin    0.980174      0.955045   0.975833        0.967295   0.397882
#
#    recall_test  acc_test  f1_score_test
# 0     0.406152  0.535294        0.39667
# [  dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0    cora         1.0           1.0        1.0             1.0   0.781341
#
#    recall_test  acc_test  f1_score_test
# 0     0.817384    0.8035       0.798947  ,   dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  pubmed         1.0           1.0        1.0             1.0   0.771646
#
#    recall_test  acc_test  f1_score_test
# 0     0.781766    0.7785        0.77667  ,     dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  citeseer         1.0           1.0        1.0             1.0   0.651307
#
#    recall_test  acc_test  f1_score_test
# 0     0.652012    0.6764       0.651656  ,    dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  cornell    0.927224      0.908135   0.974713        0.917484   0.354914
#
#    recall_test  acc_test  f1_score_test
# 0     0.338861  0.532432       0.344153  ,   dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0   texas    0.972625      0.966848   0.991954        0.969666   0.296897
#
#    recall_test  acc_test  f1_score_test
# 0     0.277057  0.510811       0.284965  ,      dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  wisconsin    0.980174      0.955045   0.975833        0.967295   0.397882
#
#    recall_test  acc_test  f1_score_test
# 0     0.406152  0.535294        0.39667  ]
# res   dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0   actor    0.594783      0.480918   0.538185        0.531375   0.260683
#
#    recall_test  acc_test  f1_score_test
# 0     0.249017  0.285921       0.253762
# [  dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0    cora         1.0           1.0        1.0             1.0   0.781341
#
#    recall_test  acc_test  f1_score_test
# 0     0.817384    0.8035       0.798947  ,   dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  pubmed         1.0           1.0        1.0             1.0   0.771646
#
#    recall_test  acc_test  f1_score_test
# 0     0.781766    0.7785        0.77667  ,     dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  citeseer         1.0           1.0        1.0             1.0   0.651307
#
#    recall_test  acc_test  f1_score_test
# 0     0.652012    0.6764       0.651656  ,    dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  cornell    0.927224      0.908135   0.974713        0.917484   0.354914
#
#    recall_test  acc_test  f1_score_test
# 0     0.338861  0.532432       0.344153  ,   dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0   texas    0.972625      0.966848   0.991954        0.969666   0.296897
#
#    recall_test  acc_test  f1_score_test
# 0     0.277057  0.510811       0.284965  ,      dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  wisconsin    0.980174      0.955045   0.975833        0.967295   0.397882
#
#    recall_test  acc_test  f1_score_test
# 0     0.406152  0.535294        0.39667  ,   dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0   actor    0.594783      0.480918   0.538185        0.531375   0.260683
#
#    recall_test  acc_test  f1_score_test
# 0     0.249017  0.285921       0.253762  ]
# res      dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  chameleon    0.817928      0.806324    0.80641        0.812068   0.646635
#
#    recall_test  acc_test  f1_score_test
# 0     0.634489  0.632237       0.640485
# [  dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0    cora         1.0           1.0        1.0             1.0   0.781341
#
#    recall_test  acc_test  f1_score_test
# 0     0.817384    0.8035       0.798947  ,   dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  pubmed         1.0           1.0        1.0             1.0   0.771646
#
#    recall_test  acc_test  f1_score_test
# 0     0.781766    0.7785        0.77667  ,     dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  citeseer         1.0           1.0        1.0             1.0   0.651307
#
#    recall_test  acc_test  f1_score_test
# 0     0.652012    0.6764       0.651656  ,    dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  cornell    0.927224      0.908135   0.974713        0.917484   0.354914
#
#    recall_test  acc_test  f1_score_test
# 0     0.338861  0.532432       0.344153  ,   dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0   texas    0.972625      0.966848   0.991954        0.969666   0.296897
#
#    recall_test  acc_test  f1_score_test
# 0     0.277057  0.510811       0.284965  ,      dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  wisconsin    0.980174      0.955045   0.975833        0.967295   0.397882
#
#    recall_test  acc_test  f1_score_test
# 0     0.406152  0.535294        0.39667  ,   dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0   actor    0.594783      0.480918   0.538185        0.531375   0.260683
#
#    recall_test  acc_test  f1_score_test
# 0     0.249017  0.285921       0.253762  ,      dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  chameleon    0.817928      0.806324    0.80641        0.812068   0.646635
#
#    recall_test  acc_test  f1_score_test
# 0     0.634489  0.632237       0.640485  ]
# res     dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  squirrel    0.469282      0.474848   0.475527        0.467952   0.333126
#
#    recall_test  acc_test  f1_score_test
# 0     0.373366  0.376114       0.350042
# [  dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0    cora         1.0           1.0        1.0             1.0   0.781341
#
#    recall_test  acc_test  f1_score_test
# 0     0.817384    0.8035       0.798947  ,   dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  pubmed         1.0           1.0        1.0             1.0   0.771646
#
#    recall_test  acc_test  f1_score_test
# 0     0.781766    0.7785        0.77667  ,     dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  citeseer         1.0           1.0        1.0             1.0   0.651307
#
#    recall_test  acc_test  f1_score_test
# 0     0.652012    0.6764       0.651656  ,    dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  cornell    0.927224      0.908135   0.974713        0.917484   0.354914
#
#    recall_test  acc_test  f1_score_test
# 0     0.338861  0.532432       0.344153  ,   dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0   texas    0.972625      0.966848   0.991954        0.969666   0.296897
#
#    recall_test  acc_test  f1_score_test
# 0     0.277057  0.510811       0.284965  ,      dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  wisconsin    0.980174      0.955045   0.975833        0.967295   0.397882
#
#    recall_test  acc_test  f1_score_test
# 0     0.406152  0.535294        0.39667  ,   dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0   actor    0.594783      0.480918   0.538185        0.531375   0.260683
#
#    recall_test  acc_test  f1_score_test
# 0     0.249017  0.285921       0.253762  ,      dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  chameleon    0.817928      0.806324    0.80641        0.812068   0.646635
#
#    recall_test  acc_test  f1_score_test
# 0     0.634489  0.632237       0.640485  ,     dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  squirrel    0.469282      0.474848   0.475527        0.467952   0.333126
#
#    recall_test  acc_test  f1_score_test
# 0     0.373366  0.376114       0.350042  ]
# res     dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  facebook    0.931204      0.926199   0.933335        0.928694   0.923283
#
#    recall_test  acc_test  f1_score_test
# 0     0.917607  0.926346       0.920435
# [  dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0    cora         1.0           1.0        1.0             1.0   0.781341
#
#    recall_test  acc_test  f1_score_test
# 0     0.817384    0.8035       0.798947  ,   dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  pubmed         1.0           1.0        1.0             1.0   0.771646
#
#    recall_test  acc_test  f1_score_test
# 0     0.781766    0.7785        0.77667  ,     dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  citeseer         1.0           1.0        1.0             1.0   0.651307
#
#    recall_test  acc_test  f1_score_test
# 0     0.652012    0.6764       0.651656  ,    dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  cornell    0.927224      0.908135   0.974713        0.917484   0.354914
#
#    recall_test  acc_test  f1_score_test
# 0     0.338861  0.532432       0.344153  ,   dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0   texas    0.972625      0.966848   0.991954        0.969666   0.296897
#
#    recall_test  acc_test  f1_score_test
# 0     0.277057  0.510811       0.284965  ,      dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  wisconsin    0.980174      0.955045   0.975833        0.967295   0.397882
#
#    recall_test  acc_test  f1_score_test
# 0     0.406152  0.535294        0.39667  ,   dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0   actor    0.594783      0.480918   0.538185        0.531375   0.260683
#
#    recall_test  acc_test  f1_score_test
# 0     0.249017  0.285921       0.253762  ,      dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  chameleon    0.817928      0.806324    0.80641        0.812068   0.646635
#
#    recall_test  acc_test  f1_score_test
# 0     0.634489  0.632237       0.640485  ,     dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  squirrel    0.469282      0.474848   0.475527        0.467952   0.333126
#
#    recall_test  acc_test  f1_score_test
# 0     0.373366  0.376114       0.350042  ,     dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0  facebook    0.931204      0.926199   0.933335        0.928694   0.923283
#
#    recall_test  acc_test  f1_score_test
# 0     0.917607  0.926346       0.920435  ]

# %%
avg_gnn_scores = pd.concat(GNN_SCORES)
avg_gnn_scores
# Out:
#      dataset  prec_train  recall_train  acc_train  f1_score_train  prec_test  \
# 0       cora    1.000000      1.000000   1.000000        1.000000   0.781341
# 0     pubmed    1.000000      1.000000   1.000000        1.000000   0.771646
# 0   citeseer    1.000000      1.000000   1.000000        1.000000   0.651307
# 0    cornell    0.927224      0.908135   0.974713        0.917484   0.354914
# 0      texas    0.972625      0.966848   0.991954        0.969666   0.296897
# 0  wisconsin    0.980174      0.955045   0.975833        0.967295   0.397882
# 0      actor    0.594783      0.480918   0.538185        0.531375   0.260683
# 0  chameleon    0.817928      0.806324   0.806410        0.812068   0.646635
# 0   squirrel    0.469282      0.474848   0.475527        0.467952   0.333126
# 0   facebook    0.931204      0.926199   0.933335        0.928694   0.923283
#
#    recall_test  acc_test  f1_score_test
# 0     0.817384  0.803500       0.798947
# 0     0.781766  0.778500       0.776670
# 0     0.652012  0.676400       0.651656
# 0     0.338861  0.532432       0.344153
# 0     0.277057  0.510811       0.284965
# 0     0.406152  0.535294       0.396670
# 0     0.249017  0.285921       0.253762
# 0     0.634489  0.632237       0.640485
# 0     0.373366  0.376114       0.350042
# 0     0.917607  0.926346       0.920435

# %%
#gnn_scores.to_csv('/cluster/home/kamara/Explain/csv/node_classification/real/nc_real_gnn_scores.csv', index=False)

# %% [markdown]
# ## Node Classification - Synthetic

# %% [markdown]
# ### Sparsity

# %%
logdir = f'/cluster/home/kamara/checkpoints/node_classification/sparsity_mask/logs'
jsonpath = f'/cluster/home/kamara/checkpoints/node_classification/sparsity_mask/sweep.json'
infos, accuracy, fidelity = get_info(logdir)

print(list(accuracy.keys())[1])
name = '{none}_explainer_name={explainer_name}_sparsity={sparsity}_dataset={dataset}_hard_mask={hard_mask}'

ranges = get_param_ranges(jsonpath)
df_infos = get_df_results(infos, ranges, name, metrics = ['time', "number_of_edges", "mask_sparsity_init", "non_zero_values_init"])
#df_acc_top = get_df_results(accuracy_top, ranges, name, metrics = ['f1_score', 'recall', 'precision', 'ged', 'auc'])
df_acc = get_df_results(accuracy, ranges, name, metrics = ['f1_score', 'recall', 'precision'])
df_fid = get_df_results(fidelity, ranges, name, metrics = ['fidelity_acc+', 'fidelity_acc-', 'fidelity_prob+', 'fidelity_prob-', 'mask_sparsity', 'expl_edges'])

#scores = pd.concat([df_acc, df_fid], axis=1, join="inner")
#scores = pd.merge(df_acc_top, df_acc, suffixes=['_top', ''], on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "sparsity"])
scores = df_acc
scores = pd.merge(scores, df_fid, on=["dataset", "explainer_name", "num_test", "data_save_dir", "sparsity", "hard_mask"])
scores = pd.merge(scores, df_infos, on=["dataset", "explainer_name", "num_test", "data_save_dir", "sparsity", "hard_mask"])
scores
# Out:
# _explainer_name=random_sparsity=0_dataset=syn3_hard_mask=False
#     none_x explainer_name  sparsity dataset hard_mask explain_graph_x  \
# 0                  random     0.000    syn1      True           False
# 1                  random     0.000    syn1     False           False
# 2                  random     0.000    syn3      True           False
# 3                  random     0.000    syn3     False           False
# 4                  random     0.000    syn4      True           False
# ..     ...            ...       ...     ...       ...             ...
# 355             subgraphx     0.997    syn4     False           False
# 356             subgraphx     0.997    syn5      True           False
# 357             subgraphx     0.997    syn5     False           False
# 358             subgraphx     0.997    syn6      True           False
# 359             subgraphx     0.997    syn6     False           False
#
#      num_test data_save_dir  f1_score    recall  ...  fidelity_prob+  \
# 0         100          data  0.005822  1.000000  ...        0.511743
# 1         100          data  0.005822  1.000000  ...        0.229657
# 2         100          data  0.009404  1.000000  ...        0.010216
# 3         100          data  0.009404  1.000000  ...       -0.001905
# 4         100          data  0.012320  1.000000  ...        0.963050
# ..        ...           ...       ...       ...  ...             ...
# 355       100          data  0.654525  0.516667  ...        0.939375
# 356       100          data  0.557429  0.424167  ...        0.834673
# 357       100          data  0.560954  0.425833  ...        0.837413
# 358       100          data  0.661056  0.634000  ...        0.493473
# 359       100          data  0.661056  0.634000  ...        0.493473
#
#     fidelity_prob- mask_sparsity  expl_edges  none  explain_graph    time  \
# 0        -0.000995      0.000243     4109.00                False  0.0001
# 1         0.302100      0.000243     4109.00                False  0.0001
# 2        -0.000004      0.000197     5079.00                False  0.0001
# 3        -0.001902      0.000197     5079.00                False  0.0001
# 4         0.000000      0.000517     1935.00                False  0.0000
# ..             ...           ...         ...   ...            ...     ...
# 355       0.959117      0.997417        5.00                False  0.2794
# 356       0.853791      0.997144        9.74                False  4.7674
# 357       0.848950      0.997144        9.74                False  3.6892
# 358       0.183070      0.997829        8.57                False  0.9027
# 359       0.183070      0.997829        8.57                False  0.8231
#
#      number_of_edges  mask_sparsity_init non_zero_values_init
# 0               4110            0.000243              4109.00
# 1               4110            0.000243              4109.00
# 2               5080            0.000197              5079.00
# 3               5080            0.000197              5079.00
# 4               1936            0.000517              1935.00
# ..               ...                 ...                  ...
# 355             1936            0.995610                 8.50
# 356             3410            0.995595                15.02
# 357             3410            0.995601                15.00
# 358             3948            0.997822                 8.60
# 359             3948            0.997822                 8.60
#
# [360 rows x 25 columns]

# %%
res = scores.groupby(by=['dataset', 'sparsity', 'explainer_name', 'hard_mask']).mean()
res
# Out:
#                                            num_test  f1_score    recall  \
# dataset sparsity explainer_name hard_mask
# syn1    0.000    distance       False         100.0  0.005823  1.000000
#                                 True          100.0  0.005823  1.000000
#                  gnnexplainer   False         100.0  0.444157  1.000000
#                                 True          100.0  0.444157  1.000000
#                  ig             False         100.0  0.005099  0.873333
# ...                                             ...       ...       ...
# syn6    0.997    random         True          100.0  0.002500  0.004000
#                  sa             False         100.0  0.000000  0.000000
#                                 True          100.0  0.000000  0.000000
#                  subgraphx      False         100.0  0.661056  0.634000
#                                 True          100.0  0.661056  0.634000
#
#                                            precision  fidelity_acc+  \
# dataset sparsity explainer_name hard_mask
# syn1    0.000    distance       False       0.002920           0.28
#                                 True        0.002920           0.76
#                  gnnexplainer   False       0.328940           0.56
#                                 True        0.328940           0.76
#                  ig             False       0.002557           0.35
# ...                                              ...            ...
# syn6    0.997    random         True        0.001818           0.00
#                  sa             False       0.000000           0.00
#                                 True        0.000000           0.00
#                  subgraphx      False       0.700500           0.54
#                                 True        0.700500           0.54
#
#                                            fidelity_acc-  fidelity_prob+  \
# dataset sparsity explainer_name hard_mask
# syn1    0.000    distance       False               0.64        0.102925
#                                 True                0.00        0.511743
#                  gnnexplainer   False               0.56        0.296190
#                                 True                0.00        0.511743
#                  ig             False               0.64        0.042806
# ...                                                  ...             ...
# syn6    0.997    random         True                0.64       -0.000110
#                  sa             False               0.64        0.001296
#                                 True                0.64        0.001296
#                  subgraphx      False               0.20        0.493473
#                                 True                0.20        0.493473
#
#                                            fidelity_prob-  mask_sparsity  \
# dataset sparsity explainer_name hard_mask
# syn1    0.000    distance       False            0.358078       0.010139
#                                 True             0.000000       0.010139
#                  gnnexplainer   False            0.348878       0.953431
#                                 True             0.000000       0.953431
#                  ig             False            0.412742       0.002487
# ...                                                   ...            ...
# syn6    0.997    random         True             0.599028       0.997214
#                  sa             False            0.599028       0.997214
#                                 True             0.599028       0.997214
#                  subgraphx      False            0.183070       0.997829
#                                 True             0.183070       0.997829
#
#                                            expl_edges    time  \
# dataset sparsity explainer_name hard_mask
# syn1    0.000    distance       False         4068.33  0.0127
#                                 True          4068.33  0.0135
#                  gnnexplainer   False          191.40  2.6306
#                                 True           191.40  2.7273
#                  ig             False         4099.78  0.1824
# ...                                               ...     ...
# syn6    0.997    random         True            11.00  0.0000
#                  sa             False           11.00  0.0031
#                                 True            11.00  0.0032
#                  subgraphx      False            8.57  0.8231
#                                 True             8.57  0.9027
#
#                                            number_of_edges  \
# dataset sparsity explainer_name hard_mask
# syn1    0.000    distance       False               4110.0
#                                 True                4110.0
#                  gnnexplainer   False               4110.0
#                                 True                4110.0
#                  ig             False               4110.0
# ...                                                    ...
# syn6    0.997    random         True                3948.0
#                  sa             False               3948.0
#                                 True                3948.0
#                  subgraphx      False               3948.0
#                                 True                3948.0
#
#                                            mask_sparsity_init  \
# dataset sparsity explainer_name hard_mask
# syn1    0.000    distance       False                0.010139
#                                 True                 0.010139
#                  gnnexplainer   False                0.953431
#                                 True                 0.953431
#                  ig             False                0.002487
# ...                                                       ...
# syn6    0.997    random         True                 0.000253
#                  sa             False                0.000750
#                                 True                 0.000750
#                  subgraphx      False                0.997822
#                                 True                 0.997822
#
#                                            non_zero_values_init
# dataset sparsity explainer_name hard_mask
# syn1    0.000    distance       False                   4068.33
#                                 True                    4068.33
#                  gnnexplainer   False                    191.40
#                                 True                     191.40
#                  ig             False                   4099.78
# ...                                                         ...
# syn6    0.997    random         True                    3947.00
#                  sa             False                   3945.04
#                                 True                    3945.04
#                  subgraphx      False                      8.60
#                                 True                       8.60
#
# [360 rows x 14 columns]

# %%
res = res.reset_index()
res.to_csv('/cluster/home/kamara/Explain/csv/node_classification/sparsity_mask_nc.csv', index=False)

# %% [markdown]
# ### Threshold

# %%
logdir = f'/cluster/home/kamara/checkpoints/threshold/logs'
jsonpath = f'/cluster/home/kamara/Explain/config_threshold.json'
infos, accuracy, fidelity = get_info(logdir)

print(list(accuracy.keys())[1])
name = '{none}_explainer_name={explainer_name}_threshold={threshold}_dataset={dataset}'

ranges = get_param_ranges(jsonpath)
df_infos = get_df_results(infos, ranges, name, metrics = ['time', "number_of_edges", "mask_sparsity_init", "non_zero_values_init"])
#df_acc_top = get_df_results(accuracy_top, ranges, name, metrics = ['f1_score', 'recall', 'precision', 'ged', 'auc'])
df_acc = get_df_results(accuracy, ranges, name, metrics = ['f1_score', 'recall', 'precision', 'auc'])
df_fid = get_df_results(fidelity, ranges, name, metrics = ['fidelity_acc+', 'fidelity_acc-', 'fidelity_prob+', 'fidelity_prob-', 'mask_sparsity', 'expl_edges'])

#scores = pd.concat([df_acc, df_fid], axis=1, join="inner")
#scores = pd.merge(df_acc_top, df_acc, suffixes=['_top', ''], on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "sparsity"])
scores = df_acc
scores = pd.merge(scores, df_fid, on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "threshold"])
scores = pd.merge(scores, df_infos, on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "threshold"])
# Out:
# _explainer_name=random_threshold=0.5_dataset=syn3

# %%
res = scores.groupby(by=['dataset', 'threshold', 'explainer_name']).mean()
res
# Out:
#                                   num_test_nodes  gpu  f1_score    recall  \
# dataset threshold explainer_name
# syn1    0.5       distance                 100.0  1.0  0.563576  0.413333
#                   gnnexplainer             100.0  1.0  0.365325  0.650000
#                   ig_node                  100.0  1.0  0.446275  0.436667
#                   occlusion                100.0  1.0  0.001630  0.240000
#                   pagerank                 100.0  1.0  0.880128  0.861667
# ...                                          ...  ...       ...       ...
# syn6    0.9       pagerank                 100.0  1.0  0.423048  0.314000
#                   pgmexplainer             100.0  1.0  0.380048  0.376000
#                   random                   100.0  1.0  0.005078  0.194000
#                   sa_node                  100.0  1.0  0.180224  0.112000
#                   subgraphx                100.0  1.0  0.773444  0.744000
#
#                                   precision       auc  fidelity_acc+  \
# dataset threshold explainer_name
# syn1    0.5       distance         0.939500  0.603303           0.05
#                   gnnexplainer     0.355707  0.720080           0.44
#                   ig_node          0.459524  0.478424           0.05
#                   occlusion        0.000818  0.062967           0.48
#                   pagerank         0.903381  0.930774           0.53
# ...                                     ...       ...            ...
# syn6    0.9       pagerank         0.957333  0.656954           0.63
#                   pgmexplainer     0.560708  0.687330           0.57
#                   random           0.002573  0.500879           0.07
#                   sa_node          0.532635  0.336103           0.01
#                   subgraphx        0.811500  0.871812           0.62
#
#                                   fidelity_acc-  fidelity_prob+  \
# dataset threshold explainer_name
# syn1    0.5       distance                 0.53       -0.123116
#                   gnnexplainer             0.29        0.285291
#                   ig_node                  0.53        0.024774
#                   occlusion                0.05        0.433345
#                   pagerank                 0.05        0.487905
# ...                                         ...             ...
# syn6    0.9       pagerank                 0.36        0.523581
#                   pgmexplainer             0.23        0.488138
#                   random                   0.63        0.060975
#                   sa_node                  0.64       -0.014498
#                   subgraphx                0.05        0.567656
#
#                                   fidelity_prob-  mask_sparsity  expl_edges  \
# dataset threshold explainer_name
# syn1    0.5       distance              0.487905       0.999336        2.73
#                   gnnexplainer          0.151176       0.941944      238.61
#                   ig_node               0.445705       0.520219     1971.90
#                   occlusion             0.009594       0.062044     3855.00
#                   pagerank             -0.018173       0.997202       11.50
# ...                                          ...            ...         ...
# syn6    0.9       pagerank              0.326768       0.999103        3.54
#                   pgmexplainer          0.253975       0.997219       10.98
#                   random                0.577516       0.899491      396.81
#                   sa_node               0.589573       0.560998     1733.18
#                   subgraphx             0.052988       0.997741        8.92
#
#                                     time  number_of_edges  mask_sparsity_init  \
# dataset threshold explainer_name
# syn1    0.5       distance        0.0162           4110.0            0.009175
#                   gnnexplainer    2.6174           4110.0            0.937606
#                   ig_node         0.1674           4110.0            0.050822
#                   occlusion       0.7179           4110.0            0.000243
#                   pagerank        0.0198           4110.0            0.000487
# ...                                  ...              ...                 ...
# syn6    0.9       pagerank        0.0209           3948.0            0.000507
#                   pgmexplainer    3.8762           3948.0            0.780314
#                   random          0.0000           3948.0            0.000253
#                   sa_node         0.0027           3948.0            0.000750
#                   subgraphx       3.1119           3948.0            0.977741
#
#                                   non_zero_values_init
# dataset threshold explainer_name
# syn1    0.5       distance                     4072.29
#                   gnnexplainer                  256.44
#                   ig_node                      3901.12
#                   occlusion                    4109.00
#                   pagerank                     4108.00
# ...                                                ...
# syn6    0.9       pagerank                     3946.00
#                   pgmexplainer                  867.32
#                   random                       3947.00
#                   sa_node                      3945.04
#                   subgraphx                       8.92
#
# [135 rows x 16 columns]

# %%
res = res.reset_index()
res.to_csv('/cluster/home/kamara/Explain/csv/threshold.csv', index=False)

# %% [markdown]
# ### Topk

# %%
logdir = f'/cluster/scratch/kamara/checkpoints/node_classification/syn/topk/topk_syn_1/logs'
jsonpath = f'/cluster/home/kamara/Explain/configs/syn/topk/config_syn_topk_1expe.json'
infos, initial_mask_infos, transformed_mask_infos, fidelity = get_info(logdir)
gnn_train, gnn_test = get_gnn_info(logdir)

print(list(fidelity.keys())[1])
ranges = get_param_ranges(jsonpath)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_23964/866396562.py in <module>
#       4 gnn_train, gnn_test = get_gnn_info(logdir)
#       5
# ----> 6 print(list(fidelity.keys())[1])
#       7 ranges = get_param_ranges(jsonpath)
#
# IndexError: list index out of range

# %%
#name = '{none}_explainer_name={explainer_name}_sparsity={sparsity}_dataset={dataset}_true_label_as_target={true_label_as_target}_hard_mask={hard_mask}'
name = '{none}_explainer_name={explainer_name}_dataset={dataset}_true_label_as_target={true_label_as_target}_hard_mask={hard_mask}'

# %%
df_infos = get_df_results(infos, ranges, name, metrics = ['time', "number_of_edges"])
df_initial_mask_infos = get_df_results(initial_mask_infos, ranges, name, metrics = ['mask_size', "mask_entropy", "max_avg"])
df_tranformed_mask_infos = get_df_results(transformed_mask_infos, ranges, name, metrics = ['mask_size', "mask_entropy", "max_avg", "topk"], selection="all")
df_fid = get_df_results(fidelity, ranges, name, metrics = ['fidelity_acc+', 'fidelity_acc-', 'fidelity_prob+', 'fidelity_prob-', 
                                                           'fidelity_gnn_acc+', 'fidelity_gnn_acc-', 'fidelity_gnn_prob+', 'fidelity_gnn_prob-', 'topk'], selection="all")

# %%
df_mask_infos = pd.merge(df_initial_mask_infos, df_tranformed_mask_infos, suffixes=['_init', '_transf'], on=["dataset", "explainer_name", "num_test", "data_save_dir", "seed", "true_label_as_target", "hard_mask"])
scores = df_fid
scores = pd.merge(scores, df_mask_infos, on=["dataset", "explainer_name", "num_test", "data_save_dir", "seed", "true_label_as_target", "hard_mask", "topk"])
scores = pd.merge(scores, df_infos, on=["dataset", "explainer_name", "num_test", "data_save_dir", "seed", "true_label_as_target", "hard_mask"])
scores
#scores.to_csv('/cluster/home/kamara/Explain/csv/node_classification/real/nc_real_sparsity_all.csv', index=False)
# Out:
#      none_x explainer_name    dataset             topk_list_x  \
# 0                   random       cora  1,5,10,15,20,25,50,100
# 1                   random       cora  1,5,10,15,20,25,50,100
# 2                   random       cora  1,5,10,15,20,25,50,100
# 3                   random       cora  1,5,10,15,20,25,50,100
# 4                   random       cora  1,5,10,15,20,25,50,100
# ...     ...            ...        ...                     ...
# 2464          pgmexplainer  wisconsin  1,5,10,15,20,25,50,100
# 2465          pgmexplainer  wisconsin  1,5,10,15,20,25,50,100
# 2466          pgmexplainer  wisconsin  1,5,10,15,20,25,50,100
# 2467          pgmexplainer  wisconsin  1,5,10,15,20,25,50,100
# 2468          pgmexplainer  wisconsin  1,5,10,15,20,25,50,100
#
#      true_label_as_target hard_mask explain_graph_x  num_test  seed  \
# 0                    True      True           False       100     0
# 1                    True      True           False       100     0
# 2                    True      True           False       100     0
# 3                    True      True           False       100     0
# 4                    True      True           False       100     0
# ...                   ...       ...             ...       ...   ...
# 2464                False     False           False       100     0
# 2465                False     False           False       100     0
# 2466                False     False           False       100     0
# 2467                False     False           False       100     0
# 2468                False     False           False       100     0
#
#      data_save_dir  ...        topk_list_transf  explain_graph_transf  \
# 0             data  ...  1,5,10,15,20,25,50,100                 False
# 1             data  ...  1,5,10,15,20,25,50,100                 False
# 2             data  ...  1,5,10,15,20,25,50,100                 False
# 3             data  ...  1,5,10,15,20,25,50,100                 False
# 4             data  ...  1,5,10,15,20,25,50,100                 False
# ...            ...  ...                     ...                   ...
# 2464          data  ...  1,5,10,15,20,25,50,100                 False
# 2465          data  ...  1,5,10,15,20,25,50,100                 False
# 2466          data  ...  1,5,10,15,20,25,50,100                 False
# 2467          data  ...  1,5,10,15,20,25,50,100                 False
# 2468          data  ...  1,5,10,15,20,25,50,100                 False
#
#       mask_size_transf  mask_entropy_transf  max_avg_transf  none_y  \
# 0                 1.00             0.000000        1.000000
# 1                 5.00             1.609438        0.999720
# 2                10.00             2.302585        0.999468
# 3                15.00             2.708050        0.999279
# 4                20.00             2.995732        0.999034
# ...                ...                  ...             ...     ...
# 2464             15.00             2.694923        0.836447
# 2465             19.98             2.979302        0.810814
# 2466             24.82             3.193790        0.798190
# 2467             48.76             3.847085        0.689827
# 2468             95.11             4.465277        0.574972
#
#                  topk_list_y  explain_graph_y    time number_of_edges
# 0     1,5,10,15,20,25,50,100            False  0.0002           13264
# 1     1,5,10,15,20,25,50,100            False  0.0002           13264
# 2     1,5,10,15,20,25,50,100            False  0.0002           13264
# 3     1,5,10,15,20,25,50,100            False  0.0002           13264
# 4     1,5,10,15,20,25,50,100            False  0.0002           13264
# ...                      ...              ...     ...             ...
# 2464  1,5,10,15,20,25,50,100            False  2.4069            1151
# 2465  1,5,10,15,20,25,50,100            False  2.4069            1151
# 2466  1,5,10,15,20,25,50,100            False  2.4069            1151
# 2467  1,5,10,15,20,25,50,100            False  2.4069            1151
# 2468  1,5,10,15,20,25,50,100            False  2.4069            1151
#
# [2469 rows x 36 columns]

# %%
res = scores.groupby(by=['dataset', "true_label_as_target", "hard_mask", 'topk', 'explainer_name']).mean()
res = res.drop(columns=['seed'])
#res[['mask_size', "mask_entropy", "max_avg"]]
res
# Out:
#                                                                    num_test  \
# dataset   true_label_as_target hard_mask topk  explainer_name
# actor     False                False     1.0   basic_gnnexplainer     100.0
#                                                distance               100.0
#                                                gnnexplainer           100.0
#                                                gradcam                100.0
#                                                occlusion              100.0
# ...                                                                     ...
# wisconsin True                 True      100.0 occlusion              100.0
#                                                pagerank               100.0
#                                                pgmexplainer           100.0
#                                                random                 100.0
#                                                sa                     100.0
#
#                                                                    fidelity_acc+  \
# dataset   true_label_as_target hard_mask topk  explainer_name
# actor     False                False     1.0   basic_gnnexplainer          -1.00
#                                                distance                    -1.00
#                                                gnnexplainer                -1.00
#                                                gradcam                     -1.00
#                                                occlusion                   -1.00
# ...                                                                          ...
# wisconsin True                 True      100.0 occlusion                    0.67
#                                                pagerank                     0.70
#                                                pgmexplainer                 0.63
#                                                random                       0.20
#                                                sa                           0.70
#
#                                                                    fidelity_acc-  \
# dataset   true_label_as_target hard_mask topk  explainer_name
# actor     False                False     1.0   basic_gnnexplainer          -1.00
#                                                distance                    -1.00
#                                                gnnexplainer                -1.00
#                                                gradcam                     -1.00
#                                                occlusion                   -1.00
# ...                                                                          ...
# wisconsin True                 True      100.0 occlusion                    0.13
#                                                pagerank                     0.09
#                                                pgmexplainer                 0.13
#                                                random                       0.55
#                                                sa                           0.45
#
#                                                                    fidelity_prob+  \
# dataset   true_label_as_target hard_mask topk  explainer_name
# actor     False                False     1.0   basic_gnnexplainer       -1.000000
#                                                distance                 -1.000000
#                                                gnnexplainer             -1.000000
#                                                gradcam                  -1.000000
#                                                occlusion                -1.000000
# ...                                                                           ...
# wisconsin True                 True      100.0 occlusion                 0.133390
#                                                pagerank                  0.117450
#                                                pgmexplainer              0.108370
#                                                random                   -0.008910
#                                                sa                        0.140986
#
#                                                                    fidelity_prob-  \
# dataset   true_label_as_target hard_mask topk  explainer_name
# actor     False                False     1.0   basic_gnnexplainer       -1.000000
#                                                distance                 -1.000000
#                                                gnnexplainer             -1.000000
#                                                gradcam                  -1.000000
#                                                occlusion                -1.000000
# ...                                                                           ...
# wisconsin True                 True      100.0 occlusion                -0.034419
#                                                pagerank                 -0.001679
#                                                pgmexplainer             -0.005719
#                                                random                    0.088731
#                                                sa                        0.066443
#
#                                                                    fidelity_gnn_acc+  \
# dataset   true_label_as_target hard_mask topk  explainer_name
# actor     False                False     1.0   basic_gnnexplainer               0.00
#                                                distance                         0.07
#                                                gnnexplainer                     0.43
#                                                gradcam                          0.16
#                                                occlusion                        0.38
# ...                                                                              ...
# wisconsin True                 True      100.0 occlusion                       -1.00
#                                                pagerank                        -1.00
#                                                pgmexplainer                    -1.00
#                                                random                          -1.00
#                                                sa                              -1.00
#
#                                                                    fidelity_gnn_acc-  \
# dataset   true_label_as_target hard_mask topk  explainer_name
# actor     False                False     1.0   basic_gnnexplainer               0.42
#                                                distance                         0.39
#                                                gnnexplainer                     0.41
#                                                gradcam                          0.38
#                                                occlusion                        0.39
# ...                                                                              ...
# wisconsin True                 True      100.0 occlusion                       -1.00
#                                                pagerank                        -1.00
#                                                pgmexplainer                    -1.00
#                                                random                          -1.00
#                                                sa                              -1.00
#
#                                                                    fidelity_gnn_prob+  \
# dataset   true_label_as_target hard_mask topk  explainer_name
# actor     False                False     1.0   basic_gnnexplainer            0.002503
#                                                distance                      0.016935
#                                                gnnexplainer                  0.074586
#                                                gradcam                       0.037296
#                                                occlusion                     0.062185
# ...                                                                               ...
# wisconsin True                 True      100.0 occlusion                    -1.000000
#                                                pagerank                     -1.000000
#                                                pgmexplainer                 -1.000000
#                                                random                       -1.000000
#                                                sa                           -1.000000
#
#                                                                    fidelity_gnn_prob-  \
# dataset   true_label_as_target hard_mask topk  explainer_name
# actor     False                False     1.0   basic_gnnexplainer            0.113221
#                                                distance                      0.106466
#                                                gnnexplainer                  0.098053
#                                                gradcam                       0.082071
#                                                occlusion                     0.083376
# ...                                                                               ...
# wisconsin True                 True      100.0 occlusion                    -1.000000
#                                                pagerank                     -1.000000
#                                                pgmexplainer                 -1.000000
#                                                random                       -1.000000
#                                                sa                           -1.000000
#
#                                                                    mask_size_init  \
# dataset   true_label_as_target hard_mask topk  explainer_name
# actor     False                False     1.0   basic_gnnexplainer         1208.43
#                                                distance                  60913.74
#                                                gnnexplainer               1208.43
#                                                gradcam                   39772.57
#                                                occlusion                  1208.25
# ...                                                                           ...
# wisconsin True                 True      100.0 occlusion                   290.10
#                                                pagerank                   1082.04
#                                                pgmexplainer                517.66
#                                                random                     1148.96
#                                                sa                          829.70
#
#                                                                    mask_entropy_init  \
# dataset   true_label_as_target hard_mask topk  explainer_name
# actor     False                False     1.0   basic_gnnexplainer           5.300966
#                                                distance                    10.960461
#                                                gnnexplainer                 4.690754
#                                                gradcam                      8.478164
#                                                occlusion                    5.610678
# ...                                                                              ...
# wisconsin True                 True      100.0 occlusion                    4.690044
#                                                pagerank                     5.922828
#                                                pgmexplainer                 5.756787
#                                                random                       6.853682
#                                                sa                           6.272720
#
#                                                                    max_avg_init  \
# dataset   true_label_as_target hard_mask topk  explainer_name
# actor     False                False     1.0   basic_gnnexplainer      0.696889
#                                                distance                0.110511
#                                                gnnexplainer            0.051125
#                                                gradcam                 0.149737
#                                                occlusion               0.479297
# ...                                                                         ...
# wisconsin True                 True      100.0 occlusion               0.418526
#                                                pagerank                0.001028
#                                                pgmexplainer            0.298066
#                                                random                  0.490891
#                                                sa                      0.566140
#
#                                                                    mask_size_transf  \
# dataset   true_label_as_target hard_mask topk  explainer_name
# actor     False                False     1.0   basic_gnnexplainer              1.00
#                                                distance                        1.00
#                                                gnnexplainer                    1.00
#                                                gradcam                         1.00
#                                                occlusion                       1.00
# ...                                                                             ...
# wisconsin True                 True      100.0 occlusion                      78.65
#                                                pagerank                      100.00
#                                                pgmexplainer                   95.11
#                                                random                        100.00
#                                                sa                             99.23
#
#                                                                    mask_entropy_transf  \
# dataset   true_label_as_target hard_mask topk  explainer_name
# actor     False                False     1.0   basic_gnnexplainer             0.000000
#                                                distance                       0.000000
#                                                gnnexplainer                   0.000000
#                                                gradcam                        0.000000
#                                                occlusion                      0.000000
# ...                                                                                ...
# wisconsin True                 True      100.0 occlusion                      3.744467
#                                                pagerank                       4.446748
#                                                pgmexplainer                   4.465948
#                                                random                         4.604816
#                                                sa                             4.504462
#
#                                                                    max_avg_transf  \
# dataset   true_label_as_target hard_mask topk  explainer_name
# actor     False                False     1.0   basic_gnnexplainer        1.000000
#                                                distance                  1.000000
#                                                gnnexplainer              1.000000
#                                                gradcam                   1.000000
#                                                occlusion                 1.000000
# ...                                                                           ...
# wisconsin True                 True      100.0 occlusion                 0.420155
#                                                pagerank                  0.206235
#                                                pgmexplainer              0.550145
#                                                random                    0.943692
#                                                sa                        0.643644
#
#                                                                      time  \
# dataset   true_label_as_target hard_mask topk  explainer_name
# actor     False                False     1.0   basic_gnnexplainer  3.8270
#                                                distance            0.8971
#                                                gnnexplainer        7.4523
#                                                gradcam             0.0079
#                                                occlusion           3.3738
# ...                                                                   ...
# wisconsin True                 True      100.0 occlusion           0.6651
#                                                pagerank            0.0262
#                                                pgmexplainer        2.5542
#                                                random              0.0001
#                                                sa                  0.0048
#
#                                                                    number_of_edges
# dataset   true_label_as_target hard_mask topk  explainer_name
# actor     False                False     1.0   basic_gnnexplainer          60918.0
#                                                distance                    60918.0
#                                                gnnexplainer                60918.0
#                                                gradcam                     60918.0
#                                                occlusion                   60918.0
# ...                                                                            ...
# wisconsin True                 True      100.0 occlusion                    1151.0
#                                                pagerank                     1151.0
#                                                pgmexplainer                 1151.0
#                                                random                       1151.0
#                                                sa                           1151.0
#
# [2469 rows x 17 columns]

# %%
res = res.reset_index()
res.to_csv('/cluster/home/kamara/Explain/csv/node_classification/syn/topk/nc_syn_topk_1expe.csv', index=False)

# %%
logdir = f'/cluster/home/kamara/checkpoints/topk/logs'
jsonpath = f'/cluster/home/kamara/Explain/config_topk.json'
infos, accuracy, fidelity = get_info(logdir)

print(list(accuracy.keys())[1])
name = '{none}_explainer_name={explainer_name}_topk={topk}_dataset={dataset}'

ranges = get_param_ranges(jsonpath)
df_infos = get_df_results(infos, ranges, name, metrics = ['time', "number_of_edges", "mask_sparsity_init", "non_zero_values_init"])
#df_acc_top = get_df_results(accuracy_top, ranges, name, metrics = ['f1_score', 'recall', 'precision', 'ged', 'auc'])
df_acc = get_df_results(accuracy, ranges, name, metrics = ['f1_score', 'recall', 'precision', 'auc'])
df_fid = get_df_results(fidelity, ranges, name, metrics = ['fidelity_acc+', 'fidelity_acc-', 'fidelity_prob+', 'fidelity_prob-', 'mask_sparsity', 'expl_edges'])

#scores = pd.concat([df_acc, df_fid], axis=1, join="inner")
#scores = pd.merge(df_acc_top, df_acc, suffixes=['_top', ''], on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "sparsity"])
scores = df_acc
scores = pd.merge(scores, df_fid, on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "topk"])
scores = pd.merge(scores, df_infos, on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "topk"])
# Out:
# _explainer_name=random_topk=10_dataset=syn5

# %%
res = scores.groupby(by=['dataset', 'topk', 'explainer_name']).mean()
res
# Out:
#                              num_test_nodes  gpu  f1_score    recall  \
# dataset topk explainer_name
# syn1    10   distance                 100.0  1.0  0.827099  0.895000
#              gnnexplainer             100.0  1.0  0.393343  0.440000
#              ig_node                  100.0  1.0  0.415758  0.381667
#              occlusion                100.0  1.0  0.040000  0.053333
#              pagerank                 100.0  1.0  0.863636  0.791667
# ...                                     ...  ...       ...       ...
# syn6    500  pagerank                 100.0  1.0  0.039216  1.000000
#              pgmexplainer             100.0  1.0  0.056839  0.978000
#              random                   100.0  1.0  0.005317  0.252000
#              sa_node                  100.0  1.0  0.003187  0.112000
#              subgraphx                100.0  1.0  0.765222  0.732000
#
#                              precision       auc  fidelity_acc+  \
# dataset topk explainer_name
# syn1    10   distance         0.777849  0.838573           0.38
#              gnnexplainer     0.360433  0.650486           0.21
#              ig_node          0.456667  0.690219           0.05
#              occlusion        0.032000  0.512180           0.25
#              pagerank         0.950000  0.895794           0.53
# ...                                ...       ...            ...
# syn6    500  pagerank         0.020000  0.999761           0.64
#              pgmexplainer     0.029418  0.976755           0.64
#              random           0.002687  0.505638           0.06
#              sa_node          0.001619  0.499740           0.01
#              subgraphx        0.813000 -1.000000           0.63
#
#                              fidelity_acc-  fidelity_prob+  fidelity_prob-  \
# dataset topk explainer_name
# syn1    10   distance                 0.33        0.327711        0.226022
#              gnnexplainer             0.52        0.079835        0.415991
#              ig_node                  0.53        0.054472        0.435937
#              occlusion                0.49        0.196120        0.447654
#              pagerank                 0.05        0.487905       -0.005111
# ...                                    ...             ...             ...
# syn6    500  pagerank                 0.01        0.589573        0.002842
#              pgmexplainer             0.02        0.589573        0.008439
#              random                   0.60        0.051902        0.568873
#              sa_node                  0.64        0.011466        0.589573
#              subgraphx                0.04        0.573782        0.044031
#
#                              mask_sparsity  expl_edges    time  \
# dataset topk explainer_name
# syn1    10   distance             0.997567       10.00  0.0162
#              gnnexplainer         0.997567       10.00  5.4596
#              ig_node              0.997567       10.00  0.1592
#              occlusion            0.997567       10.00  0.5690
#              pagerank             0.997567       10.00  0.0200
# ...                                    ...         ...     ...
# syn6    500  pagerank             0.873354      500.00  0.0275
#              pgmexplainer         0.903652      380.38  5.5268
#              random               0.873354      500.00  0.0000
#              sa_node              0.873354      500.00  0.0034
#              subgraphx            0.996484       13.88  3.9086
#
#                              number_of_edges  mask_sparsity_init  \
# dataset topk explainer_name
# syn1    10   distance                 4110.0            0.009175
#              gnnexplainer             4110.0            0.937606
#              ig_node                  4110.0            0.050822
#              occlusion                4110.0            0.000243
#              pagerank                 4110.0            0.000487
# ...                                      ...                 ...
# syn6    500  pagerank                 3948.0            0.000507
#              pgmexplainer             3948.0            0.780294
#              random                   3948.0            0.000253
#              sa_node                  3948.0            0.000750
#              subgraphx                3948.0            0.987751
#
#                              non_zero_values_init
# dataset topk explainer_name
# syn1    10   distance                     4072.29
#              gnnexplainer                  256.44
#              ig_node                      3901.12
#              occlusion                    4109.00
#              pagerank                     4108.00
# ...                                           ...
# syn6    500  pagerank                     3946.00
#              pgmexplainer                  867.40
#              random                       3947.00
#              sa_node                      3945.04
#              subgraphx                       8.88
#
# [225 rows x 16 columns]

# %%
res = res.reset_index()
res.to_csv('/cluster/home/kamara/Explain/csv/topk/syn/.csv', index=False)

# %% [markdown]
# ### Accuracy top

# %%
def get_info_top(logdir):
    infos, accuracy_top, accuracy, fidelity = {}, {}, {}, {}
    for filename in os.listdir(logdir):
        if filename.endswith(".stdout") and filename.startswith("_"):
            _, infos[filename.replace(".stdout", "")] = parseLogs(join(logdir, filename), kw='__infos:')
            _, accuracy_top[filename.replace(".stdout", "")] = parseLogs(join(logdir, filename), kw='__accuracy_top:')
            _, accuracy[filename.replace(".stdout", "")] = parseLogs(join(logdir, filename), kw='__accuracy:')
            _, fidelity[filename.replace(".stdout", "")] = parseLogs(join(logdir, filename), kw='__fidelity:')             
    return(infos, accuracy_top, accuracy, fidelity)

# %%
logdir = f'/cluster/home/kamara/checkpoints/top_edges/logs'
jsonpath = f'/cluster/home/kamara/Explain/config_top_edges.json'
infos, accuracy_top, accuracy, fidelity = get_info_top(logdir)

print(list(accuracy.keys())[1])
name = '{none}_explainer_name={explainer_name}_dataset={dataset}'

ranges = get_param_ranges(jsonpath)
df_infos = get_df_results(infos, ranges, name, metrics = ['time', "number_of_edges", "mask_sparsity_init", "non_zero_values_init"])
df_acc_top = get_df_results(accuracy_top, ranges, name, metrics = ['f1_score', 'recall', 'precision', 'ged', 'auc'])
df_acc = get_df_results(accuracy, ranges, name, metrics = ['f1_score', 'recall', 'precision', 'auc'])
df_fid = get_df_results(fidelity, ranges, name, metrics = ['fidelity_acc+', 'fidelity_acc-', 'fidelity_prob+', 'fidelity_prob-', 'mask_sparsity', 'expl_edges'])

#scores = pd.concat([df_acc, df_fid], axis=1, join="inner")
scores = pd.merge(df_acc_top, df_acc, suffixes=['_top', ''], on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu"])
scores = pd.merge(scores, df_fid, on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu"])
scores = pd.merge(scores, df_infos, on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu"])
# Out:
# _explainer_name=random_dataset=syn3

# %%
res = scores.groupby(by=['dataset', 'explainer_name']).mean()
res
# Out:
#                         num_test_nodes  gpu  f1_score_top  recall_top  \
# dataset explainer_name
# syn1    distance                 200.0  1.0      0.698606    0.686667
#         gnnexplainer             200.0  1.0      0.328182    0.320000
#         ig_node                  200.0  1.0      0.438333    0.438333
#         occlusion                200.0  1.0      0.054167    0.054167
#         pagerank                 200.0  1.0      0.868333    0.868333
#         pgmexplainer             200.0  1.0      0.568561    0.568333
#         random                   200.0  1.0      0.002500    0.002500
#         sa_node                  200.0  1.0      0.018788    0.018333
#         subgraphx                200.0  1.0      0.680818    0.642500
# syn3    distance                 200.0  1.0      0.722813    0.711250
#         gnnexplainer             200.0  1.0      0.610890    0.582083
#         ig_node                  200.0  1.0      0.000000    0.000000
#         occlusion                200.0  1.0      0.332303    0.320833
#         pagerank                 200.0  1.0      0.935674    0.933750
#         pgmexplainer             200.0  1.0      0.644131    0.642917
#         random                   200.0  1.0      0.004583    0.004583
#         sa_node                  200.0  1.0      0.000000    0.000000
#         subgraphx                200.0  1.0      0.568586    0.551667
# syn4    distance                 200.0  1.0      0.626712    0.615000
#         gnnexplainer             200.0  1.0      0.603697    0.588333
#         ig_node                  200.0  1.0      0.858530    0.855000
#         occlusion                200.0  1.0      0.607121    0.605000
#         pagerank                 200.0  1.0      0.839167    0.839167
#         pgmexplainer             200.0  1.0      0.934667    0.913333
#         random                   200.0  1.0      0.006667    0.006667
#         sa_node                  200.0  1.0      0.142727    0.140833
#         subgraphx                200.0  1.0      0.570909    0.549167
# syn5    distance                 200.0  1.0      0.674812    0.658333
#         gnnexplainer             200.0  1.0      0.621695    0.595417
#         ig_node                  200.0  1.0      0.806736    0.797917
#         occlusion                200.0  1.0      0.277803    0.276667
#         pagerank                 200.0  1.0      0.853287    0.851667
#         pgmexplainer             200.0  1.0      0.831922    0.822500
#         random                   200.0  1.0      0.009583    0.009583
#         sa_node                  200.0  1.0      0.835983    0.832083
#         subgraphx                200.0  1.0      0.486891    0.472917
# syn6    distance                 200.0  1.0      0.724667    0.724000
#         gnnexplainer             200.0  1.0      0.204222    0.204000
#         ig_node                  200.0  1.0      0.199222    0.198000
#         occlusion                200.0  1.0      0.023000    0.023000
#         pagerank                 200.0  1.0      0.663556    0.599000
#         pgmexplainer             200.0  1.0      0.381333    0.363000
#         random                   200.0  1.0      0.006000    0.006000
#         sa_node                  200.0  1.0      0.113222    0.109000
#         subgraphx                200.0  1.0      0.679333    0.655000
#
#                         precision_top  ged  auc_top  f1_score    recall  \
# dataset explainer_name
# syn1    distance             0.713333 -1.0     -1.0  0.005823  1.000000
#         gnnexplainer         0.338000 -1.0     -1.0  0.447901  1.000000
#         ig_node              0.438333 -1.0     -1.0  0.007163  0.915833
#         occlusion            0.054167 -1.0     -1.0  0.005822  1.000000
#         pagerank             0.868333 -1.0     -1.0  0.005825  1.000000
#         pgmexplainer         0.568833 -1.0     -1.0  0.164252  1.000000
#         random               0.002500 -1.0     -1.0  0.005822  1.000000
#         sa_node              0.019333 -1.0     -1.0  0.004854  0.833333
#         subgraphx            0.727750 -1.0     -1.0  0.774763  0.769167
# syn3    distance             0.736154 -1.0     -1.0  0.009405  1.000000
#         gnnexplainer         0.645116 -1.0     -1.0  0.751120  0.928333
#         ig_node              0.000000 -1.0     -1.0  0.008523  0.905833
#         occlusion            0.345841 -1.0     -1.0  0.064492  1.000000
#         pagerank             0.937962 -1.0     -1.0  0.009410  1.000000
#         pgmexplainer         0.645667 -1.0     -1.0  0.536775  0.995833
#         random               0.004583 -1.0     -1.0  0.009404  1.000000
#         sa_node              0.000000 -1.0     -1.0  0.008136  0.864583
#         subgraphx            0.590130 -1.0     -1.0  0.713287  0.606667
# syn4    distance             0.640917 -1.0     -1.0  0.012320  1.000000
#         gnnexplainer         0.622333 -1.0     -1.0  0.791955  1.000000
#         ig_node              0.863167 -1.0     -1.0  0.245143  1.000000
#         occlusion            0.609667 -1.0     -1.0  0.012320  1.000000
#         pagerank             0.839167 -1.0     -1.0  0.012335  1.000000
#         pgmexplainer         0.963417 -1.0     -1.0  0.644665  1.000000
#         random               0.006667 -1.0     -1.0  0.012320  1.000000
#         sa_node              0.145000 -1.0     -1.0  0.009900  0.802500
#         subgraphx            0.600250 -1.0     -1.0  0.711818  0.604167
# syn5    distance             0.693455 -1.0     -1.0  0.013978  1.000000
#         gnnexplainer         0.652467 -1.0     -1.0  0.778759  0.927500
#         ig_node              0.817220 -1.0     -1.0  0.518986  0.997917
#         occlusion            0.279076 -1.0     -1.0  0.013978  1.000000
#         pagerank             0.855212 -1.0     -1.0  0.013991  1.000000
#         pgmexplainer         0.842795 -1.0     -1.0  0.651047  1.000000
#         random               0.009583 -1.0     -1.0  0.013978  1.000000
#         sa_node              0.840523 -1.0     -1.0  0.651047  1.000000
#         subgraphx            0.503835 -1.0     -1.0  0.622345  0.487500
# syn6    distance             0.725500 -1.0     -1.0  0.005111  1.000000
#         gnnexplainer         0.204500 -1.0     -1.0  0.348225  1.000000
#         ig_node              0.200750 -1.0     -1.0  0.004309  0.850000
#         occlusion            0.023000 -1.0     -1.0  0.005053  1.000000
#         pagerank             0.744250 -1.0     -1.0  0.005056  1.000000
#         pgmexplainer         0.404250 -1.0     -1.0  0.053734  0.999000
#         random               0.006000 -1.0     -1.0  0.005053  1.000000
#         sa_node              0.118500 -1.0     -1.0  0.003570  0.706000
#         subgraphx            0.709750 -1.0     -1.0  0.760278  0.730000
#
#                         precision  ...  fidelity_acc+  fidelity_acc-  \
# dataset explainer_name             ...
# syn1    distance         0.002920  ...          0.555          0.000
#         gnnexplainer     0.351001  ...          0.555          0.000
#         ig_node          0.003618  ...          0.555          0.240
#         occlusion        0.002920  ...          0.555          0.000
#         pagerank         0.002921  ...          0.555          0.000
#         pgmexplainer     0.108257  ...          0.555          0.000
#         random           0.002920  ...          0.555          0.000
#         sa_node          0.002434  ...          0.555          0.295
#         subgraphx        0.809762  ...          0.450          0.230
# syn3    distance         0.004725  ...          0.000          0.000
#         gnnexplainer     0.708028  ...          0.000          0.000
#         ig_node          0.004281  ...          0.000          0.000
#         occlusion        0.053925  ...          0.000          0.000
#         pagerank         0.004727  ...          0.000          0.000
#         pgmexplainer     0.451593  ...          0.000          0.000
#         random           0.004724  ...          0.000          0.000
#         sa_node          0.004087  ...          0.000          0.000
#         subgraphx        0.918437  ...          0.000          0.000
# syn4    distance         0.006198  ...          1.000          0.000
#         gnnexplainer     0.672604  ...          1.000          0.000
#         ig_node          0.191910  ...          1.000          0.000
#         occlusion        0.006198  ...          1.000          0.240
#         pagerank         0.006206  ...          1.000          0.000
#         pgmexplainer     0.494818  ...          1.000          0.000
#         random           0.006198  ...          1.000          0.000
#         sa_node          0.004981  ...          1.000          0.345
#         subgraphx        0.870000  ...          1.000          1.000
# syn5    distance         0.007038  ...          1.000          0.000
#         gnnexplainer     0.697799  ...          1.000          0.000
#         ig_node          0.413972  ...          1.000          0.030
#         occlusion        0.007038  ...          1.000          0.000
#         pagerank         0.007045  ...          1.000          0.000
#         pgmexplainer     0.511138  ...          1.000          0.000
#         random           0.007038  ...          1.000          0.005
#         sa_node          0.511138  ...          1.000          0.000
#         subgraphx        0.899074  ...          1.000          0.775
# syn6    distance         0.002562  ...          0.615          0.000
#         gnnexplainer     0.227797  ...          0.615          0.000
#         ig_node          0.002160  ...          0.180          0.455
#         occlusion        0.002533  ...          1.000          0.005
#         pagerank         0.002534  ...          0.615          0.000
#         pgmexplainer     0.027928  ...          0.615          0.000
#         random           0.002533  ...          0.615          0.000
#         sa_node          0.001790  ...          0.605          0.030
#         subgraphx        0.803750  ...          0.595          0.020
#
#                         fidelity_prob+  fidelity_prob-  mask_sparsity  \
# dataset explainer_name
# syn1    distance              0.510232        0.000000       0.010618
#         gnnexplainer          0.510232        0.000000       0.926178
#         ig_node               0.507119        0.252697       0.040309
#         occlusion             0.356158       -0.096364       0.000243
#         pagerank              0.510232        0.000000       0.000487
#         pgmexplainer          0.510232       -0.000051       0.802185
#         random                0.510232       -0.000157       0.000243
#         sa_node               0.507088        0.276523       0.000487
#         subgraphx             0.408853        0.123255       0.927438
# syn3    distance              0.018805        0.000000       0.008171
#         gnnexplainer          0.018805        0.000000       0.974732
#         ig_node               0.018805       -0.000543       0.000459
#         occlusion            -0.002363       -0.000653       0.069017
#         pagerank              0.018805        0.000000       0.000604
#         pgmexplainer          0.018805       -0.000014       0.932626
#         random                0.018691       -0.000003       0.000197
#         sa_node              -0.003915       -0.000251       0.000640
#         subgraphx             0.017279       -0.003268       0.976892
# syn4    distance              0.983681        0.000000       0.004938
#         gnnexplainer          0.983681        0.000000       0.990108
#         ig_node               0.983681        0.000000       0.342707
#         occlusion             0.983686        0.235554       0.001082
#         pagerank              0.983681        0.000000       0.001235
#         pgmexplainer          0.983681        0.000000       0.985651
#         random                0.983681        0.000645       0.000517
#         sa_node               0.978033        0.335663       0.001405
#         subgraphx             0.983681        0.947216       0.995651
# syn5    distance              0.867460        0.000000       0.001151
#         gnnexplainer          0.867460        0.000000       0.989689
#         ig_node               0.867460        0.017587       0.748589
#         occlusion             0.867460        0.000000       0.002387
#         pagerank              0.867460        0.000000       0.000912
#         pgmexplainer          0.867460        0.000000       0.983340
#         random                0.867460        0.004491       0.000293
#         sa_node               0.867460        0.000000       0.983340
#         subgraphx             0.868554        0.594995       0.996176
# syn6    distance              0.567775        0.000000       0.034868
#         gnnexplainer          0.567775        0.000000       0.943673
#         ig_node               0.202089        0.386550       0.002768
#         occlusion             0.869832       -0.036690       0.000280
#         pagerank              0.567775        0.000000       0.000507
#         pgmexplainer          0.567775       -0.000646       0.808333
#         random                0.567775       -0.000354       0.000253
#         sa_node               0.554450        0.047458       0.000747
#         subgraphx             0.554217        0.026920       0.992718
#
#                         expl_edges    time  number_of_edges  \
# dataset explainer_name
# syn1    distance          4066.360  0.0171           4110.0
#         gnnexplainer       303.410  5.5336           4110.0
#         ig_node           3944.330  0.2779           4110.0
#         occlusion         4109.000  0.9668           4110.0
#         pagerank          4108.000  0.0252           4110.0
#         pgmexplainer       813.020  5.5697           4110.0
#         random            4109.000  0.0001           4110.0
#         sa_node           4108.000  0.0040           4110.0
#         subgraphx          298.230  2.2555           4110.0
# syn3    distance          5038.490  0.0225           5080.0
#         gnnexplainer       128.360  5.4594           5080.0
#         ig_node           5077.670  0.3112           5080.0
#         occlusion         4729.395  0.4339           5080.0
#         pagerank          5076.930  0.0308           5080.0
#         pgmexplainer       342.260  8.7511           5080.0
#         random            5079.000  0.0001           5080.0
#         sa_node           5076.750  0.0046           5080.0
#         subgraphx          117.390  1.9539           5080.0
# syn4    distance          1926.440  0.0093           1936.0
#         gnnexplainer        19.150  5.5851           1936.0
#         ig_node           1272.520  0.2950           1936.0
#         occlusion         1933.905  0.0784           1936.0
#         pagerank          1933.610  0.0152           1936.0
#         pgmexplainer        27.780  6.8016           1936.0
#         random            1935.000  0.0000           1936.0
#         sa_node           1933.280  0.0057           1936.0
#         subgraphx            8.420  0.3401           1936.0
# syn5    distance          3406.075  0.0162           3410.0
#         gnnexplainer        35.160  5.2330           3410.0
#         ig_node            857.310  0.3296           3410.0
#         occlusion         3401.860  0.1609           3410.0
#         pagerank          3406.890  0.0219           3410.0
#         pgmexplainer        56.810  9.6800           3410.0
#         random            3409.000  0.0001           3410.0
#         sa_node             56.810  0.0062           3410.0
#         subgraphx           13.040  3.6071           3410.0
# syn6    distance          3810.340  0.0176           3948.0
#         gnnexplainer       222.380  5.4235           3948.0
#         ig_node           3937.070  0.2812           3948.0
#         occlusion         3946.895  0.6272           3948.0
#         pagerank          3946.000  0.0234           3948.0
#         pgmexplainer       756.700  5.2963           3948.0
#         random            3947.000  0.0001           3948.0
#         sa_node           3945.050  0.0055           3948.0
#         subgraphx           28.750  3.8347           3948.0
#
#                         mask_sparsity_init  non_zero_values_init
# dataset explainer_name
# syn1    distance                  0.010618              4066.360
#         gnnexplainer              0.926178               303.410
#         ig_node                   0.040309              3944.330
#         occlusion                 0.000243              4109.000
#         pagerank                  0.000487              4108.000
#         pgmexplainer              0.802185               813.020
#         random                    0.000243              4109.000
#         sa_node                   0.000487              4108.000
#         subgraphx                 0.927438                10.530
# syn3    distance                  0.008171              5038.490
#         gnnexplainer              0.974732               128.360
#         ig_node                   0.000459              5077.670
#         occlusion                 0.069017              4729.395
#         pagerank                  0.000604              5076.930
#         pgmexplainer              0.932626               342.260
#         random                    0.000197              5079.000
#         sa_node                   0.000640              5076.750
#         subgraphx                 0.976892                15.790
# syn4    distance                  0.004938              1926.440
#         gnnexplainer              0.990108                19.150
#         ig_node                   0.342707              1272.520
#         occlusion                 0.001082              1933.905
#         pagerank                  0.001235              1933.610
#         pgmexplainer              0.985651                27.780
#         random                    0.000517              1935.000
#         sa_node                   0.001405              1933.280
#         subgraphx                 0.995651                 8.420
# syn5    distance                  0.001151              3406.075
#         gnnexplainer              0.989689                35.160
#         ig_node                   0.748589               857.310
#         occlusion                 0.002387              3401.860
#         pagerank                  0.000912              3406.890
#         pgmexplainer              0.983340                56.810
#         random                    0.000293              3409.000
#         sa_node                   0.983340                56.810
#         subgraphx                 0.996176                13.040
# syn6    distance                  0.034868              3810.340
#         gnnexplainer              0.943673               222.380
#         ig_node                   0.002768              3937.070
#         occlusion                 0.000280              3946.895
#         pagerank                  0.000507              3946.000
#         pgmexplainer              0.808333               756.700
#         random                    0.000253              3947.000
#         sa_node                   0.000747              3945.050
#         subgraphx                 0.992718                 9.010
#
# [45 rows x 21 columns]

# %%
res = res.reset_index()
res.to_csv('/cluster/home/kamara/Explain/csv/top_edges.csv', index=False)

# %% [markdown]
# ### Gc Layers

# %%
expe = "gc_layers"
logdir = f'/cluster/home/kamara/checkpoints/{expe}/logs'
jsonpath = f'/cluster/home/kamara/Explain/config_{expe}.json'
infos, accuracy, fidelity = get_info(logdir)
ranges = get_param_ranges(jsonpath)

print(list(accuracy.keys())[1])
name = '{none}_explainer_name={explainer_name}_num_gc_layers={num_gc_layers}'
# Out:
# _explainer_name=pagerank_num_gc_layers=1

# %%
df_acc = get_df_results(accuracy, ranges, name, metrics = ['f1_score', 'recall', 'precision', 'ged', 'auc'])
df_fid = get_df_results(fidelity, ranges, name, metrics = ['fidelity_acc+', 'fidelity_acc-', 'fidelity_prob+', 'fidelity_prob-'])
scores = pd.merge(df_acc, df_fid, on=["dataset", "num_gc_layers", "explainer_name", "num_test_nodes", "data_save_dir"])
scores = scores.groupby(by=['num_gc_layers', 'explainer_name']).mean()
scores
# Out:
#                               num_test_nodes  f1_score    recall  precision  \
# num_gc_layers explainer_name
# 2             gnnexplainer             200.0  0.682879  0.652500   0.720833
#               pagerank                 200.0  0.864167  0.864167   0.864167
# 3             gnnexplainer             200.0  0.329136  0.323333   0.336250
#               pagerank                 200.0  0.864167  0.864167   0.864167
# 4             gnnexplainer             200.0  0.055833  0.055833   0.055833
#               pagerank                 200.0  0.860000  0.860000   0.860000
# 5             gnnexplainer             200.0  0.006667  0.006667   0.006667
#               pagerank                 200.0  0.859167  0.859167   0.859167
# 6             gnnexplainer             200.0  0.003333  0.003333   0.003333
#               pagerank                 200.0  0.859167  0.859167   0.859167
#
#                                  ged       auc  fidelity_acc+  fidelity_acc-  \
# num_gc_layers explainer_name
# 2             gnnexplainer     4.065  0.998892          0.835          0.000
#               pagerank         2.435  0.999885          0.835          0.000
# 3             gnnexplainer     8.160  0.972214          0.610          0.015
#               pagerank         2.430  0.999885          0.610          0.000
# 4             gnnexplainer    12.475  0.834369          0.750          0.290
#               pagerank         2.515  0.999885          0.830          0.000
# 5             gnnexplainer    14.085  0.656783          0.550          0.575
#               pagerank         2.525  0.999883          0.640          0.005
# 6             gnnexplainer    14.345  0.575590          0.610          0.645
#               pagerank         2.525  0.999883          0.640          0.005
#
#                               fidelity_prob+  fidelity_prob-
# num_gc_layers explainer_name
# 2             gnnexplainer          0.650817        0.000000
#               pagerank              0.650817        0.000000
# 3             gnnexplainer          0.582833        0.014268
#               pagerank              0.589879       -0.000021
# 4             gnnexplainer          0.571764        0.246716
#               pagerank              0.640806        0.005695
# 5             gnnexplainer          0.512901        0.548674
#               pagerank              0.608210       -0.001958
# 6             gnnexplainer          0.545983        0.581469
#               pagerank              0.579183       -0.000794

# %% [markdown]
# ## Graph Classification

# %% [markdown]
# ### Sparsity

# %%
logdir = f'/cluster/home/kamara/checkpoints/graph_classification/sparsity_mask/logs'
jsonpath = f'/cluster/home/kamara/checkpoints/graph_classification/sparsity_mask/sweep.json'
infos, accuracy, fidelity = get_info(logdir)

print(list(accuracy.keys())[1])
name = '{none}_explainer_name={explainer_name}_sparsity={sparsity}_hard_mask={hard_mask}'

ranges = get_param_ranges(jsonpath)
df_infos = get_df_results(infos, ranges, name, metrics = ['time', "number_of_edges", "mask_sparsity_init", "non_zero_values_init"])
#df_acc_top = get_df_results(accuracy_top, ranges, name, metrics = ['f1_score', 'recall', 'precision', 'ged', 'auc'])
df_acc = get_df_results(accuracy, ranges, name, metrics = ['f1_score', 'recall', 'precision'])
df_fid = get_df_results(fidelity, ranges, name, metrics = ['fidelity_acc+', 'fidelity_acc-', 'fidelity_prob+', 'fidelity_prob-', 'mask_sparsity', 'expl_edges'])

#scores = pd.concat([df_acc, df_fid], axis=1, join="inner")
#scores = pd.merge(df_acc_top, df_acc, suffixes=['_top', ''], on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "sparsity"])
scores = df_acc
print(scores)
scores = pd.merge(scores, df_fid, on=["explainer_name", "num_test", "data_save_dir", "sparsity", "hard_mask"])
scores = pd.merge(scores, df_infos, on=["explainer_name", "num_test", "data_save_dir", "sparsity", "hard_mask"])
scores
# Out:
# _explainer_name=random_sparsity=0.7_hard_mask=True
# Empty DataFrame
# Columns: []
# Index: []
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_25111/280188014.py in <module>
#      16 scores = df_acc
#      17 print(scores)
# ---> 18 scores = pd.merge(scores, df_fid, on=["explainer_name", "num_test", "data_save_dir", "sparsity", "hard_mask"])
#      19 scores = pd.merge(scores, df_infos, on=["explainer_name", "num_test", "data_save_dir", "sparsity", "hard_mask"])
#      20 scores
#
# /cluster/apps/nss/gcc-8.2.0/python/3.8.5/x86_64/lib64/python3.8/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     103     validate: str | None = None,
#     104 ) -> DataFrame:
# --> 105     op = _MergeOperation(
#     106         left,
#     107         right,
#
# /cluster/apps/nss/gcc-8.2.0/python/3.8.5/x86_64/lib64/python3.8/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     696             self.right_join_keys,
#     697             self.join_names,
# --> 698         ) = self._get_merge_keys()
#     699
#     700         # validate the merge keys dtypes. We may need to coerce
#
# /cluster/apps/nss/gcc-8.2.0/python/3.8.5/x86_64/lib64/python3.8/site-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#    1106                         right_keys.append(rk)
#    1107                     if lk is not None:
# -> 1108                         left_keys.append(left._get_label_or_level_values(lk))
#    1109                         join_names.append(lk)
#    1110                     else:
#
# /cluster/apps/nss/gcc-8.2.0/python/3.8.5/x86_64/lib64/python3.8/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1777             values = self.axes[axis].get_level_values(key)._values
#    1778         else:
# -> 1779             raise KeyError(key)
#    1780
#    1781         # Check for duplicates
#
# KeyError: 'explainer_name'

# %%
res = scores.groupby(by=['dataset', 'sparsity', 'explainer_name', 'hard_mask']).mean()
res
# Out:
#                                            num_test  f1_score    recall  \
# dataset sparsity explainer_name hard_mask
# syn1    0.000    distance       False         100.0  0.005823  1.000000
#                                 True          100.0  0.005823  1.000000
#                  gnnexplainer   False         100.0  0.444157  1.000000
#                                 True          100.0  0.444157  1.000000
#                  ig             False         100.0  0.005099  0.873333
# ...                                             ...       ...       ...
# syn6    0.997    random         True          100.0  0.002500  0.004000
#                  sa             False         100.0  0.000000  0.000000
#                                 True          100.0  0.000000  0.000000
#                  subgraphx      False         100.0  0.661056  0.634000
#                                 True          100.0  0.661056  0.634000
#
#                                            precision  fidelity_acc+  \
# dataset sparsity explainer_name hard_mask
# syn1    0.000    distance       False       0.002920           0.28
#                                 True        0.002920           0.76
#                  gnnexplainer   False       0.328940           0.56
#                                 True        0.328940           0.76
#                  ig             False       0.002557           0.35
# ...                                              ...            ...
# syn6    0.997    random         True        0.001818           0.00
#                  sa             False       0.000000           0.00
#                                 True        0.000000           0.00
#                  subgraphx      False       0.700500           0.54
#                                 True        0.700500           0.54
#
#                                            fidelity_acc-  fidelity_prob+  \
# dataset sparsity explainer_name hard_mask
# syn1    0.000    distance       False               0.64        0.102925
#                                 True                0.00        0.511743
#                  gnnexplainer   False               0.56        0.296190
#                                 True                0.00        0.511743
#                  ig             False               0.64        0.042806
# ...                                                  ...             ...
# syn6    0.997    random         True                0.64       -0.000110
#                  sa             False               0.64        0.001296
#                                 True                0.64        0.001296
#                  subgraphx      False               0.20        0.493473
#                                 True                0.20        0.493473
#
#                                            fidelity_prob-  mask_sparsity  \
# dataset sparsity explainer_name hard_mask
# syn1    0.000    distance       False            0.358078       0.010139
#                                 True             0.000000       0.010139
#                  gnnexplainer   False            0.348878       0.953431
#                                 True             0.000000       0.953431
#                  ig             False            0.412742       0.002487
# ...                                                   ...            ...
# syn6    0.997    random         True             0.599028       0.997214
#                  sa             False            0.599028       0.997214
#                                 True             0.599028       0.997214
#                  subgraphx      False            0.183070       0.997829
#                                 True             0.183070       0.997829
#
#                                            expl_edges    time  \
# dataset sparsity explainer_name hard_mask
# syn1    0.000    distance       False         4068.33  0.0127
#                                 True          4068.33  0.0135
#                  gnnexplainer   False          191.40  2.6306
#                                 True           191.40  2.7273
#                  ig             False         4099.78  0.1824
# ...                                               ...     ...
# syn6    0.997    random         True            11.00  0.0000
#                  sa             False           11.00  0.0031
#                                 True            11.00  0.0032
#                  subgraphx      False            8.57  0.8231
#                                 True             8.57  0.9027
#
#                                            number_of_edges  \
# dataset sparsity explainer_name hard_mask
# syn1    0.000    distance       False               4110.0
#                                 True                4110.0
#                  gnnexplainer   False               4110.0
#                                 True                4110.0
#                  ig             False               4110.0
# ...                                                    ...
# syn6    0.997    random         True                3948.0
#                  sa             False               3948.0
#                                 True                3948.0
#                  subgraphx      False               3948.0
#                                 True                3948.0
#
#                                            mask_sparsity_init  \
# dataset sparsity explainer_name hard_mask
# syn1    0.000    distance       False                0.010139
#                                 True                 0.010139
#                  gnnexplainer   False                0.953431
#                                 True                 0.953431
#                  ig             False                0.002487
# ...                                                       ...
# syn6    0.997    random         True                 0.000253
#                  sa             False                0.000750
#                                 True                 0.000750
#                  subgraphx      False                0.997822
#                                 True                 0.997822
#
#                                            non_zero_values_init
# dataset sparsity explainer_name hard_mask
# syn1    0.000    distance       False                   4068.33
#                                 True                    4068.33
#                  gnnexplainer   False                    191.40
#                                 True                     191.40
#                  ig             False                   4099.78
# ...                                                         ...
# syn6    0.997    random         True                    3947.00
#                  sa             False                   3945.04
#                                 True                    3945.04
#                  subgraphx      False                      8.60
#                                 True                       8.60
#
# [360 rows x 14 columns]

# %%
res = res.reset_index()
res.to_csv('/cluster/home/kamara/Explain/csv/node_classification/sparsity_mask_nc.csv', index=False)
