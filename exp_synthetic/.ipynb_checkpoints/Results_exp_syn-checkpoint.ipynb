# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import seaborn as sns
from matplotlib import axes
import pandas as pd
import os
from os.path import join
import json
# Out:
# /cluster/apps/nss/gcc-6.3.0/python/3.7.4/x86_64/lib64/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import sys, os
sys.path.append('/cluster/home/kamara/Explain')
from clutils.nbutils import *
os.getcwd()
# Out:
# '/cluster/home/kamara/Explain/exp_synthetic'

# %%
def parseLogs(logfile, kw="rawlogs:"):
    logs = {}
    dicts = []
    with open(logfile) as f:
        for i_line, line in enumerate(f):
            pos = line.find(kw)
            if pos >= 0:
                pos += len(kw)
                pos_tensor = line.find("tensor(")
                while pos_tensor >= 0:
                    comma_end = line.find(",", pos_tensor)
                    tensor_end = line.find(")", pos_tensor)
                    line_new = line[:pos_tensor] + line[pos_tensor + len("tensor("):comma_end] + line[tensor_end+1:]
                    print("LINE", line)
                    print("NEW", line_new)
                    if len(line_new) >= len(line):
                        print("No line reduction")
                        break
                    line = line_new
                    pos_tensor = line.find("tensor(")
                    
                #print('line[pos:]', line[pos:])
                #print(ast.literal_eval(line[pos:]))
                kline = line[pos:].replace("'", "")
                kline = kline.replace("true", "True")

                try:
                    dic = ast.literal_eval(kline)
                except:
                    # print("Encountering weird patterns in logs")
                    # print("Line number %d" % i_line)
                    # print(line)
                    line = line.replace("nan,", "-1e8,")
                    line = line.replace("NaN", "-1e8")
                    try:
                        dic = ast.literal_eval(kline)
                    except:
                        print("Unable to replace NaNs")
                        print(line)
                        continue
                for k in dic.keys():
                    if k not in logs:
                        logs[k] = []
                    logs[k].append(dic[k])
                dicts.append(dic)

    df = pd.DataFrame(dicts)

    return logs, df

# %%
def get_info(logdir):
    accuracy, fidelity = {}, {}
    for filename in os.listdir(logdir):
        if filename.endswith(".stdout") and filename.startswith("_"):
            _, accuracy[filename.replace(".stdout", "")] = parseLogs(join(logdir, filename), kw='__accuracy:')
            _, fidelity[filename.replace(".stdout", "")] = parseLogs(join(logdir, filename), kw='__fidelity:')             
    return(accuracy, fidelity)

def get_param_ranges(jsonpath, dataset = ""):
    f = open(jsonpath,)
    data = json.load(f)
    ranges = data['params']
    ranges['none'] = ''
    return(ranges)

# %%
def get_df_results(logs, ranges, name, metrics, selection = 'last'):
    dicts = []
    for params_set in enumerateParams(ranges):
        key = name.format(**params_set)
        # if key in logs and len(logs[key]) >= 1 and metric in logs[key]:
        any_metric = (key in logs) and (len(logs[key]) >= 1) and any([metric in logs[key] for metric in metrics])
        if any_metric:
            if selection == 'all':
                for index, row in logs[key].iterrows():
                    metrics_dict = {
                        metric: select_value(row.to_frame().T, metric, 'last') if key in logs and len(logs[key]) >= 1 and metric in logs[key] else -1
                        for metric in metrics
                    }
                    dicts.append(dictmerge(params_set, metrics_dict))
                    
            else:
                metrics_dict = {
                    metric: select_value(logs[key], metric, selection) if key in logs and len(logs[key]) >= 1 and metric in logs[key] else -1
                    for metric in metrics
                }
                dicts.append(dictmerge(params_set, metrics_dict))

    df = pd.DataFrame(dicts)
    return df

# %%
expe = 'syn1'
logdir = f'/cluster/home/kamara/Explain/checkpoints/{expe}/logs'
jsonpath = f'/cluster/home/kamara/Explain/config_{expe}.json'

# %%
accuracy, fidelity = get_info(logdir)
ranges = get_param_ranges(jsonpath)
print(list(accuracy.keys())[1])
# Out:
# {"recall": 0.8699999999999999, "precision": 0.8699999999999999, "f1_score": 0.8699999999999999, "ged": 2.34, "auc": 0.9998975109809665}
#
# {"sparsity": 0.7, "normalize": true, "hard_mask": true, "fidelity_acc+": 0.61, "fidelity_acc-": 0.0, "fidelity_prob+": 0.5870216488838196, "fidelity_prob-": -4.051327778142877e-06}
#
#
# {"recall": 0.003333333333333333, "precision": 0.003333333333333333, "f1_score": 0.003333333333333333, "ged": 14.34, "auc": 0.5011934683585489}
#
# {"sparsity": 0.7, "normalize": true, "hard_mask": true, "fidelity_acc+": 0.37, "fidelity_acc-": 0.58, "fidelity_prob+": 0.37630560994148254, "fidelity_prob-": 0.562764585018158}
#
#
# {"recall": 0.6983333333333335, "precision": 0.7153333333333333, "f1_score": 0.706060606060606, "ged": 3.76, "auc": 0.9983647510980965}
#
# {"sparsity": 0.7, "normalize": true, "hard_mask": true, "fidelity_acc+": 0.61, "fidelity_acc-": 0.0, "fidelity_prob+": 0.5870216488838196, "fidelity_prob-": -0.0040666102431714535}
#
#
# {"recall": 0.415, "precision": 0.4153333333333334, "f1_score": 0.41515151515151516, "ged": 6.84, "auc": 0.5075638522856678}
#
# {"sparsity": 0.7, "normalize": true, "hard_mask": true, "fidelity_acc+": 0.33, "fidelity_acc-": 0.47, "fidelity_prob+": 0.3752467632293701, "fidelity_prob-": 0.45381760597229004}
#
#
# {"recall": 0.33333333333333326, "precision": 0.355, "f1_score": 0.3431818181818182, "ged": 8.19, "auc": 0.97229939401334}
#
# {"sparsity": 0.7, "normalize": true, "hard_mask": true, "fidelity_acc+": 0.61, "fidelity_acc-": 0.0, "fidelity_prob+": 0.5870190262794495, "fidelity_prob-": 0.0019411015091463923}
#
#
# {"recall": 0.06166666666666666, "precision": 0.06166666666666666, "f1_score": 0.06166666666666666, "ged": 9.64, "auc": 0.060232328778265815}
#
# {"sparsity": 0.7, "normalize": true, "hard_mask": true, "fidelity_acc+": 0.19, "fidelity_acc-": 0.43, "fidelity_prob+": 0.18756328523159027, "fidelity_prob-": 0.41649672389030457}
#
#
# {"recall": 0.6283333333333334, "precision": 0.6283333333333334, "f1_score": 0.6283333333333334, "ged": 5.27, "auc": 0.9915926468195869}
#
# {"sparsity": 0.7, "normalize": true, "hard_mask": true, "fidelity_acc+": 0.61, "fidelity_acc-": 0.0, "fidelity_prob+": 0.5870215892791748, "fidelity_prob-": -0.0005045277066528797}
#
#
# {"recall": 0.9233333333333335, "precision": 0.9233333333333335, "f1_score": 0.9233333333333335, "ged": 1.38, "auc": 0.9999349276069629}
#
# {"sparsity": 0.7, "normalize": true, "hard_mask": true, "fidelity_acc+": 0.61, "fidelity_acc-": 0.03, "fidelity_prob+": 0.5870215892791748, "fidelity_prob-": 0.024956680834293365}
#
#
# {"recall": 0.7566666666666667, "precision": 0.8656666666666666, "f1_score": 0.8058484848484849, "ged": 3.17, "auc": 0.9374829184968276}
#
# {"sparsity": 0.7, "normalize": true, "hard_mask": true, "fidelity_acc+": 0.76, "fidelity_acc-": 0.04, "fidelity_prob+": 0.6705951690673828, "fidelity_prob-": 0.09923192858695984}
#
# _explainer_name=random

# %%
ranges
# Out:
# {'data_save_dir': 'data',
#  'num_test_nodes': 100,
#  'dataset': 'syn1',
#  'explainer_name': ['random',
#   'distance',
#   'pagerank',
#   'sa_node',
#   'ig_node',
#   'occlusion',
#   'gnnexplainer',
#   'pgmexplainer',
#   'subgraphx'],
#  'none': ''}

# %%
name = '{none}_explainer_name={explainer_name}'

# %%
df_acc = get_df_results(accuracy, ranges, name, metrics = ['f1_score', 'recall', 'precision', 'ged', 'auc'])
df_acc
# Out:
#   none explainer_name dataset  num_test_nodes data_save_dir  f1_score  \
# 0              random    syn1             100          data  0.003333
# 1            distance    syn1             100          data  0.706061
# 2            pagerank    syn1             100          data  0.870000
# 3             sa_node    syn1             100          data  0.415152
# 4             ig_node    syn1             100          data  0.923333
# 5           occlusion    syn1             100          data  0.061667
# 6        gnnexplainer    syn1             100          data  0.343182
# 7        pgmexplainer    syn1             100          data  0.628333
# 8           subgraphx    syn1             100          data  0.805848
#
#      recall  precision    ged       auc
# 0  0.003333   0.003333  14.34  0.501193
# 1  0.698333   0.715333   3.76  0.998365
# 2  0.870000   0.870000   2.34  0.999898
# 3  0.415000   0.415333   6.84  0.507564
# 4  0.923333   0.923333   1.38  0.999935
# 5  0.061667   0.061667   9.64  0.060232
# 6  0.333333   0.355000   8.19  0.972299
# 7  0.628333   0.628333   5.27  0.991593
# 8  0.756667   0.865667   3.17  0.937483

# %%
df_fid = get_df_results(fidelity, ranges, name, metrics = ['fidelity_acc+', 'fidelity_acc-', 'fidelity_prob+', 'fidelity_prob-'])
df_fid
# Out:
#   none explainer_name dataset  num_test_nodes data_save_dir  fidelity_acc+  \
# 0              random    syn1             100          data           0.37
# 1            distance    syn1             100          data           0.61
# 2            pagerank    syn1             100          data           0.61
# 3             sa_node    syn1             100          data           0.33
# 4             ig_node    syn1             100          data           0.61
# 5           occlusion    syn1             100          data           0.19
# 6        gnnexplainer    syn1             100          data           0.61
# 7        pgmexplainer    syn1             100          data           0.61
# 8           subgraphx    syn1             100          data           0.76
#
#    fidelity_acc-  fidelity_prob+  fidelity_prob-
# 0           0.58        0.376306        0.562765
# 1           0.00        0.587022       -0.004067
# 2           0.00        0.587022       -0.000004
# 3           0.47        0.375247        0.453818
# 4           0.03        0.587022        0.024957
# 5           0.43        0.187563        0.416497
# 6           0.00        0.587019        0.001941
# 7           0.00        0.587022       -0.000505
# 8           0.04        0.670595        0.099232

# %%
res = df.groupby(by=['dataset','ntrain', 'nbits', 'M_sub', 'dist', 'reranking', 'decoder', 'nepochs']).mean()
res = res.drop(columns=['seed'])
res[:20]

# %%
res = res.reset_index()
