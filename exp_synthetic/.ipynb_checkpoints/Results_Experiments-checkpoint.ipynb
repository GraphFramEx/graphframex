# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import seaborn as sns
from matplotlib import axes
import pandas as pd
import os
from os.path import join
import json
# Out:
# /cluster/apps/nss/gcc-6.3.0/python/3.7.4/x86_64/lib64/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import sys, os
sys.path.append('/cluster/home/kamara/Explain')
from clutils.nbutils import *
os.getcwd()
# Out:
# '/cluster/home/kamara/Explain/exp_synthetic'

# %%
def parseLogs(logfile, kw="rawlogs:"):
    logs = {}
    dicts = []
    with open(logfile) as f:
        for i_line, line in enumerate(f):
            pos = line.find(kw)
            if pos >= 0:
                pos += len(kw)
                pos_tensor = line.find("tensor(")
                while pos_tensor >= 0:
                    comma_end = line.find(",", pos_tensor)
                    tensor_end = line.find(")", pos_tensor)
                    line_new = line[:pos_tensor] + line[pos_tensor + len("tensor("):comma_end] + line[tensor_end+1:]
                    print("LINE", line)
                    print("NEW", line_new)
                    if len(line_new) >= len(line):
                        print("No line reduction")
                        break
                    line = line_new
                    pos_tensor = line.find("tensor(")
                    
                #print(ast.literal_eval(line[pos:]))
                #line[pos:] = line[pos:].replace("'", "")
                kline = line[pos:]
                kline = kline.replace("true", "True")
                try:
                    dic = ast.literal_eval(kline)
                except:
                    # print("Encountering weird patterns in logs")
                    # print("Line number %d" % i_line)
                    # print(line)
                    line = line.replace("nan,", "-1e8,")
                    line = line.replace("NaN", "-1e8")
                    try:
                        dic = ast.literal_eval(line[pos:])
                    except:
                        print("Unable to replace NaNs")
                        print(line)
                        continue
                for k in dic.keys():
                    if k not in logs:
                        logs[k] = []
                    logs[k].append(dic[k])
                dicts.append(dic)

    df = pd.DataFrame(dicts)

    return logs, df

# %%
def get_info(logdir):
    infos, accuracy, fidelity = {}, {}, {}
    for filename in os.listdir(logdir):
        if filename.endswith(".stdout") and filename.startswith("_"):
            _, infos[filename.replace(".stdout", "")] = parseLogs(join(logdir, filename), kw='__infos:')
            #_, accuracy_top[filename.replace(".stdout", "")] = parseLogs(join(logdir, filename), kw='__accuracy_top:')
            _, accuracy[filename.replace(".stdout", "")] = parseLogs(join(logdir, filename), kw='__accuracy:')
            _, fidelity[filename.replace(".stdout", "")] = parseLogs(join(logdir, filename), kw='__fidelity:')             
    return(infos, accuracy, fidelity)

def get_param_ranges(jsonpath, dataset = ""):
    f = open(jsonpath,)
    data = json.load(f)
    ranges = data['params']
    ranges['none'] = ''
    return(ranges)

# %%
def get_df_results(logs, ranges, name, metrics, selection = 'last'):
    dicts = []
    for params_set in enumerateParams(ranges):
        key = name.format(**params_set)
        # if key in logs and len(logs[key]) >= 1 and metric in logs[key]:
        any_metric = (key in logs) and (len(logs[key]) >= 1) and any([metric in logs[key] for metric in metrics])
        if any_metric:
            if selection == 'all':
                for index, row in logs[key].iterrows():
                    metrics_dict = {
                        metric: select_value(row.to_frame().T, metric, 'last') if key in logs and len(logs[key]) >= 1 and metric in logs[key] else -1
                        for metric in metrics
                    }
                    dicts.append(dictmerge(params_set, metrics_dict))
                    
            else:
                metrics_dict = {
                    metric: select_value(logs[key], metric, selection) if key in logs and len(logs[key]) >= 1 and metric in logs[key] else -1
                    for metric in metrics
                }
                dicts.append(dictmerge(params_set, metrics_dict))

    df = pd.DataFrame(dicts)
    #df = df.drop(columns=['none'])
    return df

# %% [markdown]
# ## Sparsity

# %%
logdir = f'/cluster/home/kamara/Explain/checkpoints/sparsity/logs'
jsonpath = f'/cluster/home/kamara/Explain/config_sparsity.json'
infos, accuracy, fidelity = get_info(logdir)

print(list(accuracy.keys())[1])
name = '{none}_explainer_name={explainer_name}_sparsity={sparsity}_dataset={dataset}'

ranges = get_param_ranges(jsonpath)
df_infos = get_df_results(infos, ranges, name, metrics = ['time', "number_of_edges", "mask_sparsity_init", "non_zero_values_init"])
#df_acc_top = get_df_results(accuracy_top, ranges, name, metrics = ['f1_score', 'recall', 'precision', 'ged', 'auc'])
df_acc = get_df_results(accuracy, ranges, name, metrics = ['f1_score', 'recall', 'precision', 'auc'])
df_fid = get_df_results(fidelity, ranges, name, metrics = ['fidelity_acc+', 'fidelity_acc-', 'fidelity_prob+', 'fidelity_prob-', 'mask_sparsity', 'expl_edges'])

#scores = pd.concat([df_acc, df_fid], axis=1, join="inner")
#scores = pd.merge(df_acc_top, df_acc, suffixes=['_top', ''], on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "sparsity"])
scores = df_acc
scores = pd.merge(scores, df_fid, on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "sparsity"])
scores = pd.merge(scores, df_infos, on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "sparsity"])
# Out:
# _explainer_name=random_sparsity=0_dataset=syn1

# %%
res = scores.groupby(by=['dataset', 'sparsity', 'explainer_name']).mean()
res
# Out:
#                                  num_test_nodes  gpu  f1_score  recall  \
# dataset sparsity explainer_name
# syn1    0.000    distance                 100.0  1.0  0.005823   1.000
#                  gnnexplainer             100.0  1.0  0.470810   1.000
#                  ig_node                  100.0  1.0  0.007333   0.920
#                  occlusion                100.0  1.0  0.005822   1.000
#                  pagerank                 100.0  1.0  0.005825   1.000
# ...                                         ...  ...       ...     ...
# syn6    0.997    occlusion                100.0  1.0  0.021833   0.034
#                  pagerank                 100.0  1.0  0.901818   0.992
#                  pgmexplainer             100.0  1.0  0.463463   0.512
#                  random                   100.0  1.0  0.001250   0.002
#                  sa_node                  100.0  1.0  0.093160   0.112
#
#                                  precision       auc  fidelity_acc+  \
# dataset sparsity explainer_name
# syn1    0.000    distance         0.002920  0.998450           0.53
#                  gnnexplainer     0.371259  0.968212           0.53
#                  ig_node          0.003703  0.519937           0.53
#                  occlusion        0.002920  0.040737           0.53
#                  pagerank         0.002921  0.999891           0.53
# ...                                    ...       ...            ...
# syn6    0.997    occlusion        0.016091  0.507144           0.07
#                  pagerank         0.826667  0.945806           0.64
#                  pgmexplainer     0.423651  0.743368           0.55
#                  random           0.000909  0.499104           0.00
#                  sa_node          0.080583  0.554874           0.01
#
#                                  fidelity_acc-  fidelity_prob+  \
# dataset sparsity explainer_name
# syn1    0.000    distance                 0.00        0.487905
#                  gnnexplainer             0.00        0.487905
#                  ig_node                  0.24        0.484979
#                  occlusion                0.00        0.323772
#                  pagerank                 0.00        0.487905
# ...                                        ...             ...
# syn6    0.997    occlusion                0.56        0.062125
#                  pagerank                 0.01        0.589573
#                  pgmexplainer             0.22        0.497010
#                  random                   0.64        0.000075
#                  sa_node                  0.64        0.004865
#
#                                  fidelity_prob-  mask_sparsity  expl_edges  \
# dataset sparsity explainer_name
# syn1    0.000    distance              0.000000       0.009175     4072.29
#                  gnnexplainer          0.000000       0.937606      256.44
#                  ig_node               0.238978       0.050822     3901.12
#                  occlusion            -0.100171       0.000243     4109.00
#                  pagerank              0.000000       0.000487     4108.00
# ...                                         ...            ...         ...
# syn6    0.997    occlusion             0.517062       0.997214       11.00
#                  pagerank             -0.011860       0.997214       11.00
#                  pgmexplainer          0.216077       0.997214       11.00
#                  random                0.589573       0.997214       11.00
#                  sa_node               0.589573       0.997214       11.00
#
#                                    time  number_of_edges  mask_sparsity_init  \
# dataset sparsity explainer_name
# syn1    0.000    distance        0.0159           4110.0            0.009175
#                  gnnexplainer    2.5984           4110.0            0.937606
#                  ig_node         0.1673           4110.0            0.050822
#                  occlusion       0.5983           4110.0            0.000243
#                  pagerank        0.0210           4110.0            0.000487
# ...                                 ...              ...                 ...
# syn6    0.997    occlusion       0.5959           3948.0            0.000274
#                  pagerank        0.0205           3948.0            0.000507
#                  pgmexplainer    3.7949           3948.0            0.781282
#                  random          0.0001           3948.0            0.000253
#                  sa_node         0.0031           3948.0            0.000750
#
#                                  non_zero_values_init
# dataset sparsity explainer_name
# syn1    0.000    distance                     4072.29
#                  gnnexplainer                  256.44
#                  ig_node                      3901.12
#                  occlusion                    4109.00
#                  pagerank                     4108.00
# ...                                               ...
# syn6    0.997    occlusion                    3946.92
#                  pagerank                     3946.00
#                  pgmexplainer                  863.50
#                  random                       3947.00
#                  sa_node                      3945.04
#
# [168 rows x 16 columns]

# %%
res = res.reset_index()
res.to_csv('/cluster/home/kamara/Explain/csv/sparsity.csv', index=False)

# %% [markdown]
# ## Threshold

# %%
logdir = f'/cluster/home/kamara/Explain/checkpoints/threshold/logs'
jsonpath = f'/cluster/home/kamara/Explain/config_threshold.json'
infos, accuracy, fidelity = get_info(logdir)

print(list(accuracy.keys())[1])
name = '{none}_explainer_name={explainer_name}_threshold={threshold}_dataset={dataset}'

ranges = get_param_ranges(jsonpath)
df_infos = get_df_results(infos, ranges, name, metrics = ['time', "number_of_edges", "mask_sparsity_init", "non_zero_values_init"])
#df_acc_top = get_df_results(accuracy_top, ranges, name, metrics = ['f1_score', 'recall', 'precision', 'ged', 'auc'])
df_acc = get_df_results(accuracy, ranges, name, metrics = ['f1_score', 'recall', 'precision', 'auc'])
df_fid = get_df_results(fidelity, ranges, name, metrics = ['fidelity_acc+', 'fidelity_acc-', 'fidelity_prob+', 'fidelity_prob-', 'mask_sparsity', 'expl_edges'])

#scores = pd.concat([df_acc, df_fid], axis=1, join="inner")
#scores = pd.merge(df_acc_top, df_acc, suffixes=['_top', ''], on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "sparsity"])
scores = df_acc
scores = pd.merge(scores, df_fid, on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "threshold"])
scores = pd.merge(scores, df_infos, on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "threshold"])
# Out:
# _explainer_name=random_threshold=0.5_dataset=syn3

# %%
res = scores.groupby(by=['dataset', 'threshold', 'explainer_name']).mean()
res
# Out:
#                                   num_test_nodes  gpu  f1_score    recall  \
# dataset threshold explainer_name
# syn1    0.5       distance                 100.0  1.0  0.563576  0.413333
#                   gnnexplainer             100.0  1.0  0.365325  0.650000
#                   ig_node                  100.0  1.0  0.446275  0.436667
#                   occlusion                100.0  1.0  0.001630  0.240000
#                   pagerank                 100.0  1.0  0.880128  0.861667
# ...                                          ...  ...       ...       ...
# syn6    0.9       pagerank                 100.0  1.0  0.423048  0.314000
#                   pgmexplainer             100.0  1.0  0.380048  0.376000
#                   random                   100.0  1.0  0.005078  0.194000
#                   sa_node                  100.0  1.0  0.180224  0.112000
#                   subgraphx                100.0  1.0  0.773444  0.744000
#
#                                   precision       auc  fidelity_acc+  \
# dataset threshold explainer_name
# syn1    0.5       distance         0.939500  0.603303           0.05
#                   gnnexplainer     0.355707  0.720080           0.44
#                   ig_node          0.459524  0.478424           0.05
#                   occlusion        0.000818  0.062967           0.48
#                   pagerank         0.903381  0.930774           0.53
# ...                                     ...       ...            ...
# syn6    0.9       pagerank         0.957333  0.656954           0.63
#                   pgmexplainer     0.560708  0.687330           0.57
#                   random           0.002573  0.500879           0.07
#                   sa_node          0.532635  0.336103           0.01
#                   subgraphx        0.811500  0.871812           0.62
#
#                                   fidelity_acc-  fidelity_prob+  \
# dataset threshold explainer_name
# syn1    0.5       distance                 0.53       -0.123116
#                   gnnexplainer             0.29        0.285291
#                   ig_node                  0.53        0.024774
#                   occlusion                0.05        0.433345
#                   pagerank                 0.05        0.487905
# ...                                         ...             ...
# syn6    0.9       pagerank                 0.36        0.523581
#                   pgmexplainer             0.23        0.488138
#                   random                   0.63        0.060975
#                   sa_node                  0.64       -0.014498
#                   subgraphx                0.05        0.567656
#
#                                   fidelity_prob-  mask_sparsity  expl_edges  \
# dataset threshold explainer_name
# syn1    0.5       distance              0.487905       0.999336        2.73
#                   gnnexplainer          0.151176       0.941944      238.61
#                   ig_node               0.445705       0.520219     1971.90
#                   occlusion             0.009594       0.062044     3855.00
#                   pagerank             -0.018173       0.997202       11.50
# ...                                          ...            ...         ...
# syn6    0.9       pagerank              0.326768       0.999103        3.54
#                   pgmexplainer          0.253975       0.997219       10.98
#                   random                0.577516       0.899491      396.81
#                   sa_node               0.589573       0.560998     1733.18
#                   subgraphx             0.052988       0.997741        8.92
#
#                                     time  number_of_edges  mask_sparsity_init  \
# dataset threshold explainer_name
# syn1    0.5       distance        0.0162           4110.0            0.009175
#                   gnnexplainer    2.6174           4110.0            0.937606
#                   ig_node         0.1674           4110.0            0.050822
#                   occlusion       0.7179           4110.0            0.000243
#                   pagerank        0.0198           4110.0            0.000487
# ...                                  ...              ...                 ...
# syn6    0.9       pagerank        0.0209           3948.0            0.000507
#                   pgmexplainer    3.8762           3948.0            0.780314
#                   random          0.0000           3948.0            0.000253
#                   sa_node         0.0027           3948.0            0.000750
#                   subgraphx       3.1119           3948.0            0.977741
#
#                                   non_zero_values_init
# dataset threshold explainer_name
# syn1    0.5       distance                     4072.29
#                   gnnexplainer                  256.44
#                   ig_node                      3901.12
#                   occlusion                    4109.00
#                   pagerank                     4108.00
# ...                                                ...
# syn6    0.9       pagerank                     3946.00
#                   pgmexplainer                  867.32
#                   random                       3947.00
#                   sa_node                      3945.04
#                   subgraphx                       8.92
#
# [135 rows x 16 columns]

# %%
res = res.reset_index()
res.to_csv('/cluster/home/kamara/Explain/csv/threshold.csv', index=False)

# %% [markdown]
# ## Syn1

# %%
expe = "syn1"

logdir = f'/cluster/home/kamara/Explain/checkpoints/{expe}_gpu1/logs'
jsonpath = f'/cluster/home/kamara/Explain/config_{expe}.json'
infos, accuracy_top, accuracy, fidelity = get_info(logdir)

print(list(accuracy.keys())[1])
name = '{none}_explainer_name={explainer_name}_sparsity={sparsity}'

ranges = get_param_ranges(jsonpath)
df_infos = get_df_results(infos, ranges, name, metrics = ['time', 'edge_mask size'])
df_acc_top = get_df_results(accuracy_top, ranges, name, metrics = ['f1_score', 'recall', 'precision', 'ged', 'auc'])
df_acc = get_df_results(accuracy, ranges, name, metrics = ['f1_score', 'recall', 'precision', 'auc'])
df_fid = get_df_results(fidelity, ranges, name, metrics = ['fidelity_acc+', 'fidelity_acc-', 'fidelity_prob+', 'fidelity_prob-', 'mask_sparsity', 'expl_edges'])

#scores = pd.concat([df_acc, df_fid], axis=1, join="inner")
scores = pd.merge(df_acc_top, df_acc, suffixes=['_top', ''], on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "sparsity"])
scores = pd.merge(scores, df_fid, on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "sparsity"])
scores = pd.merge(scores, df_infos, on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "sparsity"])
# Out:
# _explainer_name=random_sparsity=0.997

# %%
res = scores.groupby(by=['dataset', 'sparsity', 'explainer_name']).mean()
res
# Out:
#                                  num_test_nodes  gpu  f1_score_top  \
# dataset sparsity explainer_name
# syn1    0.700    distance                 200.0  1.0      0.684318
#                  gnnexplainer             200.0  1.0      0.324167
#                  ig_node                  200.0  1.0      0.438333
#                  occlusion                200.0  1.0      0.054167
#                  pagerank                 200.0  1.0      0.868333
#                  pgmexplainer             200.0  1.0      0.570303
#                  random                   200.0  1.0      0.003333
#                  sa_node                  200.0  1.0      0.018788
#         0.990    distance                 200.0  1.0      0.698606
#                  gnnexplainer             200.0  1.0      0.339591
#                  ig_node                  200.0  1.0      0.438333
#                  occlusion                200.0  1.0      0.054167
#                  pagerank                 200.0  1.0      0.868333
#                  pgmexplainer             200.0  1.0      0.561667
#                  random                   200.0  1.0      0.001667
#                  sa_node                  200.0  1.0      0.018788
#         0.997    distance                 200.0  1.0      0.698606
#                  gnnexplainer             200.0  1.0      0.324076
#                  ig_node                  200.0  1.0      0.438333
#                  occlusion                200.0  1.0      0.054167
#                  pagerank                 200.0  1.0      0.868333
#                  pgmexplainer             200.0  1.0      0.572500
#                  sa_node                  200.0  1.0      0.018788
#
#                                  recall_top  precision_top     ged   auc_top  \
# dataset sparsity explainer_name
# syn1    0.700    distance          0.675000       0.695500   3.955  0.998328
#                  gnnexplainer      0.317500       0.332167   8.615  0.964629
#                  ig_node           0.438333       0.438333   4.915  0.494942
#                  occlusion         0.054167       0.054167   9.720  0.044283
#                  pagerank          0.868333       0.868333   2.355  0.999883
#                  pgmexplainer      0.570000       0.570667   5.060  0.963200
#                  random            0.003333       0.003333  14.500  0.492276
#                  sa_node           0.018333       0.019333   9.240  0.041694
#         0.990    distance          0.686667       0.713333   3.920  0.998173
#                  gnnexplainer      0.331667       0.349250   8.470  0.964168
#                  ig_node           0.438333       0.438333   4.915  0.494942
#                  occlusion         0.054167       0.054167   9.720  0.044283
#                  pagerank          0.868333       0.868333   2.355  0.999883
#                  pgmexplainer      0.561667       0.561667   4.925  0.965568
#                  random            0.001667       0.001667  14.430  0.488264
#                  sa_node           0.018333       0.019333   9.240  0.041694
#         0.997    distance          0.686667       0.713333   3.920  0.998173
#                  gnnexplainer      0.317500       0.332417   8.500  0.964230
#                  ig_node           0.438333       0.438333   4.915  0.494942
#                  occlusion         0.054167       0.054167   9.720  0.044283
#                  pagerank          0.868333       0.868333   2.355  0.999883
#                  pgmexplainer      0.572500       0.572500   4.920  0.963176
#                  sa_node           0.018333       0.019333   9.240  0.041694
#
#                                  f1_score    recall  precision       auc  \
# dataset sparsity explainer_name
# syn1    0.700    distance        0.011780  1.000000   0.005925  0.998328
#                  gnnexplainer    0.447869  0.991667   0.350985  0.958603
#                  ig_node         0.007739  0.495000   0.003917  0.671412
#                  occlusion       0.000672  0.054167   0.000338  0.367211
#                  pagerank        0.019262  1.000000   0.009724  0.999883
#                  pgmexplainer    0.166578  0.961667   0.109496  0.955391
#                  random          0.005646  0.495833   0.002839  0.496022
#                  sa_node         0.000559  0.041667   0.000281  0.376535
#         0.990    distance        0.301710  1.000000   0.177717  0.979044
#                  gnnexplainer    0.444689  0.722500   0.350344  0.837309
#                  ig_node         0.171329  0.491667   0.104304  0.743236
#                  occlusion       0.013858  0.054167   0.007945  0.508709
#                  pagerank        0.444444  1.000000   0.285714  0.999883
#                  pgmexplainer    0.320390  0.694167   0.211643  0.844547
#                  random          0.003404  0.013333   0.001951  0.498342
#                  sa_node         0.014502  0.033333   0.009271  0.511796
#         0.997    distance        0.786874  0.915000   0.697554  0.879120
#                  gnnexplainer    0.404388  0.488333   0.350194  0.674471
#                  ig_node         0.439359  0.440000   0.438810  0.719220
#                  occlusion       0.036111  0.054167   0.027083  0.512151
#                  pagerank        0.868333  0.868333   0.868333  0.934091
#                  pgmexplainer    0.574551  0.575833   0.573452  0.787383
#                  sa_node         0.022051  0.023333   0.020952  0.510244
#
#                                  fidelity_acc+  fidelity_acc-  fidelity_prob+  \
# dataset sparsity explainer_name
# syn1    0.700    distance                0.545          0.000        0.529477
#                  gnnexplainer            0.540          0.030        0.491962
#                  ig_node                 0.050          0.505        0.051744
#                  occlusion               0.245          0.500        0.193465
#                  pagerank                0.555          0.000        0.510232
#                  pgmexplainer            0.555          0.000        0.510232
#                  random                  0.290          0.510        0.159717
#                  sa_node                 0.050          0.555        0.004099
#         0.990    distance                0.555          0.040        0.510232
#                  gnnexplainer            0.280          0.365        0.247614
#                  ig_node                 0.050          0.505        0.051744
#                  occlusion               0.245          0.500        0.193465
#                  pagerank                0.555          0.000        0.510232
#                  pgmexplainer            0.370          0.285        0.358944
#                  random                  0.020          0.815        0.007721
#                  sa_node                 0.040          0.555        0.003970
#         0.997    distance                0.445          0.190        0.395173
#                  gnnexplainer            0.200          0.555        0.118188
#                  ig_node                 0.050          0.555        0.051744
#                  occlusion               0.245          0.500        0.193465
#                  pagerank                0.555          0.050        0.510232
#                  pgmexplainer            0.270          0.400        0.270277
#                  sa_node                 0.040          0.555        0.002697
#
#                                  fidelity_prob-  mask_sparsity  expl_edges  \
# dataset sparsity explainer_name
# syn1    0.700    distance             -0.002840       0.700000    1233.000
#                  gnnexplainer          0.029511       0.934581     268.870
#                  ig_node               0.458489       0.706674    1205.570
#                  occlusion             0.461735       0.700000    1233.000
#                  pagerank             -0.000320       0.700000    1233.000
#                  pgmexplainer         -0.005457       0.871523     528.040
#                  random                0.389428       0.700000    1233.000
#                  sa_node               0.518148       0.700000    1233.000
#         0.990    distance             -0.020407       0.990025      41.000
#                  gnnexplainer          0.300891       0.992155      32.245
#                  ig_node               0.458493       0.990025      41.000
#                  occlusion             0.461735       0.990025      41.000
#                  pagerank             -0.006687       0.990025      41.000
#                  pgmexplainer          0.205173       0.990572      38.750
#                  random                0.622423       0.990025      41.000
#                  sa_node               0.521677       0.990025      41.000
#         0.997    distance              0.104364       0.997080      12.000
#                  gnnexplainer          0.404901       0.997080      12.000
#                  ig_node               0.479967       0.997080      12.000
#                  occlusion             0.461735       0.997080      12.000
#                  pagerank             -0.014527       0.997080      12.000
#                  pgmexplainer          0.292425       0.997080      12.000
#                  sa_node               0.525947       0.997080      12.000
#
#                                    time  edge_mask size
# dataset sparsity explainer_name
# syn1    0.700    distance        0.0168        4063.705
#                  gnnexplainer    2.5523         303.410
#                  ig_node         0.2659        3944.330
#                  occlusion       0.9353        4109.000
#                  pagerank        0.0218        4108.000
#                  pgmexplainer    5.3293         820.020
#                  random          0.0001        4109.000
#                  sa_node         0.0029        4108.000
#         0.990    distance        0.0197        4066.360
#                  gnnexplainer    2.6286         303.410
#                  ig_node         0.2748        3944.330
#                  occlusion       0.7970        4109.000
#                  pagerank        0.0245        4108.000
#                  pgmexplainer    6.1561         816.910
#                  random          0.0000        4109.000
#                  sa_node         0.0058        4108.000
#         0.997    distance        0.0198        4066.360
#                  gnnexplainer    5.4222         303.410
#                  ig_node         0.2740        3944.330
#                  occlusion       0.9058        4109.000
#                  pagerank        0.0246        4108.000
#                  pgmexplainer    6.5415         815.660
#                  sa_node         0.0031        4108.000

# %%
res = res.reset_index()
res.to_csv('/cluster/home/kamara/Explain/csv/syn1_gpu1.csv', index=False)

# %% [markdown]
# ## Syn2

# %%
expe = "syn2"

logdir = f'/cluster/home/kamara/Explain/checkpoints/{expe}_gpu1/logs'
jsonpath = f'/cluster/home/kamara/Explain/config_{expe}.json'
infos, accuracy_top, accuracy, fidelity = get_info(logdir)

print(list(accuracy.keys())[1])
name = '{none}_explainer_name={explainer_name}_sparsity={sparsity}'
print(accuracy_top)
ranges = get_param_ranges(jsonpath)
df_infos = get_df_results(infos, ranges, name, metrics = ['time', 'edge_mask size'])
df_acc_top = get_df_results(accuracy_top, ranges, name, metrics = ['f1_score', 'recall', 'precision', 'ged', 'auc'])
df_acc = get_df_results(accuracy, ranges, name, metrics = ['f1_score', 'recall', 'precision', 'auc'])
df_fid = get_df_results(fidelity, ranges, name, metrics = ['fidelity_acc+', 'fidelity_acc-', 'fidelity_prob+', 'fidelity_prob-', 'mask_sparsity', 'expl_edges'])

#scores = pd.concat([df_acc, df_fid], axis=1, join="inner")
scores = pd.merge(df_acc_top, df_acc, suffixes=['_top', ''], on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "sparsity"])
scores = pd.merge(scores, df_fid, on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "sparsity"])
scores = pd.merge(scores, df_infos, on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "sparsity"])
# Out:
# _explainer_name=random_sparsity=0.99
# {'_explainer_name=random_sparsity=0.997': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=random_sparsity=0.99': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=random_sparsity=0.7': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=sa_node_sparsity=0.99': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=distance_sparsity=0.7': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=distance_sparsity=0.997': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=sa_node_sparsity=0.997': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=pagerank_sparsity=0.99': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=pagerank_sparsity=0.7': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=pagerank_sparsity=0.997': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=distance_sparsity=0.99': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=sa_node_sparsity=0.7': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=ig_node_sparsity=0.99': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=ig_node_sparsity=0.7': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=ig_node_sparsity=0.997': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=occlusion_sparsity=0.7': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=occlusion_sparsity=0.99': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=gnnexplainer_sparsity=0.7': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=gnnexplainer_sparsity=0.99': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=pgmexplainer_sparsity=0.99': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=pgmexplainer_sparsity=0.7': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=occlusion_sparsity=0.997': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=gnnexplainer_sparsity=0.997': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=subgraphx_sparsity=0.7': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=pgmexplainer_sparsity=0.997': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=subgraphx_sparsity=0.99': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=subgraphx_sparsity=0.997': Empty DataFrame
# Columns: []
# Index: []}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-7897707bb7c0> in <module>
#      15
#      16 #scores = pd.concat([df_acc, df_fid], axis=1, join="inner")
# ---> 17 scores = pd.merge(df_acc_top, df_acc, suffixes=['_top', ''], on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "sparsity"])
#      18 scores = pd.merge(scores, df_fid, on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "sparsity"])
#      19 scores = pd.merge(scores, df_infos, on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "sparsity"])
#
# ~/.local/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     117         copy=copy,
#     118         indicator=indicator,
# --> 119         validate=validate,
#     120     )
#     121     return op.get_result()
#
# ~/.local/lib/python3.7/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     697             self.right_join_keys,
#     698             self.join_names,
# --> 699         ) = self._get_merge_keys()
#     700
#     701         # validate the merge keys dtypes. We may need to coerce
#
# ~/.local/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#    1094                     if not is_rkey(rk):
#    1095                         if rk is not None:
# -> 1096                             right_keys.append(right._get_label_or_level_values(rk))
#    1097                         else:
#    1098                             # work-around for merge_asof(right_index=True)
#
# ~/.local/lib/python3.7/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1777             values = self.axes[axis].get_level_values(key)._values
#    1778         else:
# -> 1779             raise KeyError(key)
#    1780
#    1781         # Check for duplicates
#
# KeyError: 'dataset'

# %%
res = scores.groupby(by=['dataset', 'sparsity', 'explainer_name']).mean()
res
# Out:
#                                  num_test_nodes  gpu  f1_score_top  \
# dataset sparsity explainer_name
# syn6    0.700    distance                 200.0  1.0      0.724667
#                  gnnexplainer             200.0  1.0      0.211556
#                  ig_node                  200.0  1.0      0.199222
#                  occlusion                200.0  1.0      0.023000
#                  pagerank                 200.0  1.0      0.663556
#                  pgmexplainer             200.0  1.0      0.391778
#                  random                   200.0  1.0      0.001000
#                  sa_node                  200.0  1.0      0.113222
#         0.990    distance                 200.0  1.0      0.724667
#                  gnnexplainer             200.0  1.0      0.248778
#                  ig_node                  200.0  1.0      0.199222
#                  occlusion                200.0  1.0      0.023000
#                  pagerank                 200.0  1.0      0.663556
#                  pgmexplainer             200.0  1.0      0.384556
#                  random                   200.0  1.0      0.002000
#                  sa_node                  200.0  1.0      0.113222
#         0.997    distance                 200.0  1.0      0.724667
#                  gnnexplainer             200.0  1.0      0.199556
#                  ig_node                  200.0  1.0      0.199222
#                  occlusion                200.0  1.0      0.023000
#                  pagerank                 200.0  1.0      0.663556
#                  pgmexplainer             200.0  1.0      0.394222
#                  random                   200.0  1.0      0.002000
#                  sa_node                  200.0  1.0      0.113222
#
#                                  recall_top  precision_top     ged   auc_top  \
# dataset sparsity explainer_name
# syn6    0.700    distance             0.724        0.72550   2.395  0.999050
#                  gnnexplainer         0.211        0.21225   5.940  0.974278
#                  ig_node              0.198        0.20075   3.840  0.409032
#                  occlusion            0.023        0.02300   4.920  0.030280
#                  pagerank             0.599        0.74425   1.490  0.999769
#                  pgmexplainer         0.371        0.41775   3.825  0.982725
#                  random               0.001        0.00100  10.715  0.512361
#                  sa_node              0.109        0.11850   4.690  0.109168
#         0.990    distance             0.724        0.72550   2.395  0.999050
#                  gnnexplainer         0.248        0.24975   6.185  0.971178
#                  ig_node              0.198        0.20075   3.840  0.409032
#                  occlusion            0.023        0.02300   4.920  0.030280
#                  pagerank             0.599        0.74425   1.490  0.999769
#                  pgmexplainer         0.364        0.41025   3.710  0.984609
#                  random               0.002        0.00200  10.580  0.506105
#                  sa_node              0.109        0.11850   4.690  0.109168
#         0.997    distance             0.724        0.72550   2.395  0.999050
#                  gnnexplainer         0.199        0.20025   6.195  0.973600
#                  ig_node              0.198        0.20075   3.840  0.409032
#                  occlusion            0.023        0.02300   4.920  0.030280
#                  pagerank             0.599        0.74425   1.490  0.999769
#                  pgmexplainer         0.374        0.41950   3.755  0.984630
#                  random               0.002        0.00200  10.675  0.510506
#                  sa_node              0.109        0.11850   4.690  0.109168
#
#                                  f1_score  recall  precision       auc  \
# dataset sparsity explainer_name
# syn6    0.700    distance        0.010153   1.000   0.005102  0.999050
#                  gnnexplainer    0.348243   0.998   0.227806  0.972267
#                  ig_node         0.004620   0.410   0.002323  0.615142
#                  occlusion       0.000306   0.025   0.000154  0.357516
#                  pagerank        0.016750   1.000   0.008446  0.999769
#                  pgmexplainer    0.055130   0.992   0.028654  0.981445
#                  random          0.005215   0.527   0.002620  0.506370
#                  sa_node         0.001372   0.109   0.000691  0.420667
#         0.990    distance        0.267626   0.998   0.154596  0.995751
#                  gnnexplainer    0.348878   0.775   0.229279  0.854141
#                  ig_node         0.127721   0.380   0.076938  0.685820
#                  occlusion       0.005547   0.023   0.003160  0.500867
#                  pagerank        0.399600   0.999   0.249750  0.999273
#                  pgmexplainer    0.269505   0.725   0.165863  0.858170
#                  random          0.005064   0.022   0.002862  0.500566
#                  sa_node         0.035720   0.109   0.021497  0.550199
#         0.997    distance        0.728213   0.945   0.597249  0.865465
#                  gnnexplainer    0.280075   0.399   0.216642  0.617156
#                  ig_node         0.203939   0.238   0.178810  0.616753
#                  occlusion       0.014833   0.023   0.010955  0.504381
#                  pagerank        0.899091   0.989   0.824167  0.944308
#                  pgmexplainer    0.453887   0.501   0.415060  0.738312
#                  random          0.005000   0.008   0.003636  0.500607
#                  sa_node         0.089706   0.109   0.076942  0.553366
#
#                                  fidelity_acc+  fidelity_acc-  fidelity_prob+  \
# dataset sparsity explainer_name
# syn6    0.700    distance                0.615          0.005        0.567775
#                  gnnexplainer            0.600          0.010        0.554587
#                  ig_node                 0.005          0.620       -0.009462
#                  occlusion               0.050          0.560        0.045719
#                  pagerank                0.615          0.000        0.567775
#                  pgmexplainer            0.615          0.005        0.567756
#                  random                  0.275          0.455        0.254208
#                  sa_node                 0.005          0.615        0.011237
#         0.990    distance                0.615          0.010        0.567775
#                  gnnexplainer            0.405          0.250        0.366553
#                  ig_node                 0.005          0.620       -0.008476
#                  occlusion               0.050          0.560        0.045443
#                  pagerank                0.615          0.015        0.567775
#                  pgmexplainer            0.600          0.085        0.551405
#                  random                  0.000          0.615        0.000276
#                  sa_node                 0.005          0.615        0.009351
#         0.997    distance                0.475          0.280        0.433863
#                  gnnexplainer            0.220          0.560        0.197179
#                  ig_node                 0.010          0.615       -0.003678
#                  occlusion               0.050          0.560        0.045443
#                  pagerank                0.615          0.005        0.567775
#                  pgmexplainer            0.520          0.240        0.464162
#                  random                  0.000          0.615        0.000529
#                  sa_node                 0.005          0.615        0.005582
#
#                                  fidelity_prob-  mask_sparsity  expl_edges  \
# dataset sparsity explainer_name
# syn6    0.700    distance              0.004474       0.700101    1184.000
#                  gnnexplainer          0.004936       0.948528     203.210
#                  ig_node               0.578642       0.700101    1184.000
#                  occlusion             0.517591       0.700101    1184.000
#                  pagerank              0.000177       0.700101    1184.000
#                  pgmexplainer          0.002712       0.863475     539.000
#                  random                0.434827       0.700101    1184.000
#                  sa_node               0.567775       0.700101    1184.000
#         0.990    distance             -0.002731       0.990122      39.000
#                  gnnexplainer          0.238552       0.991344      34.175
#                  ig_node               0.581869       0.990122      39.000
#                  occlusion             0.517594       0.990122      39.000
#                  pagerank              0.031268       0.990122      39.000
#                  pgmexplainer          0.072061       0.990122      39.000
#                  random                0.568038       0.990122      39.000
#                  sa_node               0.567775       0.990122      39.000
#         0.997    distance              0.256175       0.997214      11.000
#                  gnnexplainer          0.505190       0.997214      11.000
#                  ig_node               0.601668       0.997214      11.000
#                  occlusion             0.517594       0.997214      11.000
#                  pagerank             -0.011526       0.997214      11.000
#                  pgmexplainer          0.233307       0.997214      11.000
#                  random                0.567775       0.997214      11.000
#                  sa_node               0.567775       0.997214      11.000
#
#                                    time  edge_mask size
# dataset sparsity explainer_name
# syn6    0.700    distance        0.0135        3810.340
#                  gnnexplainer    5.4895         222.380
#                  ig_node         0.1670        3937.070
#                  occlusion       0.5154        3946.935
#                  pagerank        0.0259        3946.000
#                  pgmexplainer    5.8096         757.950
#                  random          0.0001        3947.000
#                  sa_node         0.0035        3945.050
#         0.990    distance        0.0173        3810.340
#                  gnnexplainer    2.5767         222.380
#                  ig_node         0.1420        3937.070
#                  occlusion       0.4325        3946.935
#                  pagerank        0.0187        3946.000
#                  pgmexplainer    3.7507         756.460
#                  random          0.0001        3947.000
#                  sa_node         0.0033        3945.050
#         0.997    distance        0.0179        3810.340
#                  gnnexplainer    2.8052         222.380
#                  ig_node         0.2634        3937.070
#                  occlusion       0.5240        3946.935
#                  pagerank        0.0240        3946.000
#                  pgmexplainer    5.9060         753.950
#                  random          0.0001        3947.000
#                  sa_node         0.0049        3945.050

# %%
res = res.reset_index()
res.to_csv('/cluster/home/kamara/Explain/csv/syn6_gpu1.csv', index=False)

# %% [markdown]
# ## Syn3

# %%
expe = "syn3"

logdir = f'/cluster/home/kamara/Explain/checkpoints/{expe}_gpu1/logs'
jsonpath = f'/cluster/home/kamara/Explain/config_{expe}.json'
infos, accuracy_top, accuracy, fidelity = get_info(logdir)

print(list(accuracy.keys())[1])
name = '{none}_explainer_name={explainer_name}_sparsity={sparsity}'
print(accuracy_top)
ranges = get_param_ranges(jsonpath)
df_infos = get_df_results(infos, ranges, name, metrics = ['time', 'edge_mask size'])
df_acc_top = get_df_results(accuracy_top, ranges, name, metrics = ['f1_score', 'recall', 'precision', 'ged', 'auc'])
df_acc = get_df_results(accuracy, ranges, name, metrics = ['f1_score', 'recall', 'precision', 'auc'])
df_fid = get_df_results(fidelity, ranges, name, metrics = ['fidelity_acc+', 'fidelity_acc-', 'fidelity_prob+', 'fidelity_prob-', 'mask_sparsity', 'expl_edges'])

#scores = pd.concat([df_acc, df_fid], axis=1, join="inner")
scores = pd.merge(df_acc_top, df_acc, suffixes=['_top', ''], on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "sparsity"])
scores = pd.merge(scores, df_fid, on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "sparsity"])
scores = pd.merge(scores, df_infos, on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "sparsity"])
# Out:
# _explainer_name=random_sparsity=0.99
# {'_explainer_name=distance_sparsity=0.99': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=random_sparsity=0.99': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=random_sparsity=0.7': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=random_sparsity=0.997': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=distance_sparsity=0.7': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=distance_sparsity=0.997': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=pagerank_sparsity=0.99': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=pagerank_sparsity=0.7': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=sa_node_sparsity=0.7': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=pagerank_sparsity=0.997':     recall  precision  f1_score    ged       auc
# 0  0.93375   0.937962  0.935674  1.955  0.999807, '_explainer_name=ig_node_sparsity=0.7': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=sa_node_sparsity=0.99': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=sa_node_sparsity=0.997': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=occlusion_sparsity=0.997': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=occlusion_sparsity=0.7': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=ig_node_sparsity=0.99': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=ig_node_sparsity=0.997': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=gnnexplainer_sparsity=0.7': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=gnnexplainer_sparsity=0.99': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=occlusion_sparsity=0.99': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=pgmexplainer_sparsity=0.7': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=gnnexplainer_sparsity=0.997': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=pgmexplainer_sparsity=0.99': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=pgmexplainer_sparsity=0.997': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=subgraphx_sparsity=0.7': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=subgraphx_sparsity=0.99': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=subgraphx_sparsity=0.997': Empty DataFrame
# Columns: []
# Index: []}

# %%
res = scores.groupby(by=['dataset', 'sparsity', 'explainer_name']).mean()
res
# Out:
#                                  num_test_nodes  gpu  f1_score_top  \
# dataset sparsity explainer_name
# syn3    0.997    pagerank                 200.0  1.0      0.935674
#
#                                  recall_top  precision_top    ged   auc_top  \
# dataset sparsity explainer_name
# syn3    0.997    pagerank           0.93375       0.937962  1.955  0.999807
#
#                                  f1_score    recall  precision       auc  \
# dataset sparsity explainer_name
# syn3    0.997    pagerank          0.7825  0.652083   0.978125  0.805694
#
#                                  fidelity_acc+  fidelity_acc-  fidelity_prob+  \
# dataset sparsity explainer_name
# syn3    0.997    pagerank                  0.0            0.0        0.018805
#
#                                  fidelity_prob-  mask_sparsity  expl_edges  \
# dataset sparsity explainer_name
# syn3    0.997    pagerank             -0.003817       0.997047        15.0
#
#                                    time  edge_mask size
# dataset sparsity explainer_name
# syn3    0.997    pagerank        0.0248         5076.93

# %%
res = res.reset_index()
res.to_csv('/cluster/home/kamara/Explain/csv/syn6_gpu1.csv', index=False)

# %% [markdown]
# ## Syn4

# %%
expe = "syn4"

logdir = f'/cluster/home/kamara/Explain/checkpoints/{expe}_gpu1/logs'
jsonpath = f'/cluster/home/kamara/Explain/config_{expe}.json'
infos, accuracy_top, accuracy, fidelity = get_info(logdir)

print(list(accuracy.keys())[1])
name = '{none}_explainer_name={explainer_name}_sparsity={sparsity}'
print(accuracy_top)
ranges = get_param_ranges(jsonpath)
df_infos = get_df_results(infos, ranges, name, metrics = ['time', 'edge_mask size'])
df_acc_top = get_df_results(accuracy_top, ranges, name, metrics = ['f1_score', 'recall', 'precision', 'ged', 'auc'])
df_acc = get_df_results(accuracy, ranges, name, metrics = ['f1_score', 'recall', 'precision', 'auc'])
df_fid = get_df_results(fidelity, ranges, name, metrics = ['fidelity_acc+', 'fidelity_acc-', 'fidelity_prob+', 'fidelity_prob-', 'mask_sparsity', 'expl_edges'])

#scores = pd.concat([df_acc, df_fid], axis=1, join="inner")
scores = pd.merge(df_acc_top, df_acc, suffixes=['_top', ''], on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "sparsity"])
scores = pd.merge(scores, df_fid, on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "sparsity"])
scores = pd.merge(scores, df_infos, on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "sparsity"])
# Out:
# _explainer_name=random_sparsity=0.99
# {'_explainer_name=random_sparsity=0.7': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=random_sparsity=0.99': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=random_sparsity=0.997': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=distance_sparsity=0.7':    recall  precision  f1_score  ged       auc
# 0   0.615   0.640917  0.626712  3.3  0.998626, '_explainer_name=distance_sparsity=0.99':    recall  precision  f1_score  ged       auc
# 0   0.615   0.640917  0.626712  3.3  0.998626, '_explainer_name=distance_sparsity=0.997':    recall  precision  f1_score  ged       auc
# 0   0.615   0.640917  0.626712  3.3  0.998626, '_explainer_name=pagerank_sparsity=0.7':      recall  precision  f1_score   ged       auc
# 0  0.839167   0.839167  0.839167  2.56  0.999471, '_explainer_name=pagerank_sparsity=0.99':      recall  precision  f1_score   ged       auc
# 0  0.839167   0.839167  0.839167  2.56  0.999471, '_explainer_name=sa_node_sparsity=0.99':      recall  precision  f1_score   ged       auc
# 0  0.140833      0.145  0.142727  6.92  0.144339, '_explainer_name=pagerank_sparsity=0.997':      recall  precision  f1_score   ged       auc
# 0  0.839167   0.839167  0.839167  2.56  0.999471, '_explainer_name=sa_node_sparsity=0.7':      recall  precision  f1_score   ged       auc
# 0  0.140833      0.145  0.142727  6.92  0.144339, '_explainer_name=ig_node_sparsity=0.997':    recall  precision  f1_score    ged       auc
# 0   0.855   0.863167   0.85853  2.195  0.997908, '_explainer_name=ig_node_sparsity=0.99':    recall  precision  f1_score    ged       auc
# 0   0.855   0.863167   0.85853  2.195  0.997908, '_explainer_name=sa_node_sparsity=0.997':      recall  precision  f1_score   ged       auc
# 0  0.140833      0.145  0.142727  6.92  0.144339, '_explainer_name=ig_node_sparsity=0.7':    recall  precision  f1_score    ged       auc
# 0   0.855   0.863167   0.85853  2.195  0.997908, '_explainer_name=occlusion_sparsity=0.7':    recall  precision  f1_score   ged       auc
# 0   0.605   0.609667  0.607121  6.61  0.447292, '_explainer_name=occlusion_sparsity=0.99':    recall  precision  f1_score   ged       auc
# 0   0.605   0.609667  0.607121  6.61  0.447292, '_explainer_name=occlusion_sparsity=0.997':      recall  precision  f1_score   ged       auc
# 0  0.605833     0.6105  0.607955  6.59  0.447286, '_explainer_name=gnnexplainer_sparsity=0.997':      recall  precision  f1_score    ged       auc
# 0  0.599167   0.635167  0.615439  4.995  0.998139, '_explainer_name=gnnexplainer_sparsity=0.7':      recall  precision  f1_score   ged       auc
# 0  0.590833     0.6295  0.608182  4.94  0.998143, '_explainer_name=pgmexplainer_sparsity=0.99':      recall  precision  f1_score   ged       auc
# 0  0.916667   0.968167  0.938803  0.83  0.999904, '_explainer_name=gnnexplainer_sparsity=0.99':      recall  precision  f1_score   ged       auc
# 0  0.590833   0.627167  0.607348  4.91  0.998165, '_explainer_name=pgmexplainer_sparsity=0.997':      recall  precision  f1_score    ged       auc
# 0  0.899167   0.958083  0.924152  1.015  0.999872, '_explainer_name=subgraphx_sparsity=0.7':      recall  precision  f1_score   ged       auc
# 0  0.548333   0.606333   0.57297  5.44  0.803454, '_explainer_name=pgmexplainer_sparsity=0.7':      recall  precision  f1_score    ged       auc
# 0  0.914167   0.963917  0.935212  0.885  0.999898, '_explainer_name=subgraphx_sparsity=0.99':      recall  precision  f1_score   ged       auc
# 0  0.560833   0.618167  0.585121  5.46  0.805972, '_explainer_name=subgraphx_sparsity=0.997':      recall  precision  f1_score    ged       auc
# 0  0.549167   0.603917  0.572621  5.445  0.802199}

# %%
res = scores.groupby(by=['dataset', 'sparsity', 'explainer_name']).mean()
res
# Out:
#                                  num_test_nodes  gpu  f1_score_top  \
# dataset sparsity explainer_name
# syn4    0.700    distance                 200.0  1.0      0.626712
#                  gnnexplainer             200.0  1.0      0.608182
#                  ig_node                  200.0  1.0      0.858530
#                  occlusion                200.0  1.0      0.607121
#                  pagerank                 200.0  1.0      0.839167
#                  pgmexplainer             200.0  1.0      0.935212
#                  sa_node                  200.0  1.0      0.142727
#                  subgraphx                200.0  1.0      0.572970
#         0.990    distance                 200.0  1.0      0.626712
#                  gnnexplainer             200.0  1.0      0.607348
#                  ig_node                  200.0  1.0      0.858530
#                  occlusion                200.0  1.0      0.607121
#                  pagerank                 200.0  1.0      0.839167
#                  pgmexplainer             200.0  1.0      0.938803
#                  sa_node                  200.0  1.0      0.142727
#                  subgraphx                200.0  1.0      0.585121
#         0.997    distance                 200.0  1.0      0.626712
#                  gnnexplainer             200.0  1.0      0.615439
#                  ig_node                  200.0  1.0      0.858530
#                  occlusion                200.0  1.0      0.607955
#                  pagerank                 200.0  1.0      0.839167
#                  pgmexplainer             200.0  1.0      0.924152
#                  sa_node                  200.0  1.0      0.142727
#                  subgraphx                200.0  1.0      0.572621
#
#                                  recall_top  precision_top    ged   auc_top  \
# dataset sparsity explainer_name
# syn4    0.700    distance          0.615000       0.640917  3.300  0.998626
#                  gnnexplainer      0.590833       0.629500  4.940  0.998143
#                  ig_node           0.855000       0.863167  2.195  0.997908
#                  occlusion         0.605000       0.609667  6.610  0.447292
#                  pagerank          0.839167       0.839167  2.560  0.999471
#                  pgmexplainer      0.914167       0.963917  0.885  0.999898
#                  sa_node           0.140833       0.145000  6.920  0.144339
#                  subgraphx         0.548333       0.606333  5.440  0.803454
#         0.990    distance          0.615000       0.640917  3.300  0.998626
#                  gnnexplainer      0.590833       0.627167  4.910  0.998165
#                  ig_node           0.855000       0.863167  2.195  0.997908
#                  occlusion         0.605000       0.609667  6.610  0.447292
#                  pagerank          0.839167       0.839167  2.560  0.999471
#                  pgmexplainer      0.916667       0.968167  0.830  0.999904
#                  sa_node           0.140833       0.145000  6.920  0.144339
#                  subgraphx         0.560833       0.618167  5.460  0.805972
#         0.997    distance          0.615000       0.640917  3.300  0.998626
#                  gnnexplainer      0.599167       0.635167  4.995  0.998139
#                  ig_node           0.855000       0.863167  2.195  0.997908
#                  occlusion         0.605833       0.610500  6.590  0.447286
#                  pagerank          0.839167       0.839167  2.560  0.999471
#                  pgmexplainer      0.899167       0.958083  1.015  0.999872
#                  sa_node           0.140833       0.145000  6.920  0.144339
#                  subgraphx         0.549167       0.603917  5.445  0.802199
#
#                                  f1_score    recall  precision       auc  \
# dataset sparsity explainer_name
# syn4    0.700    distance        0.035135  1.000000   0.017882  0.998626
#                  gnnexplainer    0.791955  1.000000   0.672604  0.998143
#                  ig_node         0.257116  0.998333   0.198028  0.998491
#                  occlusion       0.019510  0.641667   0.009906  0.640333
#                  pagerank        0.040514  1.000000   0.020676  0.999471
#                  pgmexplainer    0.644665  1.000000   0.494818  0.999898
#                  sa_node         0.004368  0.143333   0.002218  0.442828
#                  subgraphx       0.715182  0.607500   0.873250  0.803454
#         0.990    distance        0.679596  0.985833   0.520096  0.960458
#                  gnnexplainer    0.790623  0.981667   0.674739  0.959713
#                  ig_node         0.735008  0.989167   0.588182  0.994180
#                  occlusion       0.398306  0.641667   0.289288  0.720648
#                  pagerank        0.748750  0.998333   0.599000  0.995738
#                  pgmexplainer    0.771405  1.000000   0.631136  0.999904
#                  sa_node         0.094979  0.143333   0.071115  0.567722
#                  subgraphx       0.721273  0.612500   0.881000  0.805972
#         0.997    distance        0.645232  0.523333   0.859167  0.682560
#                  gnnexplainer    0.569323  0.498333   0.670417  0.638531
#                  ig_node         0.642222  0.481667   0.963333  0.701633
#                  occlusion       0.658212  0.543333   0.850750  0.677138
#                  pagerank        0.610000  0.457500   0.915000  0.695349
#                  pgmexplainer    0.653333  0.490000   0.980000  0.704351
#                  sa_node         0.179333  0.135833   0.265000  0.566463
#                  subgraphx       0.629202  0.496667   0.871417  0.682968
#
#                                  fidelity_acc+  fidelity_acc-  fidelity_prob+  \
# dataset sparsity explainer_name
# syn4    0.700    distance                1.000          0.000        0.983681
#                  gnnexplainer            1.000          0.000        0.983681
#                  ig_node                 1.000          0.005        0.983681
#                  occlusion               0.985          0.805        0.975911
#                  pagerank                1.000          0.000        0.983681
#                  pgmexplainer            1.000          0.000        0.983681
#                  sa_node                 0.095          1.000        0.238060
#                  subgraphx               1.000          1.000        0.983681
#         0.990    distance                1.000          0.310        0.983681
#                  gnnexplainer            0.995          0.245        0.976732
#                  ig_node                 1.000          0.040        0.983681
#                  occlusion               0.985          0.805        0.973778
#                  pagerank                1.000          0.065        0.983681
#                  pgmexplainer            1.000          0.020        0.983681
#                  sa_node                 0.095          1.000        0.238060
#                  subgraphx               1.000          1.000        0.983681
#         0.997    distance                0.970          1.000        0.941473
#                  gnnexplainer            0.815          1.000        0.781343
#                  ig_node                 0.865          1.000        0.868868
#                  occlusion               0.985          1.000        0.975893
#                  pagerank                1.000          1.000        0.981763
#                  pgmexplainer            0.820          1.000        0.825887
#                  sa_node                 0.070          1.000        0.219666
#                  subgraphx               0.980          1.000        0.957547
#
#                                  fidelity_prob-  mask_sparsity  expl_edges  \
# dataset sparsity explainer_name
# syn4    0.700    distance              0.000000       0.700413     580.000
#                  gnnexplainer          0.000000       0.990108      19.150
#                  ig_node               0.030835       0.799334     388.490
#                  occlusion             0.800374       0.700413     580.000
#                  pagerank              0.000000       0.700413     580.000
#                  pgmexplainer          0.000000       0.985651      27.780
#                  sa_node               0.983681       0.700413     580.000
#                  subgraphx             0.947432       0.995646       8.430
#         0.990    distance              0.333360       0.990186      19.000
#                  gnnexplainer          0.221270       0.991211      17.015
#                  ig_node               0.084763       0.990367      18.650
#                  occlusion             0.800374       0.990186      19.000
#                  pagerank              0.059558       0.990186      19.000
#                  pgmexplainer          0.015063       0.990514      18.365
#                  sa_node               0.983681       0.990186      19.000
#                  subgraphx             0.947216       0.995651       8.420
#         0.997    distance              0.912662       0.997417       5.000
#                  gnnexplainer          0.983199       0.997417       5.000
#                  ig_node               0.891070       0.997417       5.000
#                  occlusion             0.979240       0.997417       5.000
#                  pagerank              0.892771       0.997417       5.000
#                  pgmexplainer          0.894390       0.997417       5.000
#                  sa_node               0.983681       0.997417       5.000
#                  subgraphx             0.945934       0.997417       5.000
#
#                                    time  edge_mask size
# dataset sparsity explainer_name
# syn4    0.700    distance        0.0097        1926.440
#                  gnnexplainer    2.7866          19.150
#                  ig_node         0.2788        1272.520
#                  occlusion       0.0919        1933.905
#                  pagerank        0.0139        1933.610
#                  pgmexplainer    7.2730          27.780
#                  sa_node         0.0030        1933.280
#                  subgraphx       0.3506           8.430
#         0.990    distance        0.0068        1926.440
#                  gnnexplainer    2.4973          19.150
#                  ig_node         0.2749        1272.520
#                  occlusion       0.0922        1933.905
#                  pagerank        0.0130        1933.610
#                  pgmexplainer    4.5190          27.780
#                  sa_node         0.0031        1933.280
#                  subgraphx       0.3395           8.420
#         0.997    distance        0.0102        1926.440
#                  gnnexplainer    2.7057          19.150
#                  ig_node         0.3205        1272.520
#                  occlusion       0.0571        1933.905
#                  pagerank        0.0134        1933.610
#                  pgmexplainer    6.8353          27.780
#                  sa_node         0.0053        1933.280
#                  subgraphx       0.3566           8.420

# %%
res = res.reset_index()
res.to_csv('/cluster/home/kamara/Explain/csv/syn4_gpu1.csv', index=False)

# %% [markdown]
# ## Syn5

# %%
expe = "syn5"

logdir = f'/cluster/home/kamara/Explain/checkpoints/{expe}_gpu1/logs'
jsonpath = f'/cluster/home/kamara/Explain/config_{expe}.json'
infos, accuracy_top, accuracy, fidelity = get_info(logdir)

print(list(accuracy.keys())[1])
name = '{none}_explainer_name={explainer_name}_sparsity={sparsity}'
print(accuracy_top)
ranges = get_param_ranges(jsonpath)
df_infos = get_df_results(infos, ranges, name, metrics = ['time', 'edge_mask size'])
df_acc_top = get_df_results(accuracy_top, ranges, name, metrics = ['f1_score', 'recall', 'precision', 'ged', 'auc'])
df_acc = get_df_results(accuracy, ranges, name, metrics = ['f1_score', 'recall', 'precision', 'auc'])
df_fid = get_df_results(fidelity, ranges, name, metrics = ['fidelity_acc+', 'fidelity_acc-', 'fidelity_prob+', 'fidelity_prob-', 'mask_sparsity', 'expl_edges'])

#scores = pd.concat([df_acc, df_fid], axis=1, join="inner")
scores = pd.merge(df_acc_top, df_acc, suffixes=['_top', ''], on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "sparsity"])
scores = pd.merge(scores, df_fid, on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "sparsity"])
scores = pd.merge(scores, df_infos, on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "sparsity"])
# Out:
# _explainer_name=random_sparsity=0.7
# {'_explainer_name=random_sparsity=0.99': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=random_sparsity=0.7': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=random_sparsity=0.997': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=distance_sparsity=0.7': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=distance_sparsity=0.99': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=pagerank_sparsity=0.997': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=pagerank_sparsity=0.99': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=distance_sparsity=0.997': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=pagerank_sparsity=0.7': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=sa_node_sparsity=0.7': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=sa_node_sparsity=0.99': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=ig_node_sparsity=0.99': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=sa_node_sparsity=0.997': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=ig_node_sparsity=0.997': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=ig_node_sparsity=0.7': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=occlusion_sparsity=0.7': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=occlusion_sparsity=0.99': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=occlusion_sparsity=0.997': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=gnnexplainer_sparsity=0.7': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=gnnexplainer_sparsity=0.99': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=gnnexplainer_sparsity=0.997': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=pgmexplainer_sparsity=0.7': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=pgmexplainer_sparsity=0.99': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=pgmexplainer_sparsity=0.997': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=subgraphx_sparsity=0.7': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=subgraphx_sparsity=0.997': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=subgraphx_sparsity=0.99': Empty DataFrame
# Columns: []
# Index: []}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-7f24c2a48f57> in <module>
#      15
#      16 #scores = pd.concat([df_acc, df_fid], axis=1, join="inner")
# ---> 17 scores = pd.merge(df_acc_top, df_acc, suffixes=['_top', ''], on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "sparsity"])
#      18 scores = pd.merge(scores, df_fid, on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "sparsity"])
#      19 scores = pd.merge(scores, df_infos, on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "sparsity"])
#
# ~/.local/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     117         copy=copy,
#     118         indicator=indicator,
# --> 119         validate=validate,
#     120     )
#     121     return op.get_result()
#
# ~/.local/lib/python3.7/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     697             self.right_join_keys,
#     698             self.join_names,
# --> 699         ) = self._get_merge_keys()
#     700
#     701         # validate the merge keys dtypes. We may need to coerce
#
# ~/.local/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#    1094                     if not is_rkey(rk):
#    1095                         if rk is not None:
# -> 1096                             right_keys.append(right._get_label_or_level_values(rk))
#    1097                         else:
#    1098                             # work-around for merge_asof(right_index=True)
#
# ~/.local/lib/python3.7/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1777             values = self.axes[axis].get_level_values(key)._values
#    1778         else:
# -> 1779             raise KeyError(key)
#    1780
#    1781         # Check for duplicates
#
# KeyError: 'dataset'

# %%
res = scores.groupby(by=['dataset', 'sparsity', 'explainer_name']).mean()
res
# Out:
#                                  num_test_nodes  gpu  f1_score_top  \
# dataset sparsity explainer_name
# syn4    0.700    distance                 200.0  1.0      0.626712
#                  gnnexplainer             200.0  1.0      0.608182
#                  ig_node                  200.0  1.0      0.858530
#                  occlusion                200.0  1.0      0.607121
#                  pagerank                 200.0  1.0      0.839167
#                  pgmexplainer             200.0  1.0      0.935212
#                  sa_node                  200.0  1.0      0.142727
#                  subgraphx                200.0  1.0      0.572970
#         0.990    distance                 200.0  1.0      0.626712
#                  gnnexplainer             200.0  1.0      0.607348
#                  ig_node                  200.0  1.0      0.858530
#                  occlusion                200.0  1.0      0.607121
#                  pagerank                 200.0  1.0      0.839167
#                  pgmexplainer             200.0  1.0      0.938803
#                  sa_node                  200.0  1.0      0.142727
#                  subgraphx                200.0  1.0      0.585121
#         0.997    distance                 200.0  1.0      0.626712
#                  gnnexplainer             200.0  1.0      0.615439
#                  ig_node                  200.0  1.0      0.858530
#                  occlusion                200.0  1.0      0.607955
#                  pagerank                 200.0  1.0      0.839167
#                  pgmexplainer             200.0  1.0      0.924152
#                  sa_node                  200.0  1.0      0.142727
#                  subgraphx                200.0  1.0      0.572621
#
#                                  recall_top  precision_top    ged   auc_top  \
# dataset sparsity explainer_name
# syn4    0.700    distance          0.615000       0.640917  3.300  0.998626
#                  gnnexplainer      0.590833       0.629500  4.940  0.998143
#                  ig_node           0.855000       0.863167  2.195  0.997908
#                  occlusion         0.605000       0.609667  6.610  0.447292
#                  pagerank          0.839167       0.839167  2.560  0.999471
#                  pgmexplainer      0.914167       0.963917  0.885  0.999898
#                  sa_node           0.140833       0.145000  6.920  0.144339
#                  subgraphx         0.548333       0.606333  5.440  0.803454
#         0.990    distance          0.615000       0.640917  3.300  0.998626
#                  gnnexplainer      0.590833       0.627167  4.910  0.998165
#                  ig_node           0.855000       0.863167  2.195  0.997908
#                  occlusion         0.605000       0.609667  6.610  0.447292
#                  pagerank          0.839167       0.839167  2.560  0.999471
#                  pgmexplainer      0.916667       0.968167  0.830  0.999904
#                  sa_node           0.140833       0.145000  6.920  0.144339
#                  subgraphx         0.560833       0.618167  5.460  0.805972
#         0.997    distance          0.615000       0.640917  3.300  0.998626
#                  gnnexplainer      0.599167       0.635167  4.995  0.998139
#                  ig_node           0.855000       0.863167  2.195  0.997908
#                  occlusion         0.605833       0.610500  6.590  0.447286
#                  pagerank          0.839167       0.839167  2.560  0.999471
#                  pgmexplainer      0.899167       0.958083  1.015  0.999872
#                  sa_node           0.140833       0.145000  6.920  0.144339
#                  subgraphx         0.549167       0.603917  5.445  0.802199
#
#                                  f1_score    recall  precision       auc  \
# dataset sparsity explainer_name
# syn4    0.700    distance        0.035135  1.000000   0.017882  0.998626
#                  gnnexplainer    0.791955  1.000000   0.672604  0.998143
#                  ig_node         0.257116  0.998333   0.198028  0.998491
#                  occlusion       0.019510  0.641667   0.009906  0.640333
#                  pagerank        0.040514  1.000000   0.020676  0.999471
#                  pgmexplainer    0.644665  1.000000   0.494818  0.999898
#                  sa_node         0.004368  0.143333   0.002218  0.442828
#                  subgraphx       0.715182  0.607500   0.873250  0.803454
#         0.990    distance        0.679596  0.985833   0.520096  0.960458
#                  gnnexplainer    0.790623  0.981667   0.674739  0.959713
#                  ig_node         0.735008  0.989167   0.588182  0.994180
#                  occlusion       0.398306  0.641667   0.289288  0.720648
#                  pagerank        0.748750  0.998333   0.599000  0.995738
#                  pgmexplainer    0.771405  1.000000   0.631136  0.999904
#                  sa_node         0.094979  0.143333   0.071115  0.567722
#                  subgraphx       0.721273  0.612500   0.881000  0.805972
#         0.997    distance        0.645232  0.523333   0.859167  0.682560
#                  gnnexplainer    0.569323  0.498333   0.670417  0.638531
#                  ig_node         0.642222  0.481667   0.963333  0.701633
#                  occlusion       0.658212  0.543333   0.850750  0.677138
#                  pagerank        0.610000  0.457500   0.915000  0.695349
#                  pgmexplainer    0.653333  0.490000   0.980000  0.704351
#                  sa_node         0.179333  0.135833   0.265000  0.566463
#                  subgraphx       0.629202  0.496667   0.871417  0.682968
#
#                                  fidelity_acc+  fidelity_acc-  fidelity_prob+  \
# dataset sparsity explainer_name
# syn4    0.700    distance                1.000          0.000        0.983681
#                  gnnexplainer            1.000          0.000        0.983681
#                  ig_node                 1.000          0.005        0.983681
#                  occlusion               0.985          0.805        0.975911
#                  pagerank                1.000          0.000        0.983681
#                  pgmexplainer            1.000          0.000        0.983681
#                  sa_node                 0.095          1.000        0.238060
#                  subgraphx               1.000          1.000        0.983681
#         0.990    distance                1.000          0.310        0.983681
#                  gnnexplainer            0.995          0.245        0.976732
#                  ig_node                 1.000          0.040        0.983681
#                  occlusion               0.985          0.805        0.973778
#                  pagerank                1.000          0.065        0.983681
#                  pgmexplainer            1.000          0.020        0.983681
#                  sa_node                 0.095          1.000        0.238060
#                  subgraphx               1.000          1.000        0.983681
#         0.997    distance                0.970          1.000        0.941473
#                  gnnexplainer            0.815          1.000        0.781343
#                  ig_node                 0.865          1.000        0.868868
#                  occlusion               0.985          1.000        0.975893
#                  pagerank                1.000          1.000        0.981763
#                  pgmexplainer            0.820          1.000        0.825887
#                  sa_node                 0.070          1.000        0.219666
#                  subgraphx               0.980          1.000        0.957547
#
#                                  fidelity_prob-  mask_sparsity  expl_edges  \
# dataset sparsity explainer_name
# syn4    0.700    distance              0.000000       0.700413     580.000
#                  gnnexplainer          0.000000       0.990108      19.150
#                  ig_node               0.030835       0.799334     388.490
#                  occlusion             0.800374       0.700413     580.000
#                  pagerank              0.000000       0.700413     580.000
#                  pgmexplainer          0.000000       0.985651      27.780
#                  sa_node               0.983681       0.700413     580.000
#                  subgraphx             0.947432       0.995646       8.430
#         0.990    distance              0.333360       0.990186      19.000
#                  gnnexplainer          0.221270       0.991211      17.015
#                  ig_node               0.084763       0.990367      18.650
#                  occlusion             0.800374       0.990186      19.000
#                  pagerank              0.059558       0.990186      19.000
#                  pgmexplainer          0.015063       0.990514      18.365
#                  sa_node               0.983681       0.990186      19.000
#                  subgraphx             0.947216       0.995651       8.420
#         0.997    distance              0.912662       0.997417       5.000
#                  gnnexplainer          0.983199       0.997417       5.000
#                  ig_node               0.891070       0.997417       5.000
#                  occlusion             0.979240       0.997417       5.000
#                  pagerank              0.892771       0.997417       5.000
#                  pgmexplainer          0.894390       0.997417       5.000
#                  sa_node               0.983681       0.997417       5.000
#                  subgraphx             0.945934       0.997417       5.000
#
#                                    time  edge_mask size
# dataset sparsity explainer_name
# syn4    0.700    distance        0.0097        1926.440
#                  gnnexplainer    2.7866          19.150
#                  ig_node         0.2788        1272.520
#                  occlusion       0.0919        1933.905
#                  pagerank        0.0139        1933.610
#                  pgmexplainer    7.2730          27.780
#                  sa_node         0.0030        1933.280
#                  subgraphx       0.3506           8.430
#         0.990    distance        0.0068        1926.440
#                  gnnexplainer    2.4973          19.150
#                  ig_node         0.2749        1272.520
#                  occlusion       0.0922        1933.905
#                  pagerank        0.0130        1933.610
#                  pgmexplainer    4.5190          27.780
#                  sa_node         0.0031        1933.280
#                  subgraphx       0.3395           8.420
#         0.997    distance        0.0102        1926.440
#                  gnnexplainer    2.7057          19.150
#                  ig_node         0.3205        1272.520
#                  occlusion       0.0571        1933.905
#                  pagerank        0.0134        1933.610
#                  pgmexplainer    6.8353          27.780
#                  sa_node         0.0053        1933.280
#                  subgraphx       0.3566           8.420

# %%
res = res.reset_index()
res.to_csv('/cluster/home/kamara/Explain/csv/syn6_gpu1.csv', index=False)

# %% [markdown]
# ## Syn6

# %%
expe = "syn6"

logdir = f'/cluster/home/kamara/Explain/checkpoints/{expe}_gpu1/logs'
jsonpath = f'/cluster/home/kamara/Explain/config_{expe}.json'
infos, accuracy_top, accuracy, fidelity = get_info(logdir)

print(list(accuracy.keys())[1])
name = '{none}_explainer_name={explainer_name}_sparsity={sparsity}'
print(accuracy_top)
ranges = get_param_ranges(jsonpath)
df_infos = get_df_results(infos, ranges, name, metrics = ['time', 'edge_mask size'])
df_acc_top = get_df_results(accuracy_top, ranges, name, metrics = ['f1_score', 'recall', 'precision', 'ged', 'auc'])
df_acc = get_df_results(accuracy, ranges, name, metrics = ['f1_score', 'recall', 'precision', 'auc'])
df_fid = get_df_results(fidelity, ranges, name, metrics = ['fidelity_acc+', 'fidelity_acc-', 'fidelity_prob+', 'fidelity_prob-', 'mask_sparsity', 'expl_edges'])

#scores = pd.concat([df_acc, df_fid], axis=1, join="inner")
scores = pd.merge(df_acc_top, df_acc, suffixes=['_top', ''], on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "sparsity"])
scores = pd.merge(scores, df_fid, on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "sparsity"])
scores = pd.merge(scores, df_infos, on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "sparsity"])
# Out:
# _explainer_name=random_sparsity=0.99
# {'_explainer_name=random_sparsity=0.7':    recall  precision  f1_score     ged       auc
# 0   0.001      0.001     0.001  10.715  0.512361, '_explainer_name=random_sparsity=0.99':    recall  precision  f1_score    ged       auc
# 0   0.002      0.002     0.002  10.58  0.506105, '_explainer_name=random_sparsity=0.997':    recall  precision  f1_score     ged       auc
# 0   0.002      0.002     0.002  10.675  0.510506, '_explainer_name=distance_sparsity=0.7':    recall  precision  f1_score    ged      auc
# 0   0.724     0.7255  0.724667  2.395  0.99905, '_explainer_name=distance_sparsity=0.99':    recall  precision  f1_score    ged      auc
# 0   0.724     0.7255  0.724667  2.395  0.99905, '_explainer_name=distance_sparsity=0.997':    recall  precision  f1_score    ged      auc
# 0   0.724     0.7255  0.724667  2.395  0.99905, '_explainer_name=pagerank_sparsity=0.99':    recall  precision  f1_score   ged       auc
# 0   0.599    0.74425  0.663556  1.49  0.999769, '_explainer_name=pagerank_sparsity=0.7':    recall  precision  f1_score   ged       auc
# 0   0.599    0.74425  0.663556  1.49  0.999769, '_explainer_name=pagerank_sparsity=0.997':    recall  precision  f1_score   ged       auc
# 0   0.599    0.74425  0.663556  1.49  0.999769, '_explainer_name=sa_node_sparsity=0.7':    recall  precision  f1_score   ged       auc
# 0   0.109     0.1185  0.113222  4.69  0.109168, '_explainer_name=sa_node_sparsity=0.99':    recall  precision  f1_score   ged       auc
# 0   0.109     0.1185  0.113222  4.69  0.109168, '_explainer_name=sa_node_sparsity=0.997':    recall  precision  f1_score   ged       auc
# 0   0.109     0.1185  0.113222  4.69  0.109168, '_explainer_name=ig_node_sparsity=0.7':    recall  precision  f1_score   ged       auc
# 0   0.198    0.20075  0.199222  3.84  0.409032, '_explainer_name=occlusion_sparsity=0.99':    recall  precision  f1_score   ged      auc
# 0   0.023      0.023     0.023  4.92  0.03028, '_explainer_name=gnnexplainer_sparsity=0.7':    recall  precision  f1_score   ged       auc
# 0   0.211    0.21225  0.211556  5.94  0.974278, '_explainer_name=ig_node_sparsity=0.99':    recall  precision  f1_score   ged       auc
# 0   0.198    0.20075  0.199222  3.84  0.409032, '_explainer_name=ig_node_sparsity=0.997':    recall  precision  f1_score   ged       auc
# 0   0.198    0.20075  0.199222  3.84  0.409032, '_explainer_name=occlusion_sparsity=0.7':    recall  precision  f1_score   ged      auc
# 0   0.023      0.023     0.023  4.92  0.03028, '_explainer_name=gnnexplainer_sparsity=0.997':    recall  precision  f1_score    ged     auc
# 0   0.199    0.20025  0.199556  6.195  0.9736, '_explainer_name=occlusion_sparsity=0.997':    recall  precision  f1_score   ged      auc
# 0   0.023      0.023     0.023  4.92  0.03028, '_explainer_name=gnnexplainer_sparsity=0.99':    recall  precision  f1_score    ged       auc
# 0   0.248    0.24975  0.248778  6.185  0.971178, '_explainer_name=pgmexplainer_sparsity=0.7':    recall  precision  f1_score    ged       auc
# 0   0.371    0.41775  0.391778  3.825  0.982725, '_explainer_name=pgmexplainer_sparsity=0.99':    recall  precision  f1_score   ged       auc
# 0   0.364    0.41025  0.384556  3.71  0.984609, '_explainer_name=subgraphx_sparsity=0.997': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=pgmexplainer_sparsity=0.997':    recall  precision  f1_score    ged      auc
# 0   0.374     0.4195  0.394222  3.755  0.98463, '_explainer_name=subgraphx_sparsity=0.7': Empty DataFrame
# Columns: []
# Index: [], '_explainer_name=subgraphx_sparsity=0.99': Empty DataFrame
# Columns: []
# Index: []}

# %%
res = scores.groupby(by=['dataset', 'sparsity', 'explainer_name']).mean()
res
# Out:
#                                  num_test_nodes  gpu  f1_score_top  \
# dataset sparsity explainer_name
# syn6    0.700    distance                 200.0  1.0      0.724667
#                  gnnexplainer             200.0  1.0      0.211556
#                  ig_node                  200.0  1.0      0.199222
#                  occlusion                200.0  1.0      0.023000
#                  pagerank                 200.0  1.0      0.663556
#                  pgmexplainer             200.0  1.0      0.391778
#                  random                   200.0  1.0      0.001000
#                  sa_node                  200.0  1.0      0.113222
#         0.990    distance                 200.0  1.0      0.724667
#                  gnnexplainer             200.0  1.0      0.248778
#                  ig_node                  200.0  1.0      0.199222
#                  occlusion                200.0  1.0      0.023000
#                  pagerank                 200.0  1.0      0.663556
#                  pgmexplainer             200.0  1.0      0.384556
#                  random                   200.0  1.0      0.002000
#                  sa_node                  200.0  1.0      0.113222
#         0.997    distance                 200.0  1.0      0.724667
#                  gnnexplainer             200.0  1.0      0.199556
#                  ig_node                  200.0  1.0      0.199222
#                  occlusion                200.0  1.0      0.023000
#                  pagerank                 200.0  1.0      0.663556
#                  pgmexplainer             200.0  1.0      0.394222
#                  random                   200.0  1.0      0.002000
#                  sa_node                  200.0  1.0      0.113222
#
#                                  recall_top  precision_top     ged   auc_top  \
# dataset sparsity explainer_name
# syn6    0.700    distance             0.724        0.72550   2.395  0.999050
#                  gnnexplainer         0.211        0.21225   5.940  0.974278
#                  ig_node              0.198        0.20075   3.840  0.409032
#                  occlusion            0.023        0.02300   4.920  0.030280
#                  pagerank             0.599        0.74425   1.490  0.999769
#                  pgmexplainer         0.371        0.41775   3.825  0.982725
#                  random               0.001        0.00100  10.715  0.512361
#                  sa_node              0.109        0.11850   4.690  0.109168
#         0.990    distance             0.724        0.72550   2.395  0.999050
#                  gnnexplainer         0.248        0.24975   6.185  0.971178
#                  ig_node              0.198        0.20075   3.840  0.409032
#                  occlusion            0.023        0.02300   4.920  0.030280
#                  pagerank             0.599        0.74425   1.490  0.999769
#                  pgmexplainer         0.364        0.41025   3.710  0.984609
#                  random               0.002        0.00200  10.580  0.506105
#                  sa_node              0.109        0.11850   4.690  0.109168
#         0.997    distance             0.724        0.72550   2.395  0.999050
#                  gnnexplainer         0.199        0.20025   6.195  0.973600
#                  ig_node              0.198        0.20075   3.840  0.409032
#                  occlusion            0.023        0.02300   4.920  0.030280
#                  pagerank             0.599        0.74425   1.490  0.999769
#                  pgmexplainer         0.374        0.41950   3.755  0.984630
#                  random               0.002        0.00200  10.675  0.510506
#                  sa_node              0.109        0.11850   4.690  0.109168
#
#                                  f1_score  recall  precision       auc  \
# dataset sparsity explainer_name
# syn6    0.700    distance        0.010153   1.000   0.005102  0.999050
#                  gnnexplainer    0.348243   0.998   0.227806  0.972267
#                  ig_node         0.004620   0.410   0.002323  0.615142
#                  occlusion       0.000306   0.025   0.000154  0.357516
#                  pagerank        0.016750   1.000   0.008446  0.999769
#                  pgmexplainer    0.055130   0.992   0.028654  0.981445
#                  random          0.005215   0.527   0.002620  0.506370
#                  sa_node         0.001372   0.109   0.000691  0.420667
#         0.990    distance        0.267626   0.998   0.154596  0.995751
#                  gnnexplainer    0.348878   0.775   0.229279  0.854141
#                  ig_node         0.127721   0.380   0.076938  0.685820
#                  occlusion       0.005547   0.023   0.003160  0.500867
#                  pagerank        0.399600   0.999   0.249750  0.999273
#                  pgmexplainer    0.269505   0.725   0.165863  0.858170
#                  random          0.005064   0.022   0.002862  0.500566
#                  sa_node         0.035720   0.109   0.021497  0.550199
#         0.997    distance        0.728213   0.945   0.597249  0.865465
#                  gnnexplainer    0.280075   0.399   0.216642  0.617156
#                  ig_node         0.203939   0.238   0.178810  0.616753
#                  occlusion       0.014833   0.023   0.010955  0.504381
#                  pagerank        0.899091   0.989   0.824167  0.944308
#                  pgmexplainer    0.453887   0.501   0.415060  0.738312
#                  random          0.005000   0.008   0.003636  0.500607
#                  sa_node         0.089706   0.109   0.076942  0.553366
#
#                                  fidelity_acc+  fidelity_acc-  fidelity_prob+  \
# dataset sparsity explainer_name
# syn6    0.700    distance                0.615          0.005        0.567775
#                  gnnexplainer            0.600          0.010        0.554587
#                  ig_node                 0.005          0.620       -0.009462
#                  occlusion               0.050          0.560        0.045719
#                  pagerank                0.615          0.000        0.567775
#                  pgmexplainer            0.615          0.005        0.567756
#                  random                  0.275          0.455        0.254208
#                  sa_node                 0.005          0.615        0.011237
#         0.990    distance                0.615          0.010        0.567775
#                  gnnexplainer            0.405          0.250        0.366553
#                  ig_node                 0.005          0.620       -0.008476
#                  occlusion               0.050          0.560        0.045443
#                  pagerank                0.615          0.015        0.567775
#                  pgmexplainer            0.600          0.085        0.551405
#                  random                  0.000          0.615        0.000276
#                  sa_node                 0.005          0.615        0.009351
#         0.997    distance                0.475          0.280        0.433863
#                  gnnexplainer            0.220          0.560        0.197179
#                  ig_node                 0.010          0.615       -0.003678
#                  occlusion               0.050          0.560        0.045443
#                  pagerank                0.615          0.005        0.567775
#                  pgmexplainer            0.520          0.240        0.464162
#                  random                  0.000          0.615        0.000529
#                  sa_node                 0.005          0.615        0.005582
#
#                                  fidelity_prob-  mask_sparsity  expl_edges  \
# dataset sparsity explainer_name
# syn6    0.700    distance              0.004474       0.700101    1184.000
#                  gnnexplainer          0.004936       0.948528     203.210
#                  ig_node               0.578642       0.700101    1184.000
#                  occlusion             0.517591       0.700101    1184.000
#                  pagerank              0.000177       0.700101    1184.000
#                  pgmexplainer          0.002712       0.863475     539.000
#                  random                0.434827       0.700101    1184.000
#                  sa_node               0.567775       0.700101    1184.000
#         0.990    distance             -0.002731       0.990122      39.000
#                  gnnexplainer          0.238552       0.991344      34.175
#                  ig_node               0.581869       0.990122      39.000
#                  occlusion             0.517594       0.990122      39.000
#                  pagerank              0.031268       0.990122      39.000
#                  pgmexplainer          0.072061       0.990122      39.000
#                  random                0.568038       0.990122      39.000
#                  sa_node               0.567775       0.990122      39.000
#         0.997    distance              0.256175       0.997214      11.000
#                  gnnexplainer          0.505190       0.997214      11.000
#                  ig_node               0.601668       0.997214      11.000
#                  occlusion             0.517594       0.997214      11.000
#                  pagerank             -0.011526       0.997214      11.000
#                  pgmexplainer          0.233307       0.997214      11.000
#                  random                0.567775       0.997214      11.000
#                  sa_node               0.567775       0.997214      11.000
#
#                                    time  edge_mask size
# dataset sparsity explainer_name
# syn6    0.700    distance        0.0135        3810.340
#                  gnnexplainer    5.4895         222.380
#                  ig_node         0.1670        3937.070
#                  occlusion       0.5154        3946.935
#                  pagerank        0.0259        3946.000
#                  pgmexplainer    5.8096         757.950
#                  random          0.0001        3947.000
#                  sa_node         0.0035        3945.050
#         0.990    distance        0.0173        3810.340
#                  gnnexplainer    2.5767         222.380
#                  ig_node         0.1420        3937.070
#                  occlusion       0.4325        3946.935
#                  pagerank        0.0187        3946.000
#                  pgmexplainer    3.7507         756.460
#                  random          0.0001        3947.000
#                  sa_node         0.0033        3945.050
#         0.997    distance        0.0179        3810.340
#                  gnnexplainer    2.8052         222.380
#                  ig_node         0.2634        3937.070
#                  occlusion       0.5240        3946.935
#                  pagerank        0.0240        3946.000
#                  pgmexplainer    5.9060         753.950
#                  random          0.0001        3947.000
#                  sa_node         0.0049        3945.050

# %%
res = res.reset_index()
res.to_csv('/cluster/home/kamara/Explain/csv/syn6_gpu1.csv', index=False)

# %%
Expe = ["syn1", "syn3", "syn4", "syn5", "syn6"]

print(list(accuracy.keys())[1])
name = '{none}_explainer_name={explainer_name}_sparsity={sparsity}'

df = pd.DataFrame()

for expe in Expe:
    logdir = f'/cluster/home/kamara/Explain/checkpoints/{expe}_gpu1/logs'
    jsonpath = f'/cluster/home/kamara/Explain/config_{expe}.json'
    infos, accuracy_top, accuracy, fidelity = get_info(logdir)
    ranges = get_param_ranges(jsonpath)
    df_infos = get_df_results(infos, ranges, name, metrics = ['time'])
    
    df_acc_top = get_df_results(accuracy_top, ranges, name, metrics = ['f1_score', 'recall', 'precision', 'ged', 'auc'])
    df_acc = get_df_results(accuracy, ranges, name, metrics = ['f1_score', 'recall', 'precision', 'auc'])
    df_fid = get_df_results(fidelity, ranges, name, metrics = ['fidelity_acc+', 'fidelity_acc-', 'fidelity_prob+', 'fidelity_prob-'])

    #scores = pd.concat([df_acc, df_fid], axis=1, join="inner")
    print(df_acc_top)
    scores = pd.merge(df_acc_top, df_acc, suffixes=['_top', ''], on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "sparsity"])
    scores = pd.merge(scores, df_fid, on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "sparsity"])
    scores = pd.merge(scores, df_infos, on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "sparsity"])

    print(scores)
    df = pd.concat([df, scores], axis=0)
df
# Out:
# _explainer_name=random_sparsity=0.99
#    none explainer_name  sparsity dataset  num_test_nodes data_save_dir   gpu  \
# 0             distance     0.700    syn1             200          data  True
# 1             distance     0.990    syn1             200          data  True
# 2             distance     0.997    syn1             200          data  True
# 3             pagerank     0.700    syn1             200          data  True
# 4             pagerank     0.990    syn1             200          data  True
# 5             pagerank     0.997    syn1             200          data  True
# 6              sa_node     0.700    syn1             200          data  True
# 7              sa_node     0.990    syn1             200          data  True
# 8              sa_node     0.997    syn1             200          data  True
# 9              ig_node     0.700    syn1             200          data  True
# 10             ig_node     0.990    syn1             200          data  True
# 11             ig_node     0.997    syn1             200          data  True
# 12           occlusion     0.700    syn1             200          data  True
# 13           occlusion     0.990    syn1             200          data  True
# 14           occlusion     0.997    syn1             200          data  True
# 15        gnnexplainer     0.700    syn1             200          data  True
# 16        gnnexplainer     0.990    syn1             200          data  True
# 17        gnnexplainer     0.997    syn1             200          data  True
# 18        pgmexplainer     0.700    syn1             200          data  True
# 19        pgmexplainer     0.990    syn1             200          data  True
# 20        pgmexplainer     0.997    syn1             200          data  True
#
#     f1_score    recall  precision    ged       auc
# 0   0.684318  0.675000   0.695500  3.955  0.998328
# 1   0.698606  0.686667   0.713333  3.920  0.998173
# 2   0.698606  0.686667   0.713333  3.920  0.998173
# 3   0.868333  0.868333   0.868333  2.355  0.999883
# 4   0.868333  0.868333   0.868333  2.355  0.999883
# 5   0.868333  0.868333   0.868333  2.355  0.999883
# 6   0.018788  0.018333   0.019333  9.240  0.041694
# 7   0.018788  0.018333   0.019333  9.240  0.041694
# 8   0.018788  0.018333   0.019333  9.240  0.041694
# 9   0.438333  0.438333   0.438333  4.915  0.494942
# 10  0.438333  0.438333   0.438333  4.915  0.494942
# 11  0.438333  0.438333   0.438333  4.915  0.494942
# 12  0.054167  0.054167   0.054167  9.720  0.044283
# 13  0.054167  0.054167   0.054167  9.720  0.044283
# 14  0.054167  0.054167   0.054167  9.720  0.044283
# 15  0.324167  0.317500   0.332167  8.615  0.964629
# 16  0.339591  0.331667   0.349250  8.470  0.964168
# 17  0.324076  0.317500   0.332417  8.500  0.964230
# 18  0.570303  0.570000   0.570667  5.060  0.963200
# 19  0.561667  0.561667   0.561667  4.925  0.965568
# 20  0.572500  0.572500   0.572500  4.920  0.963176
#    none_top explainer_name  sparsity dataset  num_test_nodes data_save_dir  \
# 0                 distance     0.700    syn1             200          data
# 1                 distance     0.990    syn1             200          data
# 2                 distance     0.997    syn1             200          data
# 3                 pagerank     0.700    syn1             200          data
# 4                 pagerank     0.990    syn1             200          data
# 5                 pagerank     0.997    syn1             200          data
# 6                  sa_node     0.700    syn1             200          data
# 7                  sa_node     0.990    syn1             200          data
# 8                  sa_node     0.997    syn1             200          data
# 9                  ig_node     0.700    syn1             200          data
# 10                 ig_node     0.990    syn1             200          data
# 11                 ig_node     0.997    syn1             200          data
# 12               occlusion     0.700    syn1             200          data
# 13               occlusion     0.990    syn1             200          data
# 14               occlusion     0.997    syn1             200          data
# 15            gnnexplainer     0.700    syn1             200          data
# 16            gnnexplainer     0.990    syn1             200          data
# 17            gnnexplainer     0.997    syn1             200          data
# 18            pgmexplainer     0.700    syn1             200          data
# 19            pgmexplainer     0.990    syn1             200          data
# 20            pgmexplainer     0.997    syn1             200          data
#
#      gpu  f1_score_top  recall_top  precision_top  ...    recall  precision  \
# 0   True      0.684318    0.675000       0.695500  ...  1.000000   0.005925
# 1   True      0.698606    0.686667       0.713333  ...  1.000000   0.177717
# 2   True      0.698606    0.686667       0.713333  ...  0.915000   0.697554
# 3   True      0.868333    0.868333       0.868333  ...  1.000000   0.009724
# 4   True      0.868333    0.868333       0.868333  ...  1.000000   0.285714
# 5   True      0.868333    0.868333       0.868333  ...  0.868333   0.868333
# 6   True      0.018788    0.018333       0.019333  ...  0.041667   0.000281
# 7   True      0.018788    0.018333       0.019333  ...  0.033333   0.009271
# 8   True      0.018788    0.018333       0.019333  ...  0.023333   0.020952
# 9   True      0.438333    0.438333       0.438333  ...  0.495000   0.003917
# 10  True      0.438333    0.438333       0.438333  ...  0.491667   0.104304
# 11  True      0.438333    0.438333       0.438333  ...  0.440000   0.438810
# 12  True      0.054167    0.054167       0.054167  ...  0.054167   0.000338
# 13  True      0.054167    0.054167       0.054167  ...  0.054167   0.007945
# 14  True      0.054167    0.054167       0.054167  ...  0.054167   0.027083
# 15  True      0.324167    0.317500       0.332167  ...  0.991667   0.350985
# 16  True      0.339591    0.331667       0.349250  ...  0.722500   0.350344
# 17  True      0.324076    0.317500       0.332417  ...  0.488333   0.350194
# 18  True      0.570303    0.570000       0.570667  ...  0.961667   0.109496
# 19  True      0.561667    0.561667       0.561667  ...  0.694167   0.211643
# 20  True      0.572500    0.572500       0.572500  ...  0.575833   0.573452
#
#          auc  none_y  fidelity_acc+  fidelity_acc-  fidelity_prob+  \
# 0   0.998328                  0.545          0.000        0.529477
# 1   0.979044                  0.555          0.040        0.510232
# 2   0.879120                  0.445          0.190        0.395173
# 3   0.999883                  0.555          0.000        0.510232
# 4   0.999883                  0.555          0.000        0.510232
# 5   0.934091                  0.555          0.050        0.510232
# 6   0.376535                  0.050          0.555        0.004099
# 7   0.511796                  0.040          0.555        0.003970
# 8   0.510244                  0.040          0.555        0.002697
# 9   0.671412                  0.050          0.505        0.051744
# 10  0.743236                  0.050          0.505        0.051744
# 11  0.719220                  0.050          0.555        0.051744
# 12  0.367211                  0.245          0.500        0.193465
# 13  0.508709                  0.245          0.500        0.193465
# 14  0.512151                  0.245          0.500        0.193465
# 15  0.958603                  0.540          0.030        0.491962
# 16  0.837309                  0.280          0.365        0.247614
# 17  0.674471                  0.200          0.555        0.118188
# 18  0.955391                  0.555          0.000        0.510232
# 19  0.844547                  0.370          0.285        0.358944
# 20  0.787383                  0.270          0.400        0.270277
#
#    fidelity_prob-  none    time
# 0       -0.002840        0.0168
# 1       -0.020407        0.0197
# 2        0.104364        0.0198
# 3       -0.000320        0.0218
# 4       -0.006687        0.0245
# 5       -0.014527        0.0246
# 6        0.518148        0.0029
# 7        0.521677        0.0058
# 8        0.525947        0.0031
# 9        0.458489        0.2659
# 10       0.458493        0.2748
# 11       0.479967        0.2740
# 12       0.461735        0.9353
# 13       0.461735        0.7970
# 14       0.461735        0.9058
# 15       0.029511        2.5523
# 16       0.300891        2.6286
# 17       0.404901        5.4222
# 18      -0.005457        5.3293
# 19       0.205173        6.1561
# 20       0.292425        6.5415
#
# [21 rows x 24 columns]
# Empty DataFrame
# Columns: []
# Index: []
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-becd3f9a38fc> in <module>
#      19     #scores = pd.concat([df_acc, df_fid], axis=1, join="inner")
#      20     print(df_acc_top)
# ---> 21     scores = pd.merge(df_acc_top, df_acc, suffixes=['_top', ''], on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "sparsity"])
#      22     scores = pd.merge(scores, df_fid, on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "sparsity"])
#      23     scores = pd.merge(scores, df_infos, on=["dataset", "explainer_name", "num_test_nodes", "data_save_dir", "gpu", "sparsity"])
#
# ~/.local/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     117         copy=copy,
#     118         indicator=indicator,
# --> 119         validate=validate,
#     120     )
#     121     return op.get_result()
#
# ~/.local/lib/python3.7/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     697             self.right_join_keys,
#     698             self.join_names,
# --> 699         ) = self._get_merge_keys()
#     700
#     701         # validate the merge keys dtypes. We may need to coerce
#
# ~/.local/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#    1094                     if not is_rkey(rk):
#    1095                         if rk is not None:
# -> 1096                             right_keys.append(right._get_label_or_level_values(rk))
#    1097                         else:
#    1098                             # work-around for merge_asof(right_index=True)
#
# ~/.local/lib/python3.7/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1777             values = self.axes[axis].get_level_values(key)._values
#    1778         else:
# -> 1779             raise KeyError(key)
#    1780
#    1781         # Check for duplicates
#
# KeyError: 'dataset'

# %%
df = df.groupby(by=['dataset', 'explainer_name']).mean()
df
# Out:
#                         num_test_nodes  f1_score    recall  precision    ged  \
# dataset explainer_name
# syn1    distance                 100.0  0.706061  0.698333   0.715333   3.76
#         gnnexplainer             100.0  0.343182  0.333333   0.355000   8.19
#         ig_node                  100.0  0.923333  0.923333   0.923333   1.38
#         occlusion                100.0  0.061667  0.061667   0.061667   9.64
#         pagerank                 100.0  0.870000  0.870000   0.870000   2.34
#         pgmexplainer             100.0  0.628333  0.628333   0.628333   5.27
#         random                   100.0  0.003333  0.003333   0.003333  14.34
#         sa_node                  100.0  0.415152  0.415000   0.415333   6.84
#         subgraphx                100.0  0.805848  0.756667   0.865667   3.17
# syn4    distance                 100.0  0.385909  0.378333   0.395000   3.88
#         gnnexplainer             100.0  0.368485  0.361667   0.376667   4.97
#         ig_node                  100.0  0.520455  0.520000   0.521000   3.60
#         occlusion                100.0  0.486667  0.486667   0.486667   5.20
#         pagerank                 100.0  0.520000  0.520000   0.520000   3.72
#         pgmexplainer             100.0  0.596364  0.586667   0.610000   2.51
#         random                   100.0  0.003333  0.003333   0.003333  11.94
#         sa_node                  100.0  0.185121  0.183333   0.187667   7.00
#         subgraphx                100.0  0.382182  0.365000   0.405500   5.87
# syn6    distance                 100.0  0.714000  0.714000   0.714000   2.67
#         gnnexplainer             100.0  0.212444  0.212000   0.213000   6.33
#         ig_node                  100.0  0.282667  0.272000   0.296000   3.75
#         occlusion                100.0  0.002000  0.002000   0.002000   4.26
#         pagerank                 100.0  0.659333  0.594000   0.741000   1.35
#         pgmexplainer             100.0  0.374000  0.356000   0.396500   3.51
#         random                   100.0  0.000000  0.000000   0.000000  10.51
#         sa_node                  100.0  0.273333  0.258000   0.292500   4.07
#         subgraphx                100.0  0.605333  0.592000   0.622000   3.27
#
#                                  auc  fidelity_acc+  fidelity_acc-  \
# dataset explainer_name
# syn1    distance        9.983648e-01           0.61           0.00
#         gnnexplainer    9.722994e-01           0.61           0.00
#         ig_node         9.999349e-01           0.61           0.03
#         occlusion       6.023233e-02           0.19           0.43
#         pagerank        9.998975e-01           0.61           0.00
#         pgmexplainer    9.915926e-01           0.61           0.00
#         random          5.011935e-01           0.37           0.58
#         sa_node         5.075639e-01           0.33           0.47
#         subgraphx       9.374829e-01           0.76           0.04
# syn4    distance       -1.000000e+08           0.66           0.00
#         gnnexplainer   -1.000000e+08           0.66           0.00
#         ig_node        -1.000000e+08           0.66           0.01
#         occlusion      -1.000000e+08           0.63           0.55
#         pagerank       -1.000000e+08           0.66           0.00
#         pgmexplainer   -1.000000e+08           0.66           0.00
#         random         -1.000000e+08           0.45           0.64
#         sa_node        -1.000000e+08           0.29           0.64
#         subgraphx      -1.000000e+08           0.66           0.09
# syn6    distance        9.990938e-01           0.62           0.00
#         gnnexplainer    9.659125e-01           0.60           0.00
#         ig_node         3.800498e-01           0.00           0.62
#         occlusion       2.948362e-02           0.01           0.62
#         pagerank        9.997684e-01           0.62           0.00
#         pgmexplainer    9.811585e-01           0.62           0.00
#         random          5.075132e-01           0.28           0.47
#         sa_node         3.800721e-01           0.03           0.59
#         subgraphx       8.486648e-01           0.57           0.07
#
#                         fidelity_prob+  fidelity_prob-     time
# dataset explainer_name
# syn1    distance              0.587022       -0.004067   0.0160
#         gnnexplainer          0.587019        0.001941   5.7731
#         ig_node               0.587022        0.024957   0.2855
#         occlusion             0.187563        0.416497   0.9867
#         pagerank              0.587022       -0.000004   0.0211
#         pgmexplainer          0.587022       -0.000505   4.9757
#         random                0.376306        0.562765   0.0000
#         sa_node               0.375247        0.453818   0.0026
#         subgraphx             0.670595        0.099232  24.0716
# syn4    distance              0.548575        0.000000   0.0136
#         gnnexplainer          0.548575        0.000000   5.9137
#         ig_node               0.549716       -0.019863   0.2935
#         occlusion             0.530939        0.448775   0.1083
#         pagerank              0.548575        0.000000   0.0224
#         pgmexplainer          0.548575        0.000000   9.6187
#         random                0.350906        0.532336   0.0000
#         sa_node               0.203064        0.426773   0.0057
#         subgraphx             0.548409        0.162509   0.4980
# syn6    distance              0.577499       -0.000357   0.0120
#         gnnexplainer          0.563248        0.006408   2.4941
#         ig_node              -0.007132        0.584631   0.1497
#         occlusion             0.006000        0.576931   0.6072
#         pagerank              0.577499       -0.000031   0.0166
#         pgmexplainer          0.577499       -0.000557   3.3396
#         random                0.243356        0.421491   0.0000
#         sa_node               0.021633        0.555866   0.0030
#         subgraphx             0.531047        0.105819   1.5216

# %% [markdown]
# ## Gc Layers

# %%
expe = "gc_layers"
logdir = f'/cluster/home/kamara/Explain/checkpoints/{expe}/logs'
jsonpath = f'/cluster/home/kamara/Explain/config_{expe}.json'
infos, accuracy, fidelity = get_info(logdir)
ranges = get_param_ranges(jsonpath)

print(list(accuracy.keys())[1])
name = '{none}_explainer_name={explainer_name}_num_gc_layers={num_gc_layers}'
# Out:
# _explainer_name=pagerank_num_gc_layers=1

# %%
df_acc = get_df_results(accuracy, ranges, name, metrics = ['f1_score', 'recall', 'precision', 'ged', 'auc'])
df_fid = get_df_results(fidelity, ranges, name, metrics = ['fidelity_acc+', 'fidelity_acc-', 'fidelity_prob+', 'fidelity_prob-'])
scores = pd.merge(df_acc, df_fid, on=["dataset", "num_gc_layers", "explainer_name", "num_test_nodes", "data_save_dir"])
scores = scores.groupby(by=['num_gc_layers', 'explainer_name']).mean()
scores
# Out:
#                               num_test_nodes  f1_score    recall  precision  \
# num_gc_layers explainer_name
# 2             gnnexplainer             200.0  0.682879  0.652500   0.720833
#               pagerank                 200.0  0.864167  0.864167   0.864167
# 3             gnnexplainer             200.0  0.329136  0.323333   0.336250
#               pagerank                 200.0  0.864167  0.864167   0.864167
# 4             gnnexplainer             200.0  0.055833  0.055833   0.055833
#               pagerank                 200.0  0.860000  0.860000   0.860000
# 5             gnnexplainer             200.0  0.006667  0.006667   0.006667
#               pagerank                 200.0  0.859167  0.859167   0.859167
# 6             gnnexplainer             200.0  0.003333  0.003333   0.003333
#               pagerank                 200.0  0.859167  0.859167   0.859167
#
#                                  ged       auc  fidelity_acc+  fidelity_acc-  \
# num_gc_layers explainer_name
# 2             gnnexplainer     4.065  0.998892          0.835          0.000
#               pagerank         2.435  0.999885          0.835          0.000
# 3             gnnexplainer     8.160  0.972214          0.610          0.015
#               pagerank         2.430  0.999885          0.610          0.000
# 4             gnnexplainer    12.475  0.834369          0.750          0.290
#               pagerank         2.515  0.999885          0.830          0.000
# 5             gnnexplainer    14.085  0.656783          0.550          0.575
#               pagerank         2.525  0.999883          0.640          0.005
# 6             gnnexplainer    14.345  0.575590          0.610          0.645
#               pagerank         2.525  0.999883          0.640          0.005
#
#                               fidelity_prob+  fidelity_prob-
# num_gc_layers explainer_name
# 2             gnnexplainer          0.650817        0.000000
#               pagerank              0.650817        0.000000
# 3             gnnexplainer          0.582833        0.014268
#               pagerank              0.589879       -0.000021
# 4             gnnexplainer          0.571764        0.246716
#               pagerank              0.640806        0.005695
# 5             gnnexplainer          0.512901        0.548674
#               pagerank              0.608210       -0.001958
# 6             gnnexplainer          0.545983        0.581469
#               pagerank              0.579183       -0.000794

# %% [markdown]
# ## Num top edges

# %%
ranges
# Out:
# {'gpu': [True],
#  'data_save_dir': ['data'],
#  'num_test_nodes': [100],
#  'dataset': ['syn1'],
#  'num_top_edges': [4, 6, 8, 10, 14, 20],
#  'explainer_name': ['distance', 'pagerank', 'gnnexplainer'],
#  'none': ['']}

# %%
expe = "top_edges"
logdir = f'/cluster/home/kamara/Explain/checkpoints/{expe}/logs'
jsonpath = f'/cluster/home/kamara/Explain/config_{expe}.json'
infos, accuracy, fidelity = get_info(logdir)
ranges = get_param_ranges(jsonpath)
print(list(accuracy.keys())[1])

name = '{none}_explainer_name={explainer_name}_num_top_edges={num_top_edges}'
# Out:
# Unable to replace NaNs
# __accuracy:{"sparsity": 0, "normalize": false, "hard_mask": true, "recall": 0.0, "precision": 0.0, "f1_score": 0.0, "ged": 5.19, "auc": 0.5056686188384577}
#
# Unable to replace NaNs
# __accuracy:{"sparsity": 0.7, "normalize": false, "hard_mask": true, "recall": 0.0, "precision": 0.0, "f1_score": 0.0, "ged": 5.11, "auc": 0.4954032454856028}
#
# Unable to replace NaNs
# __fidelity:{"sparsity": 0, "normalize": false, "hard_mask": true, "fidelity_acc+": 0.61, "fidelity_acc-": 0.0, "fidelity_prob+": 0.5870216488838196, "fidelity_prob-": 0.0}
#
# Unable to replace NaNs
# __fidelity:{"sparsity": 0.7, "normalize": false, "hard_mask": true, "fidelity_acc+": 0.22, "fidelity_acc-": 0.44, "fidelity_prob+": 0.22215938568115234, "fidelity_prob-": 0.4264999032020569}
#
# Unable to replace NaNs
# __accuracy:{"sparsity": 0, "normalize": false, "hard_mask": true, "recall": 0.0, "precision": 0.0, "f1_score": 0.0, "ged": 13.69, "auc": 0.5056686188384577}
#
# Unable to replace NaNs
# __accuracy:{"sparsity": 0.7, "normalize": false, "hard_mask": true, "recall": 0.0, "precision": 0.0, "f1_score": 0.0, "ged": 13.54, "auc": 0.4954032454856028}
#
# Unable to replace NaNs
# __fidelity:{"sparsity": 0, "normalize": false, "hard_mask": true, "fidelity_acc+": 0.61, "fidelity_acc-": 0.0, "fidelity_prob+": 0.5870216488838196, "fidelity_prob-": 0.0}
#
# Unable to replace NaNs
# __fidelity:{"sparsity": 0.7, "normalize": false, "hard_mask": true, "fidelity_acc+": 0.22, "fidelity_acc-": 0.44, "fidelity_prob+": 0.22215938568115234, "fidelity_prob-": 0.4264999032020569}
#
# Unable to replace NaNs
# __accuracy:{"sparsity": 0, "normalize": false, "hard_mask": true, "recall": 0.0, "precision": 0.0, "f1_score": 0.0, "ged": 9.44, "auc": 0.5056686188384577}
#
# Unable to replace NaNs
# __accuracy:{"sparsity": 0.7, "normalize": false, "hard_mask": true, "recall": 0.0, "precision": 0.0, "f1_score": 0.0, "ged": 9.38, "auc": 0.4954032454856028}
#
# Unable to replace NaNs
# __fidelity:{"sparsity": 0, "normalize": false, "hard_mask": true, "fidelity_acc+": 0.61, "fidelity_acc-": 0.0, "fidelity_prob+": 0.5870215892791748, "fidelity_prob-": 0.0}
#
# Unable to replace NaNs
# __fidelity:{"sparsity": 0.7, "normalize": false, "hard_mask": true, "fidelity_acc+": 0.22, "fidelity_acc-": 0.44, "fidelity_prob+": 0.2221594601869583, "fidelity_prob-": 0.4264998137950897}
#
# Unable to replace NaNs
# __accuracy:{"sparsity": 0, "normalize": false, "hard_mask": true, "recall": 0.0, "precision": 0.0, "f1_score": 0.0, "ged": 5.0, "auc": 0.5002440214738897}
#
# Unable to replace NaNs
# __accuracy:{"sparsity": 0.7, "normalize": false, "hard_mask": true, "recall": 0.0, "precision": 0.0, "f1_score": 0.0, "ged": 5.0, "auc": 0.5091935090287945}
#
# Unable to replace NaNs
# __fidelity:{"sparsity": 0, "normalize": false, "hard_mask": true, "fidelity_acc+": 0.61, "fidelity_acc-": 0.0, "fidelity_prob+": 0.5870216488838196, "fidelity_prob-": 0.0}
#
# Unable to replace NaNs
# __fidelity:{"sparsity": 0.7, "normalize": false, "hard_mask": true, "fidelity_acc+": 0.22, "fidelity_acc-": 0.42, "fidelity_prob+": 0.2233142852783203, "fidelity_prob-": 0.4087138772010803}
#
# Unable to replace NaNs
# __accuracy:{"sparsity": 0, "normalize": false, "hard_mask": true, "recall": 0.0, "precision": 0.0, "f1_score": 0.0, "ged": 13.0, "auc": 0.5002440214738897}
#
# Unable to replace NaNs
# __accuracy:{"sparsity": 0.7, "normalize": false, "hard_mask": true, "recall": 0.0, "precision": 0.0, "f1_score": 0.0, "ged": 13.0, "auc": 0.5091935090287945}
#
# Unable to replace NaNs
# __fidelity:{"sparsity": 0, "normalize": false, "hard_mask": true, "fidelity_acc+": 0.61, "fidelity_acc-": 0.0, "fidelity_prob+": 0.5870216488838196, "fidelity_prob-": 0.0}
#
# Unable to replace NaNs
# __fidelity:{"sparsity": 0.7, "normalize": false, "hard_mask": true, "fidelity_acc+": 0.22, "fidelity_acc-": 0.42, "fidelity_prob+": 0.2233142852783203, "fidelity_prob-": 0.4087138772010803}
#
# Unable to replace NaNs
# __accuracy:{"sparsity": 0, "normalize": false, "hard_mask": true, "recall": 0.0, "precision": 0.0, "f1_score": 0.0, "ged": 9.0, "auc": 0.5002440214738897}
#
# Unable to replace NaNs
# __accuracy:{"sparsity": 0.7, "normalize": false, "hard_mask": true, "recall": 0.0, "precision": 0.0, "f1_score": 0.0, "ged": 9.0, "auc": 0.5091935090287945}
#
# Unable to replace NaNs
# __fidelity:{"sparsity": 0, "normalize": false, "hard_mask": true, "fidelity_acc+": 0.61, "fidelity_acc-": 0.0, "fidelity_prob+": 0.5870215892791748, "fidelity_prob-": 0.0}
#
# Unable to replace NaNs
# __fidelity:{"sparsity": 0.7, "normalize": false, "hard_mask": true, "fidelity_acc+": 0.22, "fidelity_acc-": 0.42, "fidelity_prob+": 0.2233143299818039, "fidelity_prob-": 0.40871378779411316}
#
# Unable to replace NaNs
# __accuracy:{"sparsity": 0, "normalize": false, "hard_mask": true, "recall": 0.0, "precision": 0.0, "f1_score": 0.0, "ged": 17.0, "auc": 0.5002440214738897}
#
# Unable to replace NaNs
# __fidelity:{"sparsity": 0, "normalize": false, "hard_mask": true, "fidelity_acc+": 0.61, "fidelity_acc-": 0.0, "fidelity_prob+": 0.5870216488838196, "fidelity_prob-": 0.0}
#
# Unable to replace NaNs
# __accuracy:{"sparsity": 0, "normalize": false, "hard_mask": true, "recall": 0.20666666666666667, "precision": 0.31916666666666665, "f1_score": 0.25044444444444447, "ged": 4.26, "auc": 0.9718399219131284}
#
# Unable to replace NaNs
# __accuracy:{"sparsity": 0.7, "normalize": false, "hard_mask": true, "recall": 0.20666666666666667, "precision": 0.31916666666666665, "f1_score": 0.25044444444444447, "ged": 4.24, "auc": 0.9742398731088335}
#
# Unable to replace NaNs
# __fidelity:{"sparsity": 0, "normalize": false, "hard_mask": true, "fidelity_acc+": 0.61, "fidelity_acc-": 0.0, "fidelity_prob+": 0.5870215892791748, "fidelity_prob-": 0.0}
#
# Unable to replace NaNs
# __fidelity:{"sparsity": 0.7, "normalize": false, "hard_mask": true, "fidelity_acc+": 0.61, "fidelity_acc-": 0.0, "fidelity_prob+": 0.5870215892791748, "fidelity_prob-": -0.00012919366417918354}
#
# Unable to replace NaNs
# __accuracy:{"sparsity": 0, "normalize": false, "hard_mask": true, "recall": 0.305, "precision": 0.3213333333333333, "f1_score": 0.3122424242424242, "ged": 6.5, "auc": 0.9718399219131284}
#
# Unable to replace NaNs
# __accuracy:{"sparsity": 0.7, "normalize": false, "hard_mask": true, "recall": 0.305, "precision": 0.3213333333333333, "f1_score": 0.3122424242424242, "ged": 6.49, "auc": 0.9742398731088335}
#
# Unable to replace NaNs
# __fidelity:{"sparsity": 0, "normalize": false, "hard_mask": true, "fidelity_acc+": 0.61, "fidelity_acc-": 0.0, "fidelity_prob+": 0.5870216488838196, "fidelity_prob-": 0.0}
#
# Unable to replace NaNs
# __fidelity:{"sparsity": 0.7, "normalize": false, "hard_mask": true, "fidelity_acc+": 0.61, "fidelity_acc-": 0.0, "fidelity_prob+": 0.5870216488838196, "fidelity_prob-": -0.00012919366417918354}
#
# Unable to replace NaNs
# __accuracy:{"sparsity": 0, "normalize": false, "hard_mask": true, "recall": 0.4566666666666667, "precision": 0.2846111111111111, "f1_score": 0.35040476190476183, "ged": 11.84, "auc": 0.9718399219131284}
#
# Unable to replace NaNs
# __fidelity:{"sparsity": 0, "normalize": false, "hard_mask": true, "fidelity_acc+": 0.61, "fidelity_acc-": 0.0, "fidelity_prob+": 0.5870215892791748, "fidelity_prob-": 0.0}
#
# Unable to replace NaNs
# __accuracy:{"sparsity": 0, "normalize": false, "hard_mask": true, "recall": 0.5416666666666666, "precision": 0.24354595404595403, "f1_score": 0.3357487100103199, "ged": 18.44, "auc": 0.9718399219131284}
#
# Unable to replace NaNs
# __fidelity:{"sparsity": 0, "normalize": false, "hard_mask": true, "fidelity_acc+": 0.61, "fidelity_acc-": 0.0, "fidelity_prob+": 0.5870216488838196, "fidelity_prob-": 0.0}
#
# Unable to replace NaNs
# __accuracy:{"sparsity": 0, "normalize": false, "hard_mask": true, "recall": 0.39166666666666666, "precision": 0.3023809523809524, "f1_score": 0.341007326007326, "ged": 9.34, "auc": 0.9718399219131284}
#
# Unable to replace NaNs
# __accuracy:{"sparsity": 0.7, "normalize": false, "hard_mask": true, "recall": 0.39166666666666666, "precision": 0.3023809523809524, "f1_score": 0.341007326007326, "ged": 9.37, "auc": 0.9742398731088335}
#
# Unable to replace NaNs
# __fidelity:{"sparsity": 0, "normalize": false, "hard_mask": true, "fidelity_acc+": 0.61, "fidelity_acc-": 0.0, "fidelity_prob+": 0.5870216488838196, "fidelity_prob-": 0.0}
#
# Unable to replace NaNs
# __fidelity:{"sparsity": 0.7, "normalize": false, "hard_mask": true, "fidelity_acc+": 0.61, "fidelity_acc-": 0.0, "fidelity_prob+": 0.5870216488838196, "fidelity_prob-": -0.00012919366417918354}
#
# _explainer_name=distance_num_top_edges=8

# %%
df_acc = get_df_results(accuracy, ranges, name, metrics = ['sparsity', 'normalize', 'hard_mask', 'f1_score', 'recall', 'precision', 'ged', 'auc'])
df_fid = get_df_results(fidelity, ranges, name, metrics = ['sparsity', 'normalize', 'hard_mask', 'fidelity_acc+', 'fidelity_acc-', 'fidelity_prob+', 'fidelity_prob-'])
scores = pd.merge(df_acc, df_fid, on=["dataset", "num_top_edges", "explainer_name", "num_test_nodes", "data_save_dir", 'sparsity', 'normalize', 'hard_mask'])
scores = scores.groupby(by=['num_top_edges', 'explainer_name']).mean()
scores
# Out:
#                               num_test_nodes  gpu_x  sparsity  normalize  \
# num_top_edges explainer_name
# 4             distance                 100.0    1.0       0.7        1.0
#               gnnexplainer             100.0    1.0       0.7        1.0
#               pagerank                 100.0    1.0       0.7        1.0
# 6             distance                 100.0    1.0       0.7        1.0
#               gnnexplainer             100.0    1.0       0.7        1.0
#               pagerank                 100.0    1.0       0.7        1.0
# 8             distance                 100.0    1.0       0.7        1.0
#               gnnexplainer             100.0    1.0       0.7        1.0
#               pagerank                 100.0    1.0       0.7        1.0
# 10            distance                 100.0    1.0       0.0        1.0
#               gnnexplainer             100.0    1.0       0.7        1.0
#               pagerank                 100.0    1.0       0.7        1.0
# 14            gnnexplainer             100.0    1.0       0.0        1.0
#
#                               hard_mask  f1_score    recall  precision    ged  \
# num_top_edges explainer_name
# 4             distance              1.0  0.000000  0.000000   0.000000   5.11
#               gnnexplainer          1.0  0.250444  0.206667   0.319167   4.24
#               pagerank              1.0  0.000000  0.000000   0.000000   5.00
# 6             distance              1.0  0.000000  0.000000   0.000000   9.38
#               gnnexplainer          1.0  0.312242  0.305000   0.321333   6.49
#               pagerank              1.0  0.000000  0.000000   0.000000   9.00
# 8             distance              1.0  0.000000  0.000000   0.000000  13.54
#               gnnexplainer          1.0  0.341007  0.391667   0.302381   9.37
#               pagerank              1.0  0.000000  0.000000   0.000000  13.00
# 10            distance              1.0  0.000000  0.000000   0.000000  17.88
#               gnnexplainer          1.0  0.350405  0.456667   0.284611  11.84
#               pagerank              1.0  0.000000  0.000000   0.000000  17.00
# 14            gnnexplainer          1.0  0.335749  0.541667   0.243546  18.44
#
#                                    auc  gpu_y  fidelity_acc+  fidelity_acc-  \
# num_top_edges explainer_name
# 4             distance        0.495403    1.0           0.22           0.44
#               gnnexplainer    0.974240    1.0           0.61           0.00
#               pagerank        0.509194    1.0           0.22           0.42
# 6             distance        0.495403    1.0           0.22           0.44
#               gnnexplainer    0.974240    1.0           0.61           0.00
#               pagerank        0.509194    1.0           0.22           0.42
# 8             distance        0.495403    1.0           0.22           0.44
#               gnnexplainer    0.974240    1.0           0.61           0.00
#               pagerank        0.509194    1.0           0.22           0.42
# 10            distance        0.505669    1.0           0.61           0.00
#               gnnexplainer    0.974240    1.0           0.61           0.00
#               pagerank        0.509194    1.0           0.22           0.42
# 14            gnnexplainer    0.971840    1.0           0.61           0.00
#
#                               fidelity_prob+  fidelity_prob-
# num_top_edges explainer_name
# 4             distance              0.222159        0.426500
#               gnnexplainer          0.587022       -0.000129
#               pagerank              0.223314        0.408714
# 6             distance              0.222159        0.426500
#               gnnexplainer          0.587022       -0.000129
#               pagerank              0.223314        0.408714
# 8             distance              0.222159        0.426500
#               gnnexplainer          0.587022       -0.000129
#               pagerank              0.223314        0.408714
# 10            distance              0.587022        0.000000
#               gnnexplainer          0.587022       -0.000129
#               pagerank              0.223314        0.408714
# 14            gnnexplainer          0.587022        0.000000

# %%
df_acc
# Out:
#    explainer_name  num_top_edges dataset  num_test_nodes data_save_dir   gpu  \
# 0        distance              4    syn1             100          data  True
# 1        distance              6    syn1             100          data  True
# 2        distance              8    syn1             100          data  True
# 3        distance             10    syn1             100          data  True
# 4        pagerank              4    syn1             100          data  True
# 5        pagerank              6    syn1             100          data  True
# 6        pagerank              8    syn1             100          data  True
# 7        pagerank             10    syn1             100          data  True
# 8    gnnexplainer              4    syn1             100          data  True
# 9    gnnexplainer              6    syn1             100          data  True
# 10   gnnexplainer              8    syn1             100          data  True
# 11   gnnexplainer             10    syn1             100          data  True
# 12   gnnexplainer             14    syn1             100          data  True
#
#     sparsity  normalize  hard_mask  f1_score    recall  precision    ged  \
# 0        0.7       True       True  0.000000  0.000000   0.000000   5.11
# 1        0.7       True       True  0.000000  0.000000   0.000000   9.38
# 2        0.7       True       True  0.000000  0.000000   0.000000  13.54
# 3        0.0       True       True  0.000000  0.000000   0.000000  17.88
# 4        0.7       True       True  0.000000  0.000000   0.000000   5.00
# 5        0.7       True       True  0.000000  0.000000   0.000000   9.00
# 6        0.7       True       True  0.000000  0.000000   0.000000  13.00
# 7        0.7       True       True  0.000000  0.000000   0.000000  17.00
# 8        0.7       True       True  0.250444  0.206667   0.319167   4.24
# 9        0.7       True       True  0.312242  0.305000   0.321333   6.49
# 10       0.7       True       True  0.341007  0.391667   0.302381   9.37
# 11       0.7       True       True  0.350405  0.456667   0.284611  11.84
# 12       0.0       True       True  0.335749  0.541667   0.243546  18.44
#
#          auc
# 0   0.495403
# 1   0.495403
# 2   0.495403
# 3   0.505669
# 4   0.509194
# 5   0.509194
# 6   0.509194
# 7   0.509194
# 8   0.974240
# 9   0.974240
# 10  0.974240
# 11  0.974240
# 12  0.971840
